# %% [markdown]
# # Data retrieval European Central Bank - rates

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys


# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
print(f"Project root: {project_root}")

from  src.data.zerocurve import Zerocurve
# Out:
# Project root: f:\OneDrive\Documents\GitHub\rl-alm

# %%
zerocurve = Zerocurve()
zerocurve.read_data()
# Out:
# 2023-11-13 12:28:41.374 | INFO     | src.data.dataset:read_data:45 - reading zerocurve data from ESW.
# <Response [200]>

# %%
zerocurve.save_data()
# Out:
# 2023-10-07 11:16:12.716 | INFO     | src.data.dataset:save_data:76 - saving zerocurve data to file.

# %%
zerocurve.load_data()
# Out:
# 2023-03-17 14:55:15.806 | INFO     | src.data.dataset:load_data:44 - loading zerocurve data from file.
# c:\Users\M\miniconda3\envs\rlalm\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: invalid value encountered in log1p
#   result = func(self.values, **kwargs)

# %%
zerocurve.yield_data.tail()
# Out:
# tenor            0         3         6         9         12        15   \
# rate_dt
# 2023-09-25  3.751683  3.751683  3.677652  3.464702  3.216968  2.985824
# 2023-09-26  3.737301  3.737301  3.656557  3.444470  3.200715  2.974377
# 2023-09-27  3.730413  3.730413  3.636575  3.421566  3.179101  2.955331
# 2023-09-28  3.721660  3.721660  3.638389  3.462015  3.262490  3.075940
# 2023-09-29  3.704640  3.704640  3.567680  3.357423  3.137363  2.938945
#
# tenor            18        24        36        48        60        84   \
# rate_dt
# 2023-09-25  2.793005  2.537665  2.411272  2.513987  2.666792  2.930921
# 2023-09-26  2.786112  2.537741  2.417661  2.521918  2.675016  2.939314
# 2023-09-27  2.769598  2.524639  2.406130  2.510145  2.663490  2.929774
# 2023-09-28  2.918661  2.706421  2.600821  2.701685  2.854605  3.126773
# 2023-09-29  2.775181  2.557949  2.448934  2.543060  2.687325  2.945825
#
# tenor            120       180       360
# rate_dt
# 2023-09-25  3.150154  3.185130  2.469549
# 2023-09-26  3.159040  3.195138  2.481582
# 2023-09-27  3.153697  3.196498  2.490209
# 2023-09-28  3.358782  3.404238  2.674394
# 2023-09-29  3.172924  3.236893  2.592162

# %%
zerocurve.lineplot()
