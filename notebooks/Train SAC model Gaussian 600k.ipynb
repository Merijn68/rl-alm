# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20SAC%20model%20Gaussian%20600k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train SAC RL model
#
# The SAC (Soft Actor-Critic) algorithm is an off-policy reinforcement learning method designed for continuous action spaces. It combines the benefits of both policy-based and value-based methods and is known for its sample efficiency and stability.
#
# The actor in SAC is responsible for selecting actions in the environment. It typically uses a neural network to learn a policy that maps observations to continuous actions.
# SAC uses a stochastic policy, which means it outputs a probability distribution over the available actions, often modeled as a Gaussian distribution.
# This stochasticity helps exploration during training.
#
# Critic: SAC also includes two critics, referred to as Q-networks. These networks estimate the state-action value function, providing two independent value estimates.
# Having multiple critics helps stabilize the training process.
#
# SAC collects data by interacting with the environment. The actor's stochastic policy is used to sample actions,
# and these actions are executed in the environment to collect state-action-reward transitions.
# SAC uses an experience replay buffer to store and sample past experiences.
# This buffer allows the algorithm to learn from a diverse set of experiences and reduce sample correlations.
#
# SAC employs a variant of the Bellman equation to update the critics. The key innovation in SAC is the use of a "soft" Bellman backup.
# This involves minimizing a loss that aims to make the critics agree with each other and be close to the minimum of the Bellman error.
#
# The actor's policy is updated based on the soft Q-values from the critics. The objective is to maximize the expected reward, including an entropy term.
# The entropy term encourages exploration by discouraging overly deterministic policies.
#
# SAC introduces a temperature parameter that scales the entropy term in the policy update. This temperature parameter can be learned or adjusted during training.
# It helps balance exploration and exploitation by controlling the level of stochasticity in the policy.
#
# These steps are repeated iteratively, allowing the agent to improve its policy and value functions over time. The process continues until convergence or a specified number of iterations.
#
# SAC's main advantages include:
#
# It can handle continuous action spaces efficiently.
# It provides a good balance between exploration and exploitation, thanks to the entropy term.
# It benefits from experience replay, which reduces sample correlations and enhances learning stability.
# It can be used in combination with target value networks for even more stability.
#
# https://arxiv.org/pdf/1801.01290.pdf

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct 22 21:58:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    44W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 700, done.
# remote: Counting objects: 100% (700/700), done.
# remote: Compressing objects: 100% (372/372), done.
# remote: Total 700 (delta 362), reused 643 (delta 320), pack-reused 0
# Receiving objects: 100% (700/700), 17.62 MiB | 2.94 MiB/s, done.
# Resolving deltas: 100% (362/362), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.1.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import SAC

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-10-22 21:59:18.571 | INFO     | src.data.dataset:read_data:45 - reading interest data from ESW.
# 2023-10-22 21:59:19.080 | INFO     | src.data.dataset:read_data:45 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# steps: 60, score: -10267

# %% [markdown]
# Define the model. For the initial model we use the A2C model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'SAC_Gausian'
ent_coef= 0.001

model = SAC(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        ent_coef='auto',
        use_sde = False, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2023-10-22 21:59:20.277 | INFO     | src.data.dataset:read_data:45 - reading interest data from ESW.
# 2023-10-22 21:59:20.561 | INFO     | src.data.dataset:read_data:45 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 600_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    n_updates       | 529339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8828     |
# |    fps             | 70       |
# |    time_elapsed    | 7521     |
# |    total_timesteps | 529680   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 389      |
# |    ent_coef        | 0.497    |
# |    ent_coef_loss   | -0.0328  |
# |    learning_rate   | 0.000117 |
# |    n_updates       | 529579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8832     |
# |    fps             | 70       |
# |    time_elapsed    | 7524     |
# |    total_timesteps | 529920   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 602      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.000117 |
# |    n_updates       | 529819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8836     |
# |    fps             | 70       |
# |    time_elapsed    | 7528     |
# |    total_timesteps | 530160   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 484      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | 0.000547 |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8840     |
# |    fps             | 70       |
# |    time_elapsed    | 7531     |
# |    total_timesteps | 530400   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 246      |
# |    ent_coef        | 0.487    |
# |    ent_coef_loss   | 0.0474   |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8844     |
# |    fps             | 70       |
# |    time_elapsed    | 7535     |
# |    total_timesteps | 530640   |
# | train/             |          |
# |    actor_loss      | -512     |
# |    critic_loss     | 549      |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | 0.256    |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8848     |
# |    fps             | 70       |
# |    time_elapsed    | 7538     |
# |    total_timesteps | 530880   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 466      |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -0.0737  |
# |    learning_rate   | 0.000115 |
# |    n_updates       | 530779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8852     |
# |    fps             | 70       |
# |    time_elapsed    | 7542     |
# |    total_timesteps | 531120   |
# | train/             |          |
# |    actor_loss      | -519     |
# |    critic_loss     | 694      |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -0.0284  |
# |    learning_rate   | 0.000115 |
# |    n_updates       | 531019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8856     |
# |    fps             | 70       |
# |    time_elapsed    | 7545     |
# |    total_timesteps | 531360   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 560      |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | -0.0974  |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8860     |
# |    fps             | 70       |
# |    time_elapsed    | 7548     |
# |    total_timesteps | 531600   |
# | train/             |          |
# |    actor_loss      | -531     |
# |    critic_loss     | 407      |
# |    ent_coef        | 0.49     |
# |    ent_coef_loss   | -0.162   |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8864     |
# |    fps             | 70       |
# |    time_elapsed    | 7552     |
# |    total_timesteps | 531840   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 729      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.182    |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8868     |
# |    fps             | 70       |
# |    time_elapsed    | 7555     |
# |    total_timesteps | 532080   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 656      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 531979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8872     |
# |    fps             | 70       |
# |    time_elapsed    | 7559     |
# |    total_timesteps | 532320   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 676      |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | 0.0416   |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 532219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8876     |
# |    fps             | 70       |
# |    time_elapsed    | 7562     |
# |    total_timesteps | 532560   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 631      |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8880     |
# |    fps             | 70       |
# |    time_elapsed    | 7566     |
# |    total_timesteps | 532800   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 534      |
# |    ent_coef        | 0.481    |
# |    ent_coef_loss   | 0.0395   |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8884     |
# |    fps             | 70       |
# |    time_elapsed    | 7569     |
# |    total_timesteps | 533040   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 998      |
# |    ent_coef        | 0.483    |
# |    ent_coef_loss   | -0.0204  |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8888     |
# |    fps             | 70       |
# |    time_elapsed    | 7572     |
# |    total_timesteps | 533280   |
# | train/             |          |
# |    actor_loss      | -522     |
# |    critic_loss     | 416      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.108    |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 533179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8892     |
# |    fps             | 70       |
# |    time_elapsed    | 7576     |
# |    total_timesteps | 533520   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 357      |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | 0.247    |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 533419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8896     |
# |    fps             | 70       |
# |    time_elapsed    | 7579     |
# |    total_timesteps | 533760   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 651      |
# |    ent_coef        | 0.484    |
# |    ent_coef_loss   | 0.0118   |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8900     |
# |    fps             | 70       |
# |    time_elapsed    | 7583     |
# |    total_timesteps | 534000   |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 604      |
# |    ent_coef        | 0.49     |
# |    ent_coef_loss   | -0.0252  |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8904     |
# |    fps             | 70       |
# |    time_elapsed    | 7586     |
# |    total_timesteps | 534240   |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 1.06e+03 |
# |    ent_coef        | 0.488    |
# |    ent_coef_loss   | 0.0732   |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 534139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8908     |
# |    fps             | 70       |
# |    time_elapsed    | 7589     |
# |    total_timesteps | 534480   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 583      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8912     |
# |    fps             | 70       |
# |    time_elapsed    | 7593     |
# |    total_timesteps | 534720   |
# | train/             |          |
# |    actor_loss      | -521     |
# |    critic_loss     | 251      |
# |    ent_coef        | 0.493    |
# |    ent_coef_loss   | -0.0466  |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8916     |
# |    fps             | 70       |
# |    time_elapsed    | 7596     |
# |    total_timesteps | 534960   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 373      |
# |    ent_coef        | 0.495    |
# |    ent_coef_loss   | 0.229    |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 534859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8920     |
# |    fps             | 70       |
# |    time_elapsed    | 7600     |
# |    total_timesteps | 535200   |
# | train/             |          |
# |    actor_loss      | -514     |
# |    critic_loss     | 707      |
# |    ent_coef        | 0.495    |
# |    ent_coef_loss   | -0.0372  |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8924     |
# |    fps             | 70       |
# |    time_elapsed    | 7603     |
# |    total_timesteps | 535440   |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 835      |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | -0.0254  |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8928     |
# |    fps             | 70       |
# |    time_elapsed    | 7607     |
# |    total_timesteps | 535680   |
# | train/             |          |
# |    actor_loss      | -508     |
# |    critic_loss     | 1.36e+03 |
# |    ent_coef        | 0.49     |
# |    ent_coef_loss   | 0.0596   |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8932     |
# |    fps             | 70       |
# |    time_elapsed    | 7610     |
# |    total_timesteps | 535920   |
# | train/             |          |
# |    actor_loss      | -514     |
# |    critic_loss     | 786      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.0579  |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8936     |
# |    fps             | 70       |
# |    time_elapsed    | 7614     |
# |    total_timesteps | 536160   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 686      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | 0.188    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8940     |
# |    fps             | 70       |
# |    time_elapsed    | 7617     |
# |    total_timesteps | 536400   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 331      |
# |    ent_coef        | 0.49     |
# |    ent_coef_loss   | 0.14     |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8944     |
# |    fps             | 70       |
# |    time_elapsed    | 7620     |
# |    total_timesteps | 536640   |
# | train/             |          |
# |    actor_loss      | -517     |
# |    critic_loss     | 504      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8948     |
# |    fps             | 70       |
# |    time_elapsed    | 7624     |
# |    total_timesteps | 536880   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 749      |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | 0.0142   |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 536779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8952     |
# |    fps             | 70       |
# |    time_elapsed    | 7627     |
# |    total_timesteps | 537120   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 1.86e+03 |
# |    ent_coef        | 0.493    |
# |    ent_coef_loss   | -0.026   |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 537019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8956     |
# |    fps             | 70       |
# |    time_elapsed    | 7631     |
# |    total_timesteps | 537360   |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 911      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.0148   |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8960     |
# |    fps             | 70       |
# |    time_elapsed    | 7634     |
# |    total_timesteps | 537600   |
# | train/             |          |
# |    actor_loss      | -508     |
# |    critic_loss     | 910      |
# |    ent_coef        | 0.484    |
# |    ent_coef_loss   | -0.0936  |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8964     |
# |    fps             | 70       |
# |    time_elapsed    | 7637     |
# |    total_timesteps | 537840   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 882      |
# |    ent_coef        | 0.479    |
# |    ent_coef_loss   | -0.0794  |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8968     |
# |    fps             | 70       |
# |    time_elapsed    | 7641     |
# |    total_timesteps | 538080   |
# | train/             |          |
# |    actor_loss      | -519     |
# |    critic_loss     | 624      |
# |    ent_coef        | 0.481    |
# |    ent_coef_loss   | -0.0857  |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 537979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8972     |
# |    fps             | 70       |
# |    time_elapsed    | 7644     |
# |    total_timesteps | 538320   |
# | train/             |          |
# |    actor_loss      | -536     |
# |    critic_loss     | 751      |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | 0.135    |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 538219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8976     |
# |    fps             | 70       |
# |    time_elapsed    | 7648     |
# |    total_timesteps | 538560   |
# | train/             |          |
# |    actor_loss      | -528     |
# |    critic_loss     | 509      |
# |    ent_coef        | 0.483    |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8980     |
# |    fps             | 70       |
# |    time_elapsed    | 7651     |
# |    total_timesteps | 538800   |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 748      |
# |    ent_coef        | 0.49     |
# |    ent_coef_loss   | -0.0517  |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8984     |
# |    fps             | 70       |
# |    time_elapsed    | 7655     |
# |    total_timesteps | 539040   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 527      |
# |    ent_coef        | 0.496    |
# |    ent_coef_loss   | -0.0531  |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8988     |
# |    fps             | 70       |
# |    time_elapsed    | 7658     |
# |    total_timesteps | 539280   |
# | train/             |          |
# |    actor_loss      | -488     |
# |    critic_loss     | 1.21e+03 |
# |    ent_coef        | 0.496    |
# |    ent_coef_loss   | 0.226    |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8992     |
# |    fps             | 70       |
# |    time_elapsed    | 7661     |
# |    total_timesteps | 539520   |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 1.4e+03  |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.187   |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8996     |
# |    fps             | 70       |
# |    time_elapsed    | 7665     |
# |    total_timesteps | 539760   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 731      |
# |    ent_coef        | 0.478    |
# |    ent_coef_loss   | 0.197    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9000     |
# |    fps             | 70       |
# |    time_elapsed    | 7668     |
# |    total_timesteps | 540000   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 908      |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | -0.0321  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9004     |
# |    fps             | 70       |
# |    time_elapsed    | 7671     |
# |    total_timesteps | 540240   |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 752      |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | 0.142    |
# |    learning_rate   | 9.96e-05 |
# |    n_updates       | 540139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9008     |
# |    fps             | 70       |
# |    time_elapsed    | 7675     |
# |    total_timesteps | 540480   |
# | train/             |          |
# |    actor_loss      | -519     |
# |    critic_loss     | 817      |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.0265  |
# |    learning_rate   | 9.92e-05 |
# |    n_updates       | 540379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9012     |
# |    fps             | 70       |
# |    time_elapsed    | 7678     |
# |    total_timesteps | 540720   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 350      |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 9.88e-05 |
# |    n_updates       | 540619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9016     |
# |    fps             | 70       |
# |    time_elapsed    | 7682     |
# |    total_timesteps | 540960   |
# | train/             |          |
# |    actor_loss      | -517     |
# |    critic_loss     | 428      |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 9.84e-05 |
# |    n_updates       | 540859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 70       |
# |    time_elapsed    | 7685     |
# |    total_timesteps | 541200   |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 673      |
# |    ent_coef        | 0.513    |
# |    ent_coef_loss   | 0.117    |
# |    learning_rate   | 9.8e-05  |
# |    n_updates       | 541099   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 60        |
# |    ep_rew_mean     | 1.16e+03  |
# | time/              |           |
# |    episodes        | 9024      |
# |    fps             | 70        |
# |    time_elapsed    | 7688      |
# |    total_timesteps | 541440    |
# | train/             |           |
# |    actor_loss      | -522      |
# |    critic_loss     | 508       |
# |    ent_coef        | 0.514     |
# |    ent_coef_loss   | -0.000144 |
# |    learning_rate   | 9.76e-05  |
# |    n_updates       | 541339    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9028     |
# |    fps             | 70       |
# |    time_elapsed    | 7692     |
# |    total_timesteps | 541680   |
# | train/             |          |
# |    actor_loss      | -518     |
# |    critic_loss     | 355      |
# |    ent_coef        | 0.519    |
# |    ent_coef_loss   | -0.0634  |
# |    learning_rate   | 9.72e-05 |
# |    n_updates       | 541579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9032     |
# |    fps             | 70       |
# |    time_elapsed    | 7695     |
# |    total_timesteps | 541920   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 1.14e+03 |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | 0.296    |
# |    learning_rate   | 9.68e-05 |
# |    n_updates       | 541819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9036     |
# |    fps             | 70       |
# |    time_elapsed    | 7699     |
# |    total_timesteps | 542160   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 442      |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | -0.0594  |
# |    learning_rate   | 9.64e-05 |
# |    n_updates       | 542059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 70       |
# |    time_elapsed    | 7702     |
# |    total_timesteps | 542400   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 429      |
# |    ent_coef        | 0.521    |
# |    ent_coef_loss   | -0.289   |
# |    learning_rate   | 9.6e-05  |
# |    n_updates       | 542299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9044     |
# |    fps             | 70       |
# |    time_elapsed    | 7705     |
# |    total_timesteps | 542640   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 490      |
# |    ent_coef        | 0.516    |
# |    ent_coef_loss   | 0.0706   |
# |    learning_rate   | 9.56e-05 |
# |    n_updates       | 542539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9048     |
# |    fps             | 70       |
# |    time_elapsed    | 7709     |
# |    total_timesteps | 542880   |
# | train/             |          |
# |    actor_loss      | -482     |
# |    critic_loss     | 417      |
# |    ent_coef        | 0.521    |
# |    ent_coef_loss   | 0.0474   |
# |    learning_rate   | 9.52e-05 |
# |    n_updates       | 542779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9052     |
# |    fps             | 70       |
# |    time_elapsed    | 7712     |
# |    total_timesteps | 543120   |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 843      |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | 0.0443   |
# |    learning_rate   | 9.48e-05 |
# |    n_updates       | 543019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9056     |
# |    fps             | 70       |
# |    time_elapsed    | 7716     |
# |    total_timesteps | 543360   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 420      |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -0.0479  |
# |    learning_rate   | 9.44e-05 |
# |    n_updates       | 543259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9060     |
# |    fps             | 70       |
# |    time_elapsed    | 7719     |
# |    total_timesteps | 543600   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 1.34e+03 |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 9.4e-05  |
# |    n_updates       | 543499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9064     |
# |    fps             | 70       |
# |    time_elapsed    | 7723     |
# |    total_timesteps | 543840   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 582      |
# |    ent_coef        | 0.503    |
# |    ent_coef_loss   | 0.0285   |
# |    learning_rate   | 9.36e-05 |
# |    n_updates       | 543739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9068     |
# |    fps             | 70       |
# |    time_elapsed    | 7726     |
# |    total_timesteps | 544080   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 379      |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 9.32e-05 |
# |    n_updates       | 543979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9072     |
# |    fps             | 70       |
# |    time_elapsed    | 7729     |
# |    total_timesteps | 544320   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 374      |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 9.28e-05 |
# |    n_updates       | 544219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9076     |
# |    fps             | 70       |
# |    time_elapsed    | 7733     |
# |    total_timesteps | 544560   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 616      |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | -0.0956  |
# |    learning_rate   | 9.24e-05 |
# |    n_updates       | 544459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9080     |
# |    fps             | 70       |
# |    time_elapsed    | 7736     |
# |    total_timesteps | 544800   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 586      |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | 0.0868   |
# |    learning_rate   | 9.2e-05  |
# |    n_updates       | 544699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9084     |
# |    fps             | 70       |
# |    time_elapsed    | 7740     |
# |    total_timesteps | 545040   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 515      |
# |    ent_coef        | 0.506    |
# |    ent_coef_loss   | 0.0141   |
# |    learning_rate   | 9.16e-05 |
# |    n_updates       | 544939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9088     |
# |    fps             | 70       |
# |    time_elapsed    | 7743     |
# |    total_timesteps | 545280   |
# | train/             |          |
# |    actor_loss      | -537     |
# |    critic_loss     | 404      |
# |    ent_coef        | 0.504    |
# |    ent_coef_loss   | 0.0212   |
# |    learning_rate   | 9.12e-05 |
# |    n_updates       | 545179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9092     |
# |    fps             | 70       |
# |    time_elapsed    | 7746     |
# |    total_timesteps | 545520   |
# | train/             |          |
# |    actor_loss      | -533     |
# |    critic_loss     | 484      |
# |    ent_coef        | 0.504    |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 9.08e-05 |
# |    n_updates       | 545419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9096     |
# |    fps             | 70       |
# |    time_elapsed    | 7750     |
# |    total_timesteps | 545760   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 443      |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | -0.179   |
# |    learning_rate   | 9.04e-05 |
# |    n_updates       | 545659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9100     |
# |    fps             | 70       |
# |    time_elapsed    | 7753     |
# |    total_timesteps | 546000   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 997      |
# |    ent_coef        | 0.497    |
# |    ent_coef_loss   | -0.0348  |
# |    learning_rate   | 9e-05    |
# |    n_updates       | 545899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9104     |
# |    fps             | 70       |
# |    time_elapsed    | 7757     |
# |    total_timesteps | 546240   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 896      |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | 0.085    |
# |    learning_rate   | 8.96e-05 |
# |    n_updates       | 546139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9108     |
# |    fps             | 70       |
# |    time_elapsed    | 7760     |
# |    total_timesteps | 546480   |
# | train/             |          |
# |    actor_loss      | -492     |
# |    critic_loss     | 864      |
# |    ent_coef        | 0.497    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 8.92e-05 |
# |    n_updates       | 546379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9112     |
# |    fps             | 70       |
# |    time_elapsed    | 7764     |
# |    total_timesteps | 546720   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 489      |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | -0.0991  |
# |    learning_rate   | 8.88e-05 |
# |    n_updates       | 546619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9116     |
# |    fps             | 70       |
# |    time_elapsed    | 7767     |
# |    total_timesteps | 546960   |
# | train/             |          |
# |    actor_loss      | -528     |
# |    critic_loss     | 771      |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | 0.0569   |
# |    learning_rate   | 8.84e-05 |
# |    n_updates       | 546859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9120     |
# |    fps             | 70       |
# |    time_elapsed    | 7770     |
# |    total_timesteps | 547200   |
# | train/             |          |
# |    actor_loss      | -492     |
# |    critic_loss     | 761      |
# |    ent_coef        | 0.506    |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 8.8e-05  |
# |    n_updates       | 547099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9124     |
# |    fps             | 70       |
# |    time_elapsed    | 7774     |
# |    total_timesteps | 547440   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 1.46e+03 |
# |    ent_coef        | 0.503    |
# |    ent_coef_loss   | 0.0515   |
# |    learning_rate   | 8.76e-05 |
# |    n_updates       | 547339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9128     |
# |    fps             | 70       |
# |    time_elapsed    | 7777     |
# |    total_timesteps | 547680   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 381      |
# |    ent_coef        | 0.504    |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 8.72e-05 |
# |    n_updates       | 547579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9132     |
# |    fps             | 70       |
# |    time_elapsed    | 7781     |
# |    total_timesteps | 547920   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 964      |
# |    ent_coef        | 0.505    |
# |    ent_coef_loss   | 0.03     |
# |    learning_rate   | 8.68e-05 |
# |    n_updates       | 547819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9136     |
# |    fps             | 70       |
# |    time_elapsed    | 7784     |
# |    total_timesteps | 548160   |
# | train/             |          |
# |    actor_loss      | -517     |
# |    critic_loss     | 404      |
# |    ent_coef        | 0.504    |
# |    ent_coef_loss   | 0.023    |
# |    learning_rate   | 8.64e-05 |
# |    n_updates       | 548059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 9140     |
# |    fps             | 70       |
# |    time_elapsed    | 7787     |
# |    total_timesteps | 548400   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 510      |
# |    ent_coef        | 0.509    |
# |    ent_coef_loss   | 0.0791   |
# |    learning_rate   | 8.6e-05  |
# |    n_updates       | 548299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9144     |
# |    fps             | 70       |
# |    time_elapsed    | 7791     |
# |    total_timesteps | 548640   |
# | train/             |          |
# |    actor_loss      | -519     |
# |    critic_loss     | 1.57e+03 |
# |    ent_coef        | 0.517    |
# |    ent_coef_loss   | 0.23     |
# |    learning_rate   | 8.56e-05 |
# |    n_updates       | 548539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9148     |
# |    fps             | 70       |
# |    time_elapsed    | 7794     |
# |    total_timesteps | 548880   |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 617      |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | -0.0513  |
# |    learning_rate   | 8.52e-05 |
# |    n_updates       | 548779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 9152     |
# |    fps             | 70       |
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9896     |
# |    fps             | 70       |
# |    time_elapsed    | 8433     |
# |    total_timesteps | 593760   |
# | train/             |          |
# |    actor_loss      | -533     |
# |    critic_loss     | 529      |
# |    ent_coef        | 0.487    |
# |    ent_coef_loss   | 0.0272   |
# |    learning_rate   | 1.04e-05 |
# |    n_updates       | 593659   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 60        |
# |    ep_rew_mean     | 1.17e+03  |
# | time/              |           |
# |    episodes        | 9900      |
# |    fps             | 70        |
# |    time_elapsed    | 8437      |
# |    total_timesteps | 594000    |
# | train/             |           |
# |    actor_loss      | -503      |
# |    critic_loss     | 366       |
# |    ent_coef        | 0.487     |
# |    ent_coef_loss   | -0.000403 |
# |    learning_rate   | 1e-05     |
# |    n_updates       | 593899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9904     |
# |    fps             | 70       |
# |    time_elapsed    | 8440     |
# |    total_timesteps | 594240   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 556      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.0514  |
# |    learning_rate   | 9.6e-06  |
# |    n_updates       | 594139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9908     |
# |    fps             | 70       |
# |    time_elapsed    | 8444     |
# |    total_timesteps | 594480   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 724      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.0687   |
# |    learning_rate   | 9.2e-06  |
# |    n_updates       | 594379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9912     |
# |    fps             | 70       |
# |    time_elapsed    | 8447     |
# |    total_timesteps | 594720   |
# | train/             |          |
# |    actor_loss      | -532     |
# |    critic_loss     | 851      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.0359  |
# |    learning_rate   | 8.8e-06  |
# |    n_updates       | 594619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9916     |
# |    fps             | 70       |
# |    time_elapsed    | 8450     |
# |    total_timesteps | 594960   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 674      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 8.4e-06  |
# |    n_updates       | 594859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 70       |
# |    time_elapsed    | 8454     |
# |    total_timesteps | 595200   |
# | train/             |          |
# |    actor_loss      | -537     |
# |    critic_loss     | 453      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.00435 |
# |    learning_rate   | 8e-06    |
# |    n_updates       | 595099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9924     |
# |    fps             | 70       |
# |    time_elapsed    | 8457     |
# |    total_timesteps | 595440   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 665      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.183    |
# |    learning_rate   | 7.6e-06  |
# |    n_updates       | 595339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9928     |
# |    fps             | 70       |
# |    time_elapsed    | 8461     |
# |    total_timesteps | 595680   |
# | train/             |          |
# |    actor_loss      | -511     |
# |    critic_loss     | 731      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.216   |
# |    learning_rate   | 7.2e-06  |
# |    n_updates       | 595579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9932     |
# |    fps             | 70       |
# |    time_elapsed    | 8464     |
# |    total_timesteps | 595920   |
# | train/             |          |
# |    actor_loss      | -497     |
# |    critic_loss     | 939      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.112   |
# |    learning_rate   | 6.8e-06  |
# |    n_updates       | 595819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9936     |
# |    fps             | 70       |
# |    time_elapsed    | 8467     |
# |    total_timesteps | 596160   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 968      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.169    |
# |    learning_rate   | 6.4e-06  |
# |    n_updates       | 596059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 70       |
# |    time_elapsed    | 8471     |
# |    total_timesteps | 596400   |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 462      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.00122  |
# |    learning_rate   | 6e-06    |
# |    n_updates       | 596299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9944     |
# |    fps             | 70       |
# |    time_elapsed    | 8474     |
# |    total_timesteps | 596640   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 725      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | 0.0129   |
# |    learning_rate   | 5.6e-06  |
# |    n_updates       | 596539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9948     |
# |    fps             | 70       |
# |    time_elapsed    | 8478     |
# |    total_timesteps | 596880   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 521      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.192   |
# |    learning_rate   | 5.2e-06  |
# |    n_updates       | 596779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9952     |
# |    fps             | 70       |
# |    time_elapsed    | 8481     |
# |    total_timesteps | 597120   |
# | train/             |          |
# |    actor_loss      | -498     |
# |    critic_loss     | 715      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.144   |
# |    learning_rate   | 4.8e-06  |
# |    n_updates       | 597019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9956     |
# |    fps             | 70       |
# |    time_elapsed    | 8485     |
# |    total_timesteps | 597360   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 574      |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.0209  |
# |    learning_rate   | 4.4e-06  |
# |    n_updates       | 597259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 70       |
# |    time_elapsed    | 8488     |
# |    total_timesteps | 597600   |
# | train/             |          |
# |    actor_loss      | -528     |
# |    critic_loss     | 370      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.027    |
# |    learning_rate   | 4e-06    |
# |    n_updates       | 597499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9964     |
# |    fps             | 70       |
# |    time_elapsed    | 8491     |
# |    total_timesteps | 597840   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 745      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 3.6e-06  |
# |    n_updates       | 597739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9968     |
# |    fps             | 70       |
# |    time_elapsed    | 8495     |
# |    total_timesteps | 598080   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 376      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 3.2e-06  |
# |    n_updates       | 597979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 9972     |
# |    fps             | 70       |
# |    time_elapsed    | 8498     |
# |    total_timesteps | 598320   |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 808      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.14     |
# |    learning_rate   | 2.8e-06  |
# |    n_updates       | 598219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9976     |
# |    fps             | 70       |
# |    time_elapsed    | 8502     |
# |    total_timesteps | 598560   |
# | train/             |          |
# |    actor_loss      | -507     |
# |    critic_loss     | 334      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.00131 |
# |    learning_rate   | 2.4e-06  |
# |    n_updates       | 598459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 70       |
# |    time_elapsed    | 8505     |
# |    total_timesteps | 598800   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 392      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.0537  |
# |    learning_rate   | 2e-06    |
# |    n_updates       | 598699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9984     |
# |    fps             | 70       |
# |    time_elapsed    | 8509     |
# |    total_timesteps | 599040   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 364      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 1.6e-06  |
# |    n_updates       | 598939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9988     |
# |    fps             | 70       |
# |    time_elapsed    | 8512     |
# |    total_timesteps | 599280   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 355      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.0729  |
# |    learning_rate   | 1.2e-06  |
# |    n_updates       | 599179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9992     |
# |    fps             | 70       |
# |    time_elapsed    | 8515     |
# |    total_timesteps | 599520   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 359      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.297    |
# |    learning_rate   | 8.02e-07 |
# |    n_updates       | 599419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 9996     |
# |    fps             | 70       |
# |    time_elapsed    | 8519     |
# |    total_timesteps | 599760   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 695      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 4.02e-07 |
# |    n_updates       | 599659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 70       |
# |    time_elapsed    | 8522     |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | -531     |
# |    critic_loss     | 717      |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | 0.0278   |
# |    learning_rate   | 1.67e-09 |
# |    n_updates       | 599899   |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Green",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ")
# Out:
# Model name: SAC_Gausian, Steps: 600000, Mean: 1064.0488, IQR: 193.25, CVaR: -410.2631578947368

# %%
print(model.policy)
# Out:
# MultiInputPolicy(
#   (actor): Actor(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=52, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=4, bias=True)
#     (log_std): Linear(in_features=256, out_features=4, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  1289
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1      -2             0                  0   891.112335   -2
# 1          2       0             0                  0   976.193021    0
# 2          3       1             0                  0   410.519116    1
# 3          4       0             0                  0  1186.811062    0
# 4          5       1             0                  0   669.229242    1
# 5          6       0             0                  0  1481.768286    0
# 6          7       2             0                  0  1171.644401    2
# 7          8       3             0                  0  1014.880875    3
# 8          9       1             0                  0  2123.603741    1
# 9         10       4             0                  0  1456.014045    4
# 10        11       6             0                  0  1132.955050    6
# 11        12       8             0                  0  1158.282854    8
# 12        13      11             0                  0   538.917831   11
# 13        14      11             0                  0   883.818840   11
# 14        15      13             0                  0   719.352814   13
# 15        16      16             0                  0   304.427058   16
# 16        17      18             0                  0    30.783339   18
# 17        18      19             0                  0   371.797592   19
# 18        19      21             0                  0   326.778517   21
# 19        20      21             0                  0   773.090533   21
# 20        21      24             0                  0   472.369256   24
# 21        22      24             0                  0   906.209699   24
# 22        23      23             0                  0  1539.485601   23
# 23        24      23             0                  0  1630.939515   23
# 24        25      26             0                  0   488.134121   26
# 25        26      25             0                  0   636.697083   25
# 26        27      25             0                  0  1035.237499   25
# 27        28      27             0                  0    60.568531   27
# 28        29      27             0                  0    96.645870   27
# 29        30      26             0                  0   623.719433   26
# 30        31      26             0                  0   714.308544   26
# 31        32      25             0                  0  1014.648442   25
# 32        33      27             0                  0   339.354985   27
# 33        34      27             0                  0   557.051026   27
# 34        35      27             0                  0   769.892321   27
# 35        36      29             0                  0   398.700636   29
# 36        37      28             0                  0  1450.030363   28
# 37        38      27             0                  0  2062.098074   27
# 38        39      27             0                  0  2403.048109   27
# 39        40      29             0                  0  1750.777125   29
# 40        41      28             0                  0  2193.269961   28
# 41        42      30             0                  0  1517.901785   30
# 42        43      33             0                  0   508.709837   33
# 43        44      33             0                  0   620.177413   33
# 44        45      33             0                  0   612.963797   33
# 45        46      32             0                  0   614.082118   32
# 46        47      32             0                  0   570.532855   32
# 47        48      31             0                  0   514.246037   31
# 48        49      31             0                  0   817.872342   31
# 49        50      30             0                  0   999.074440   30
# 50        51      30             0                  0  1467.208946   30
# 51        52      29             0                  0  2244.957693   29
# 52        53      31             0                  0  1945.638525   31
# 53        54      33             0                  0  1456.334768   33
# 54        55      29             0                  0  3422.776571   29
# 55        56      32             0                  0  2919.829256   32
# 56        57      30             0                  0  3986.551668   30
# 57        58      29             0                  0  5386.357118   29
# 58        59      28             0                  0  6269.129778   28
# 59        60      29             0                  0  6145.569429   29
#
#        income  funding_cost  total_funding  total_mortgages
# 0    0.000000     -2.000950           -889                0
# 1    3.734338     -4.231649          -1972             1000
# 2    6.334325     -5.080617          -2403             2000
# 3    6.334325     -6.594545          -3177             2000
# 4    9.423998     -7.524262          -3656             3000
# 5    9.423998     -8.936922          -4467             3000
# 6   12.394600    -10.025424          -5155             4000
# 7   15.320408    -11.499348          -5996             5000
# 8   15.320408    -13.438434          -7102             5000
# 9   18.790062    -13.904676          -7433             6000
# 10  21.723744    -14.734529          -8107             7000
# 11  24.619097    -16.122358          -9130             8000
# 12  27.523853    -15.940274          -9508             9000
# 13  27.523853    -16.126895          -9851             9000
# 14  30.549906    -16.825281         -10685            10000
# 15  33.515983    -16.948645         -11269            11000
# 16  36.549714    -17.865086         -11993            12000
# 17  36.549714    -17.319081         -12332            12000
# 18  39.701280    -18.163547         -13285            13000
# 19  39.701280    -17.957158         -13729            13000
# 20  42.607569    -18.152516         -14427            14000
# 21  42.607569    -17.945461         -14859            14000
# 22  41.863205    -18.518948         -15490            14000
# 23  41.863205    -18.496291         -15579            14000
# 24  44.402570    -18.209439         -15434            15000
# 25  44.402570    -18.404868         -15581            15000
# 26  44.402570    -18.833705         -15978            15000
# 27  46.837243    -19.096106         -16001            16000
# 28  46.837243    -19.772852         -16035            16000
# 29  46.837243    -20.334638         -16560            16000
# 30  46.837243    -20.561790         -16648            16000
# 31  46.446882    -20.941608         -16946            16000
# 32  49.217325    -21.473651         -17268            17000
# 33  49.217325    -21.843252         -17483            17000
# 34  49.217325    -22.178507         -17693            17000
# 35  52.303266    -22.956304         -18320            18000
# 36  52.303266    -23.970261         -19370            18000
# 37  52.303266    -24.716133         -19980            18000
# 38  52.303266    -25.259887         -20319            18000
# 39  54.891543    -25.842168         -20665            19000
# 40  54.891543    -26.369843         -21105            19000
# 41  57.566305    -26.572739         -21428            20000
# 42  59.960559    -26.545655         -21416            21000
# 43  59.960559    -26.827715         -21526            21000
# 44  60.344242    -27.032538         -21516            21000
# 45  60.344242    -27.523684         -21515            21000
# 46  60.344242    -27.891024         -21469            21000
# 47  60.344242    -28.603373         -21411            21000
# 48  60.344242    -29.032969         -21713            21000
# 49  60.344242    -29.437208         -21892            21000
# 50  60.344242    -29.805622         -22358            21000
# 51  60.344242    -30.650825         -23134            21000
# 52  63.033483    -31.239324         -23832            22000
# 53  65.673255    -31.869371         -24341            23000
# 54  62.998493    -33.068910         -25306            22000
# 55  65.971348    -33.759508         -25801            23000
# 56  65.971348    -35.062578         -26866            23000
# 57  65.971348    -36.410637         -28263            23000
# 58  65.971348    -37.675251         -29145            23000
# 59  68.501881    -38.830436         -30019            24000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=1175.68 Expected Shortfall=809.80 Interquartile Range=147.00

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")

# %%
from google.colab import runtime
runtime.unassign()
