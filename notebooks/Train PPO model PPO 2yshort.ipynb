# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20PPO%20model%20PPO%202yshort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train PPO RL model
#
# The Proximal Policy Optimization algorithm combines ideas from A2C (having multiple workers) and TRPO (it uses a trust region to improve the actor).
#
# The main idea is that after an update, the new policy should be not too far from the old policy. For that, ppo uses clipping to avoid too large update.
#
# Original paper: https://arxiv.org/abs/1707.06347

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Nov 15 15:24:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 831, done.
# remote: Counting objects: 100% (831/831), done.
# remote: Compressing objects: 100% (483/483), done.
# remote: Total 831 (delta 436), reused 696 (delta 340), pack-reused 0
# Receiving objects: 100% (831/831), 21.29 MiB | 13.47 MiB/s, done.
# Resolving deltas: 100% (436/436), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.1.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import PPO

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %%
# Change Path settings to output results to gdrive

MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/models')
DATA_MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/data/model')
FIGURES_PATH = Path('/content/gdrive/MyDrive/rl-alm/reports/figures')
NOTEBOOK_PATH = Path('/content/gdrive/MyDrive/rl-alm/notebooks')

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-11-15 15:25:40.082 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-15 15:25:42.818 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# steps: 60, score: -19215

# %% [markdown]
# Define the model. For the initial model we use the PPO model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'PPO_2yshort'
ent_coef= 0.0005
gamma = 0.99

model = PPO(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        gamma = gamma,
        ent_coef = ent_coef,
        use_sde = False, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# 2023-11-15 15:25:50.802 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-15 15:25:52.751 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 600_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    loss                 | 1.06e+04    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.0028     |
# |    std                  | 0.966       |
# |    value_loss           | 1.9e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 67           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0057690283 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.000775     |
# |    loss                 | 1.13e+04     |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00418     |
# |    std                  | 0.956        |
# |    value_loss           | 2.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 68           |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0028724724 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.000771     |
# |    loss                 | 7.77e+03     |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 0.959        |
# |    value_loss           | 2.2e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 999          |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 69           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 141312       |
# | train/                  |              |
# |    approx_kl            | 0.0044272924 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.000768     |
# |    loss                 | 7.47e+03     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00345     |
# |    std                  | 0.958        |
# |    value_loss           | 1.59e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 70           |
# |    time_elapsed         | 444          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0012878631 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.5         |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.000764     |
# |    loss                 | 6.93e+03     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.956        |
# |    value_loss           | 1.03e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 71           |
# |    time_elapsed         | 450          |
# |    total_timesteps      | 145408       |
# | train/                  |              |
# |    approx_kl            | 0.0028110729 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.49        |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.000761     |
# |    loss                 | 8.8e+03      |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.0013      |
# |    std                  | 0.957        |
# |    value_loss           | 1.82e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 72           |
# |    time_elapsed         | 456          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0021521687 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 0.000758     |
# |    loss                 | 7.81e+03     |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.961        |
# |    value_loss           | 2.62e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 73           |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0071160286 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.51        |
# |    explained_variance   | 0.581        |
# |    learning_rate        | 0.000754     |
# |    loss                 | 1.67e+04     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00546     |
# |    std                  | 0.957        |
# |    value_loss           | 2.82e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 74          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.004490995 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.000751    |
# |    loss                 | 1.08e+04    |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00239    |
# |    std                  | 0.953       |
# |    value_loss           | 2.04e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 75           |
# |    time_elapsed         | 475          |
# |    total_timesteps      | 153600       |
# | train/                  |              |
# |    approx_kl            | 0.0040092412 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.47        |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.000747     |
# |    loss                 | 9.03e+03     |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00224     |
# |    std                  | 0.948        |
# |    value_loss           | 2.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 76           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0014909082 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.45        |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.000744     |
# |    loss                 | 1.07e+04     |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.942        |
# |    value_loss           | 1.87e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 77           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 157696       |
# | train/                  |              |
# |    approx_kl            | 0.0014749634 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.42        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.000741     |
# |    loss                 | 1.12e+04     |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.000984    |
# |    std                  | 0.937        |
# |    value_loss           | 2.33e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 78           |
# |    time_elapsed         | 493          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0037030843 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.000737     |
# |    loss                 | 6.17e+03     |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.936        |
# |    value_loss           | 1.68e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 79           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0042553446 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.42        |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.000734     |
# |    loss                 | 7.78e+03     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.938        |
# |    value_loss           | 2.2e+04      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 323        |
# |    iterations           | 80         |
# |    time_elapsed         | 505        |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.00445789 |
# |    clip_fraction        | 0.00996    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.42      |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.00073    |
# |    loss                 | 6.55e+03   |
# |    n_updates            | 790        |
# |    policy_gradient_loss | -0.00329   |
# |    std                  | 0.94       |
# |    value_loss           | 1.98e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 81           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0019328472 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.63         |
# |    learning_rate        | 0.000727     |
# |    loss                 | 8.03e+03     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00244     |
# |    std                  | 0.928        |
# |    value_loss           | 1.82e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 82           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0046408325 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.000724     |
# |    loss                 | 1.13e+04     |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 0.926        |
# |    value_loss           | 2.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 83           |
# |    time_elapsed         | 524          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0044029793 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.00072      |
# |    loss                 | 6.38e+03     |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.925        |
# |    value_loss           | 1.82e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.04e+03    |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 84          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.003679304 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.000717    |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.928       |
# |    value_loss           | 2.01e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 85          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.004972602 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.000713    |
# |    loss                 | 1.27e+04    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00356    |
# |    std                  | 0.934       |
# |    value_loss           | 1.74e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 86           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0017377052 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.00071      |
# |    loss                 | 2.25e+04     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.931        |
# |    value_loss           | 3.31e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 87           |
# |    time_elapsed         | 549          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0021596581 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.000706     |
# |    loss                 | 1.1e+04      |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.936        |
# |    value_loss           | 2.12e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.07e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 88          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.003239567 |
# |    clip_fraction        | 0.00522     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.000703    |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 0.934       |
# |    value_loss           | 2.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 89          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.002796031 |
# |    clip_fraction        | 0.00908     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0007      |
# |    loss                 | 6.64e+03    |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.94        |
# |    value_loss           | 1.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 90          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004716384 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.000696    |
# |    loss                 | 8.76e+03    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00414    |
# |    std                  | 0.942       |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 91          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.004130209 |
# |    clip_fraction        | 0.00791     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.000693    |
# |    loss                 | 9.77e+03    |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.933       |
# |    value_loss           | 1.98e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 92           |
# |    time_elapsed         | 581          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0050086454 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.593        |
# |    learning_rate        | 0.000689     |
# |    loss                 | 7.54e+03     |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00312     |
# |    std                  | 0.928        |
# |    value_loss           | 2.03e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 93           |
# |    time_elapsed         | 587          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0053345547 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.37        |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.000686     |
# |    loss                 | 7.95e+03     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00344     |
# |    std                  | 0.926        |
# |    value_loss           | 1.77e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 94           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0037139198 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.000683     |
# |    loss                 | 6.42e+03     |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.931        |
# |    value_loss           | 2.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 95           |
# |    time_elapsed         | 600          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0053015733 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.4         |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.000679     |
# |    loss                 | 1.17e+04     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00462     |
# |    std                  | 0.933        |
# |    value_loss           | 1.63e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.04e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 96           |
# |    time_elapsed         | 606          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0023325714 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.000676     |
# |    loss                 | 1.29e+04     |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.934        |
# |    value_loss           | 1.81e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 97           |
# |    time_elapsed         | 612          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0038541423 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.000672     |
# |    loss                 | 8.73e+03     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00361     |
# |    std                  | 0.932        |
# |    value_loss           | 1.48e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 98           |
# |    time_elapsed         | 618          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0046589836 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.39        |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.000669     |
# |    loss                 | 5.63e+03     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.933        |
# |    value_loss           | 1.57e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 1.05e+03   |
# | time/                   |            |
# |    fps                  | 324        |
# |    iterations           | 99         |
# |    time_elapsed         | 625        |
# |    total_timesteps      | 202752     |
# | train/                  |            |
# |    approx_kl            | 0.00464614 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.38      |
# |    explained_variance   | 0.671      |
# |    learning_rate        | 0.000665   |
# |    loss                 | 1.06e+04   |
# |    n_updates            | 980        |
# |    policy_gradient_loss | -0.00292   |
# |    std                  | 0.926      |
# |    value_loss           | 1.43e+04   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 1.02e+03  |
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 100       |
# |    time_elapsed         | 631       |
# |    total_timesteps      | 204800    |
# | train/                  |           |
# |    approx_kl            | 0.0066293 |
# |    clip_fraction        | 0.0218    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.35     |
# |    explained_variance   | 0.615     |
# |    learning_rate        | 0.000662  |
# |    loss                 | 7.29e+03  |
# |    n_updates            | 990       |
# |    policy_gradient_loss | -0.00307  |
# |    std                  | 0.92      |
# |    value_loss           | 1.75e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.02e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 101         |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 206848      |
# | train/                  |             |
# |    approx_kl            | 0.004517846 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.33       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.000659    |
# |    loss                 | 1.19e+04    |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00198    |
# |    std                  | 0.919       |
# |    value_loss           | 1.83e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.03e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 102          |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0007454909 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.32        |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.000655     |
# |    loss                 | 8.45e+03     |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.000524    |
# |    std                  | 0.914        |
# |    value_loss           | 1.8e+04      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 103         |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 210944      |
# | train/                  |             |
# |    approx_kl            | 0.002502435 |
# |    clip_fraction        | 0.00405     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.000652    |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.919       |
# |    value_loss           | 1.66e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 104          |
# |    time_elapsed         | 656          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0021613622 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.32        |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 0.000648     |
# |    loss                 | 1.24e+04     |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.000995    |
# |    std                  | 0.911        |
# |    value_loss           | 1.98e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 105          |
# |    time_elapsed         | 663          |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0030780805 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.28        |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.000645     |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 0.905        |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.03e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 106         |
# |    time_elapsed         | 669         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.000858427 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.28       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.000642    |
# |    loss                 | 5.37e+04    |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00113    |
# |    std                  | 0.909       |
# |    value_loss           | 1.2e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.02e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 107          |
# |    time_elapsed         | 675          |
# |    total_timesteps      | 219136       |
# | train/                  |              |
# |    approx_kl            | 0.0060617854 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.28        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.000638     |
# |    loss                 | 8.42e+03     |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00431     |
# |    std                  | 0.902        |
# |    value_loss           | 1.62e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 108         |
# |    time_elapsed         | 681         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.002240336 |
# |    clip_fraction        | 0.00215     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.23       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.000635    |
# |    loss                 | 9.2e+03     |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.893       |
# |    value_loss           | 1.85e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 109         |
# |    time_elapsed         | 688         |
# |    total_timesteps      | 223232      |
# | train/                  |             |
# |    approx_kl            | 0.003293392 |
# |    clip_fraction        | 0.00332     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.21       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.000631    |
# |    loss                 | 7.4e+03     |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.00194    |
# |    std                  | 0.893       |
# |    value_loss           | 1.85e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.1e+03      |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 110          |
# |    time_elapsed         | 694          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0011284543 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.000628     |
# |    loss                 | 1.12e+04     |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.000815    |
# |    std                  | 0.896        |
# |    value_loss           | 1.82e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.1e+03      |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 111          |
# |    time_elapsed         | 700          |
# |    total_timesteps      | 227328       |
# | train/                  |              |
# |    approx_kl            | 0.0017329602 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.000625     |
# |    loss                 | 9.85e+03     |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.895        |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 112          |
# |    time_elapsed         | 707          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0029294272 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.23        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.000621     |
# |    loss                 | 9.23e+03     |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.898        |
# |    value_loss           | 1.72e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.06e+03    |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 113         |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.004479523 |
# |    clip_fraction        | 0.00947     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.000618    |
# |    loss                 | 3.08e+03    |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.903       |
# |    value_loss           | 1.64e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 114          |
# |    time_elapsed         | 719          |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0012979086 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.000614     |
# |    loss                 | 1.53e+04     |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.902        |
# |    value_loss           | 2.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.06e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 115          |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0034519802 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.26        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.000611     |
# |    loss                 | 6.09e+03     |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.903        |
# |    value_loss           | 1.52e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 116          |
# |    time_elapsed         | 732          |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0027132614 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.25        |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.000607     |
# |    loss                 | 6.32e+03     |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.898        |
# |    value_loss           | 1.9e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.07e+03     |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 117          |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 239616       |
# ...
# |    loss                 | 7.32e+03     |
# |    n_updates            | 2760         |
# |    policy_gradient_loss | -0.000135    |
# |    std                  | 0.885        |
# |    value_loss           | 1.83e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.05e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 278           |
# |    time_elapsed         | 1758          |
# |    total_timesteps      | 569344        |
# | train/                  |               |
# |    approx_kl            | 0.00023445813 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.16         |
# |    explained_variance   | 0.694         |
# |    learning_rate        | 5.45e-05      |
# |    loss                 | 7.52e+03      |
# |    n_updates            | 2770          |
# |    policy_gradient_loss | -0.00084      |
# |    std                  | 0.885         |
# |    value_loss           | 1.42e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.05e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 279          |
# |    time_elapsed         | 1765         |
# |    total_timesteps      | 571392       |
# | train/                  |              |
# |    approx_kl            | 9.966083e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 5.11e-05     |
# |    loss                 | 6.12e+03     |
# |    n_updates            | 2780         |
# |    policy_gradient_loss | -0.000376    |
# |    std                  | 0.885        |
# |    value_loss           | 1.38e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.05e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 280           |
# |    time_elapsed         | 1771          |
# |    total_timesteps      | 573440        |
# | train/                  |               |
# |    approx_kl            | 2.0469364e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.662         |
# |    learning_rate        | 4.77e-05      |
# |    loss                 | 4.39e+03      |
# |    n_updates            | 2790          |
# |    policy_gradient_loss | -0.000105     |
# |    std                  | 0.885         |
# |    value_loss           | 1.45e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.09e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 281           |
# |    time_elapsed         | 1777          |
# |    total_timesteps      | 575488        |
# | train/                  |               |
# |    approx_kl            | 2.6794267e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.727         |
# |    learning_rate        | 4.43e-05      |
# |    loss                 | 5.2e+03       |
# |    n_updates            | 2800          |
# |    policy_gradient_loss | -7.28e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.33e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 282          |
# |    time_elapsed         | 1784         |
# |    total_timesteps      | 577536       |
# | train/                  |              |
# |    approx_kl            | 4.974063e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.15        |
# |    explained_variance   | 0.722        |
# |    learning_rate        | 4.09e-05     |
# |    loss                 | 6.04e+03     |
# |    n_updates            | 2810         |
# |    policy_gradient_loss | -0.000316    |
# |    std                  | 0.885        |
# |    value_loss           | 1.31e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.09e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 283           |
# |    time_elapsed         | 1790          |
# |    total_timesteps      | 579584        |
# | train/                  |               |
# |    approx_kl            | 2.5385438e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.704         |
# |    learning_rate        | 3.74e-05      |
# |    loss                 | 6.11e+03      |
# |    n_updates            | 2820          |
# |    policy_gradient_loss | -0.000199     |
# |    std                  | 0.884         |
# |    value_loss           | 1.41e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.08e+03    |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 284         |
# |    time_elapsed         | 1796        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 2.86914e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.15       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 3.4e-05     |
# |    loss                 | 5e+03       |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | -0.000232   |
# |    std                  | 0.885       |
# |    value_loss           | 1.36e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 1.1e+03    |
# | time/                   |            |
# |    fps                  | 323        |
# |    iterations           | 285        |
# |    time_elapsed         | 1803       |
# |    total_timesteps      | 583680     |
# | train/                  |            |
# |    approx_kl            | 1.5831e-05 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.15      |
# |    explained_variance   | 0.71       |
# |    learning_rate        | 3.06e-05   |
# |    loss                 | 7.55e+03   |
# |    n_updates            | 2840       |
# |    policy_gradient_loss | -0.000145  |
# |    std                  | 0.885      |
# |    value_loss           | 1.41e+04   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.1e+03       |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 286           |
# |    time_elapsed         | 1809          |
# |    total_timesteps      | 585728        |
# | train/                  |               |
# |    approx_kl            | 2.2616412e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.16         |
# |    explained_variance   | 0.707         |
# |    learning_rate        | 2.72e-05      |
# |    loss                 | 7.94e+03      |
# |    n_updates            | 2850          |
# |    policy_gradient_loss | -6.08e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.49e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.1e+03       |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 287           |
# |    time_elapsed         | 1815          |
# |    total_timesteps      | 587776        |
# | train/                  |               |
# |    approx_kl            | 2.8433016e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.76          |
# |    learning_rate        | 2.38e-05      |
# |    loss                 | 5.96e+03      |
# |    n_updates            | 2860          |
# |    policy_gradient_loss | -0.000218     |
# |    std                  | 0.885         |
# |    value_loss           | 1.12e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.09e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 288           |
# |    time_elapsed         | 1822          |
# |    total_timesteps      | 589824        |
# | train/                  |               |
# |    approx_kl            | 1.2729637e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.677         |
# |    learning_rate        | 2.04e-05      |
# |    loss                 | 8.85e+03      |
# |    n_updates            | 2870          |
# |    policy_gradient_loss | -0.000113     |
# |    std                  | 0.885         |
# |    value_loss           | 1.47e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.1e+03       |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 289           |
# |    time_elapsed         | 1828          |
# |    total_timesteps      | 591872        |
# | train/                  |               |
# |    approx_kl            | 1.0557997e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.695         |
# |    learning_rate        | 1.7e-05       |
# |    loss                 | 8e+03         |
# |    n_updates            | 2880          |
# |    policy_gradient_loss | -1.88e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.51e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.09e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 290           |
# |    time_elapsed         | 1834          |
# |    total_timesteps      | 593920        |
# | train/                  |               |
# |    approx_kl            | 1.1900847e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.746         |
# |    learning_rate        | 1.35e-05      |
# |    loss                 | 5.19e+03      |
# |    n_updates            | 2890          |
# |    policy_gradient_loss | -2.51e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.23e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.03e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 291           |
# |    time_elapsed         | 1841          |
# |    total_timesteps      | 595968        |
# | train/                  |               |
# |    approx_kl            | 1.6174163e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.714         |
# |    learning_rate        | 1.01e-05      |
# |    loss                 | 5.14e+03      |
# |    n_updates            | 2900          |
# |    policy_gradient_loss | -4.79e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.34e+04      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 60             |
# |    ep_rew_mean          | 1.02e+03       |
# | time/                   |                |
# |    fps                  | 323            |
# |    iterations           | 292            |
# |    time_elapsed         | 1847           |
# |    total_timesteps      | 598016         |
# | train/                  |                |
# |    approx_kl            | 1.13708666e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.15          |
# |    explained_variance   | 0.224          |
# |    learning_rate        | 6.72e-06       |
# |    loss                 | 5.73e+04       |
# |    n_updates            | 2910           |
# |    policy_gradient_loss | -1.1e-05       |
# |    std                  | 0.885          |
# |    value_loss           | 1.44e+05       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 1.04e+03      |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 293           |
# |    time_elapsed         | 1853          |
# |    total_timesteps      | 600064        |
# | train/                  |               |
# |    approx_kl            | 1.8510036e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.15         |
# |    explained_variance   | 0.756         |
# |    learning_rate        | 3.31e-06      |
# |    loss                 | 4.64e+03      |
# |    n_updates            | 2920          |
# |    policy_gradient_loss | -1.62e-05     |
# |    std                  | 0.885         |
# |    value_loss           | 1.17e+04      |
# -------------------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Blue",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ",
                       name = f"{model_name}_{steps}_rewards",
                       figurepath = FIGURES_PATH )
# Out:
# Model name: PPO_2yshort, Steps: 600000, Mean: 1041.7537246275372, IQR: 261.0, CVaR: -3265.3473684210526

# %% [markdown]
# Showing the results of the trained model

# %%
print(model.policy)
# Out:
# MultiInputActorCriticPolicy(
#   (features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (liquidity): Flatten(start_dim=1, end_dim=-1)
#       (cashflows): Flatten(start_dim=1, end_dim=-1)
#       (swap_rates): Flatten(start_dim=1, end_dim=-1)
#       (bank_rates): Flatten(start_dim=1, end_dim=-1)
#       (features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (pi_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (liquidity): Flatten(start_dim=1, end_dim=-1)
#       (cashflows): Flatten(start_dim=1, end_dim=-1)
#       (swap_rates): Flatten(start_dim=1, end_dim=-1)
#       (bank_rates): Flatten(start_dim=1, end_dim=-1)
#       (features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (vf_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (liquidity): Flatten(start_dim=1, end_dim=-1)
#       (cashflows): Flatten(start_dim=1, end_dim=-1)
#       (swap_rates): Flatten(start_dim=1, end_dim=-1)
#       (bank_rates): Flatten(start_dim=1, end_dim=-1)
#       (features): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=52, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=52, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=4, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  914
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1       0             0                  0    82.035362    0
# 1          2       0             0                  0   319.716148    0
# 2          3       0             0                  0   848.374901    0
# 3          4       1             0                  0    98.376030    1
# 4          5       1             0                  0    98.376030    1
# 5          6       1             0                  0   555.077745    1
# 6          7       1             0                  0  2745.486986    1
# 7          8       2             0                  0  2928.849405    2
# 8          9       1             0                  0  3954.067060    1
# 9         10       3             0                  0  2954.067060    3
# 10        11       3             0                  0  4172.612516    3
# 11        12       2             0                  0  5755.410307    2
# 12        13       4             0                  0  4755.410307    4
# 13        14       5             0                  0  4343.725737    5
# 14        15       7             0                  0  3800.657103    7
# 15        16       7             0                  0  3386.657103    7
# 16        17       8             0                  0  2995.450865    8
# 17        18      10             0                  0  2306.101683   10
# 18        19      12             0                  0  2217.043043   12
# 19        20      13             0                  0  1140.367609   13
# 20        21      15             0                  0    81.367609   15
# 21        22      15             0                  0   249.836847   15
# 22        23      15             0                  0   249.836847   15
# 23        24      14             0                  0  1176.361826   14
# 24        25      16             0                  0   337.529062   16
# 25        26      15             0                  0   934.723825   15
# 26        27      15             0                  0   934.723825   15
# 27        28      18             0                  0   699.062387   18
# 28        29      17             0                  0   446.351603   17
# 29        30      17             0                  0   446.351603   17
# 30        31      16             0                  0   647.594072   16
# 31        32      16             0                  0   585.594072   16
# 32        33      16             0                  0   585.594072   16
# 33        34      16             0                  0  1059.676226   16
# 34        35      15             0                  0  2085.890932   15
# 35        36      17             0                  0  2845.241335   17
# 36        37      19             0                  0  1466.579622   19
# 37        38      20             0                  0  1627.643236   20
# 38        39      22             0                  0  1090.352190   22
# 39        40      24             0                  0   576.246874   24
# 40        41      24             0                  0    51.041475   24
# 41        42      23             0                  0   185.054079   23
# 42        43      23             0                  0   919.772158   23
# 43        44      22             0                  0  1683.467653   22
# 44        45      23             0                  0  1683.467653   23
# 45        46      22             0                  0  2683.467653   22
# 46        47      24             0                  0  1424.337450   24
# 47        48      24             0                  0  1553.443727   24
# 48        49      25             0                  0   294.709757   25
# 49        50      25             0                  0    86.711771   25
# 50        51      25             0                  0   -74.288229   25
# 51        52      25             0                  0  -265.627691   25
# 52        53      25             0                  0   310.915033   25
# 53        54      25             0                  0   399.355806   25
# 54        55      25             0                  0   399.355806   25
# 55        56      25             0                  0   537.696398   25
# 56        57      26             0                  0   636.773882   26
# 57        58      28             0                  0   184.252138   28
# 58        59      28             0                  0   184.252138   28
# 59        60      28             0                  0   184.252138   28
#
#        income  funding_cost  total_funding  total_mortgages
# 0    0.000000     -0.004965            -82                0
# 1    0.000000     -0.043141           -319                0
# 2    0.000000      0.178084           -847                0
# 3    1.308796      0.135354          -1097             1000
# 4    1.308796      0.135354          -1097             1000
# 5    1.308796      0.072574          -1552             1000
# 6    1.308796      0.056791          -3741             1000
# 7    2.730898     -0.297450          -4922             2000
# 8    2.730898     -0.921818          -5947             2000
# 9    4.429346     -0.921818          -5947             3000
# 10   4.429346     -1.195945          -7165             3000
# 11   4.429346     -1.510376          -8747             3000
# 12   5.798641     -1.510376          -8747             4000
# 13   7.624534     -1.856422          -9335             5000
# 14   9.354833     -1.887969          -9791             6000
# 15   9.354833     -2.103679          -9377             6000
# 16  10.778476     -1.859139          -9985             7000
# 17  12.733636     -2.085029         -10295             8000
# 18  14.691281     -2.086514         -11204             9000
# 19  16.600222     -2.983504         -11126            10000
# 20  18.368403     -3.010060         -11067            11000
# 21  18.368403     -3.136791         -11235            11000
# 22  18.368403     -3.136791         -11235            11000
# 23  18.368403     -4.032859         -12160            11000
# 24  20.400806     -4.117507         -12321            12000
# 25  20.400806     -4.906178         -12918            12000
# 26  20.400806     -4.906178         -12918            12000
# 27  22.760442     -4.731712         -13682            13000
# 28  22.760442     -5.444812         -13429            13000
# 29  22.760442     -5.444812         -13429            13000
# 30  22.760442     -6.386258         -13629            13000
# 31  22.760442     -6.410683         -13567            13000
# 32  22.760442     -6.410683         -13567            13000
# 33  22.760442     -6.269093         -14041            13000
# 34  22.760442     -7.522981         -15066            13000
# 35  25.198379     -7.850658         -16824            14000
# 36  27.716218     -8.493057         -16445            15000
# 37  29.910502     -9.725959         -17606            16000
# 38  32.461945     -9.769314         -18068            17000
# 39  34.880169    -10.354352         -18553            18000
# 40  34.880169    -10.818795         -18027            18000
# 41  34.880169    -11.005471         -18161            18000
# 42  34.880169    -11.616600         -18895            18000
# 43  34.880169    -12.641357         -19658            18000
# 44  36.666734    -13.470073         -20658            19000
# 45  36.666734    -14.447720         -21658            19000
# 46  39.392062    -14.917756         -21398            20000
# 47  39.392062    -15.136664         -21527            20000
# 48  41.314561    -16.206504         -21267            21000
# 49  43.306306    -17.502958         -22058            22000
# 50  43.306306    -17.544471         -21897            22000
# 51  43.306306    -17.891138         -21705            22000
# 52  45.868048    -19.991321         -23281            23000
# 53  45.868048    -20.111700         -23369            23000
# 54  45.868048    -20.111700         -23369            23000
# 55  45.868048    -20.264392         -23507            23000
# 56  48.019614    -21.896875         -24605            24000
# 57  50.048053    -21.924693         -25152            25000
# 58  50.048053    -21.924693         -25152            25000
# 59  50.048053    -21.924693         -25152            25000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=977.15 Expected Shortfall=117.20 Interquartile Range=226.50

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")

# %% [markdown]
# It would be great if we can store a local copy of the notebook after execution so I can easily look back at the performed actions...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Nov 13 19:13:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    47W / 400W |   1619MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import runtime
runtime.unassign()
# Out:
# <ipython-input-19-44ec248844a9>:2: ResourceWarning: unclosed <socket.socket fd=86, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('172.28.0.12', 37956), raddr=('172.28.0.1', 8011)>
#   runtime.unassign()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
