# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20SAC%20model%20SDE%20600k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train SAC RL model
#
# The SAC (Soft Actor-Critic) algorithm is an off-policy reinforcement learning method designed for continuous action spaces. It combines the benefits of both policy-based and value-based methods and is known for its sample efficiency and stability.
#
# The actor in SAC is responsible for selecting actions in the environment. It typically uses a neural network to learn a policy that maps observations to continuous actions.
# SAC uses a stochastic policy, which means it outputs a probability distribution over the available actions, often modeled as a Gaussian distribution.
# This stochasticity helps exploration during training.
#
# Critic: SAC also includes two critics, referred to as Q-networks. These networks estimate the state-action value function, providing two independent value estimates.
# Having multiple critics helps stabilize the training process.
#
# SAC collects data by interacting with the environment. The actor's stochastic policy is used to sample actions,
# and these actions are executed in the environment to collect state-action-reward transitions.
# SAC uses an experience replay buffer to store and sample past experiences.
# This buffer allows the algorithm to learn from a diverse set of experiences and reduce sample correlations.
#
# SAC employs a variant of the Bellman equation to update the critics. The key innovation in SAC is the use of a "soft" Bellman backup.
# This involves minimizing a loss that aims to make the critics agree with each other and be close to the minimum of the Bellman error.
#
# The actor's policy is updated based on the soft Q-values from the critics. The objective is to maximize the expected reward, including an entropy term.
# The entropy term encourages exploration by discouraging overly deterministic policies.
#
# SAC introduces a temperature parameter that scales the entropy term in the policy update. This temperature parameter can be learned or adjusted during training.
# It helps balance exploration and exploitation by controlling the level of stochasticity in the policy.
#
# These steps are repeated iteratively, allowing the agent to improve its policy and value functions over time. The process continues until convergence or a specified number of iterations.
#
# SAC's main advantages include:
#
# It can handle continuous action spaces efficiently.
# It provides a good balance between exploration and exploitation, thanks to the entropy term.
# It benefits from experience replay, which reduces sample correlations and enhances learning stability.
# It can be used in combination with target value networks for even more stability.
#
# https://arxiv.org/pdf/1801.01290.pdf

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct 22 14:35:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    46W / 350W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 696, done.
# remote: Counting objects: 100% (696/696), done.
# remote: Compressing objects: 100% (368/368), done.
# remote: Total 696 (delta 360), reused 642 (delta 320), pack-reused 0
# Receiving objects: 100% (696/696), 17.05 MiB | 17.20 MiB/s, done.
# Resolving deltas: 100% (360/360), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.5 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 57.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.1.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import SAC

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-10-22 14:36:08.464 | INFO     | src.data.dataset:read_data:45 - reading interest data from ESW.
# 2023-10-22 14:36:10.861 | INFO     | src.data.dataset:read_data:45 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# steps: 60, score: -2384

# %% [markdown]
# Define the model. For the initial model we use the A2C model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'SAC'
ent_coef= 0.001

model = SAC(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        ent_coef='auto',
        use_sde = True, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2023-10-22 14:36:15.077 | INFO     | src.data.dataset:read_data:45 - reading interest data from ESW.
# 2023-10-22 14:36:16.836 | INFO     | src.data.dataset:read_data:45 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-08-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 600_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# | time/              |          |
# |    episodes        | 8892     |
# |    fps             | 63       |
# |    time_elapsed    | 8458     |
# |    total_timesteps | 533520   |
# | train/             |          |
# |    actor_loss      | -292     |
# |    critic_loss     | 2.85e+03 |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 533419   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 812      |
# | time/              |          |
# |    episodes        | 8896     |
# |    fps             | 63       |
# |    time_elapsed    | 8462     |
# |    total_timesteps | 533760   |
# | train/             |          |
# |    actor_loss      | -339     |
# |    critic_loss     | 3.7e+03  |
# |    ent_coef        | 0.451    |
# |    ent_coef_loss   | -0.492   |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533659   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 818      |
# | time/              |          |
# |    episodes        | 8900     |
# |    fps             | 63       |
# |    time_elapsed    | 8465     |
# |    total_timesteps | 534000   |
# | train/             |          |
# |    actor_loss      | -373     |
# |    critic_loss     | 3.4e+03  |
# |    ent_coef        | 0.452    |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533899   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 816      |
# | time/              |          |
# |    episodes        | 8904     |
# |    fps             | 63       |
# |    time_elapsed    | 8469     |
# |    total_timesteps | 534240   |
# | train/             |          |
# |    actor_loss      | -277     |
# |    critic_loss     | 6.46e+03 |
# |    ent_coef        | 0.45     |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 534139   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 811      |
# | time/              |          |
# |    episodes        | 8908     |
# |    fps             | 63       |
# |    time_elapsed    | 8473     |
# |    total_timesteps | 534480   |
# | train/             |          |
# |    actor_loss      | -235     |
# |    critic_loss     | 5.68e+03 |
# |    ent_coef        | 0.45     |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534379   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 817      |
# | time/              |          |
# |    episodes        | 8912     |
# |    fps             | 63       |
# |    time_elapsed    | 8477     |
# |    total_timesteps | 534720   |
# | train/             |          |
# |    actor_loss      | -244     |
# |    critic_loss     | 4.21e+03 |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | -2.75    |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534619   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 817      |
# | time/              |          |
# |    episodes        | 8916     |
# |    fps             | 63       |
# |    time_elapsed    | 8480     |
# |    total_timesteps | 534960   |
# | train/             |          |
# |    actor_loss      | -235     |
# |    critic_loss     | 1.09e+04 |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 534859   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 8920     |
# |    fps             | 63       |
# |    time_elapsed    | 8484     |
# |    total_timesteps | 535200   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 4.4e+03  |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | 0.59     |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535099   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 814      |
# | time/              |          |
# |    episodes        | 8924     |
# |    fps             | 63       |
# |    time_elapsed    | 8488     |
# |    total_timesteps | 535440   |
# | train/             |          |
# |    actor_loss      | -344     |
# |    critic_loss     | 7.4e+03  |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | -3.27    |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535339   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 817      |
# | time/              |          |
# |    episodes        | 8928     |
# |    fps             | 63       |
# |    time_elapsed    | 8492     |
# |    total_timesteps | 535680   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 8.22e+03 |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535579   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 8932     |
# |    fps             | 63       |
# |    time_elapsed    | 8496     |
# |    total_timesteps | 535920   |
# | train/             |          |
# |    actor_loss      | -328     |
# |    critic_loss     | 2.07e+03 |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | 1.06     |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535819   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 8936     |
# |    fps             | 63       |
# |    time_elapsed    | 8499     |
# |    total_timesteps | 536160   |
# | train/             |          |
# |    actor_loss      | -271     |
# |    critic_loss     | 5.16e+03 |
# |    ent_coef        | 0.445    |
# |    ent_coef_loss   | -0.0788  |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536059   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 820      |
# | time/              |          |
# |    episodes        | 8940     |
# |    fps             | 63       |
# |    time_elapsed    | 8503     |
# |    total_timesteps | 536400   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 8.55e+03 |
# |    ent_coef        | 0.444    |
# |    ent_coef_loss   | 0.218    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536299   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 8944     |
# |    fps             | 63       |
# |    time_elapsed    | 8507     |
# |    total_timesteps | 536640   |
# | train/             |          |
# |    actor_loss      | -400     |
# |    critic_loss     | 1.89e+03 |
# |    ent_coef        | 0.441    |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536539   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 823      |
# | time/              |          |
# |    episodes        | 8948     |
# |    fps             | 63       |
# |    time_elapsed    | 8511     |
# |    total_timesteps | 536880   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 5.5e+03  |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.77    |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 536779   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 823      |
# | time/              |          |
# |    episodes        | 8952     |
# |    fps             | 63       |
# |    time_elapsed    | 8515     |
# |    total_timesteps | 537120   |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 7.28e+03 |
# |    ent_coef        | 0.438    |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 537019   |
# |    std             | 0.052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 816      |
# | time/              |          |
# |    episodes        | 8956     |
# |    fps             | 63       |
# |    time_elapsed    | 8518     |
# |    total_timesteps | 537360   |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 3.83e+03 |
# |    ent_coef        | 0.436    |
# |    ent_coef_loss   | 0.601    |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537259   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 818      |
# | time/              |          |
# |    episodes        | 8960     |
# |    fps             | 63       |
# |    time_elapsed    | 8522     |
# |    total_timesteps | 537600   |
# | train/             |          |
# |    actor_loss      | -257     |
# |    critic_loss     | 7.26e+03 |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537499   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 816      |
# | time/              |          |
# |    episodes        | 8964     |
# |    fps             | 63       |
# |    time_elapsed    | 8526     |
# |    total_timesteps | 537840   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 6.84e+03 |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -1.78    |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537739   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 822      |
# | time/              |          |
# |    episodes        | 8968     |
# |    fps             | 63       |
# |    time_elapsed    | 8530     |
# |    total_timesteps | 538080   |
# | train/             |          |
# |    actor_loss      | -193     |
# |    critic_loss     | 7.53e+03 |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | 0.909    |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 537979   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 827      |
# | time/              |          |
# |    episodes        | 8972     |
# |    fps             | 63       |
# |    time_elapsed    | 8534     |
# |    total_timesteps | 538320   |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 8.15e+03 |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | 0.916    |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 538219   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 8976     |
# |    fps             | 63       |
# |    time_elapsed    | 8537     |
# |    total_timesteps | 538560   |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 5.29e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.265    |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538459   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 834      |
# | time/              |          |
# |    episodes        | 8980     |
# |    fps             | 63       |
# |    time_elapsed    | 8541     |
# |    total_timesteps | 538800   |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 4.83e+03 |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | 0.433    |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538699   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 8984     |
# |    fps             | 63       |
# |    time_elapsed    | 8545     |
# |    total_timesteps | 539040   |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 5.24e+03 |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538939   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 835      |
# | time/              |          |
# |    episodes        | 8988     |
# |    fps             | 63       |
# |    time_elapsed    | 8549     |
# |    total_timesteps | 539280   |
# | train/             |          |
# |    actor_loss      | -339     |
# |    critic_loss     | 3.92e+03 |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539179   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 835      |
# | time/              |          |
# |    episodes        | 8992     |
# |    fps             | 63       |
# |    time_elapsed    | 8552     |
# |    total_timesteps | 539520   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 4.02e+03 |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | -0.969   |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539419   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 8996     |
# |    fps             | 63       |
# |    time_elapsed    | 8556     |
# |    total_timesteps | 539760   |
# | train/             |          |
# |    actor_loss      | -311     |
# |    critic_loss     | 3.07e+03 |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539659   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 832      |
# | time/              |          |
# |    episodes        | 9000     |
# |    fps             | 63       |
# |    time_elapsed    | 8560     |
# |    total_timesteps | 540000   |
# | train/             |          |
# |    actor_loss      | -327     |
# |    critic_loss     | 6.99e+03 |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | 1.68     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539899   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 829      |
# | time/              |          |
# |    episodes        | 9004     |
# |    fps             | 63       |
# |    time_elapsed    | 8564     |
# |    total_timesteps | 540240   |
# | train/             |          |
# |    actor_loss      | -264     |
# |    critic_loss     | 6.31e+03 |
# |    ent_coef        | 0.425    |
# |    ent_coef_loss   | -0.17    |
# |    learning_rate   | 9.96e-05 |
# |    n_updates       | 540139   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 825      |
# | time/              |          |
# |    episodes        | 9008     |
# |    fps             | 63       |
# |    time_elapsed    | 8568     |
# |    total_timesteps | 540480   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 3.99e+03 |
# |    ent_coef        | 0.425    |
# |    ent_coef_loss   | -2.39    |
# |    learning_rate   | 9.92e-05 |
# |    n_updates       | 540379   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 827      |
# | time/              |          |
# |    episodes        | 9012     |
# |    fps             | 63       |
# |    time_elapsed    | 8571     |
# |    total_timesteps | 540720   |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 7.01e+03 |
# |    ent_coef        | 0.424    |
# |    ent_coef_loss   | -0.0869  |
# |    learning_rate   | 9.88e-05 |
# |    n_updates       | 540619   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 9016     |
# |    fps             | 63       |
# |    time_elapsed    | 8575     |
# |    total_timesteps | 540960   |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 3.31e+03 |
# |    ent_coef        | 0.423    |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 9.84e-05 |
# |    n_updates       | 540859   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 63       |
# |    time_elapsed    | 8579     |
# |    total_timesteps | 541200   |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 7.12e+03 |
# |    ent_coef        | 0.422    |
# |    ent_coef_loss   | -0.425   |
# |    learning_rate   | 9.8e-05  |
# |    n_updates       | 541099   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 9024     |
# |    fps             | 63       |
# |    time_elapsed    | 8583     |
# |    total_timesteps | 541440   |
# | train/             |          |
# |    actor_loss      | -287     |
# |    critic_loss     | 4.9e+03  |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -2.81    |
# |    learning_rate   | 9.76e-05 |
# |    n_updates       | 541339   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 834      |
# | time/              |          |
# |    episodes        | 9028     |
# |    fps             | 63       |
# |    time_elapsed    | 8586     |
# |    total_timesteps | 541680   |
# | train/             |          |
# |    actor_loss      | -334     |
# |    critic_loss     | 7.04e+03 |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 9.72e-05 |
# |    n_updates       | 541579   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 831      |
# | time/              |          |
# |    episodes        | 9032     |
# |    fps             | 63       |
# |    time_elapsed    | 8590     |
# |    total_timesteps | 541920   |
# | train/             |          |
# |    actor_loss      | -353     |
# |    critic_loss     | 1.52e+04 |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | 2.05     |
# |    learning_rate   | 9.68e-05 |
# |    n_updates       | 541819   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 9036     |
# |    fps             | 63       |
# |    time_elapsed    | 8594     |
# |    total_timesteps | 542160   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 1.66e+04 |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 9.64e-05 |
# |    n_updates       | 542059   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 841      |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 63       |
# |    time_elapsed    | 8598     |
# |    total_timesteps | 542400   |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 6.59e+03 |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 9.6e-05  |
# |    n_updates       | 542299   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 836      |
# | time/              |          |
# |    episodes        | 9044     |
# |    fps             | 63       |
# |    time_elapsed    | 8602     |
# |    total_timesteps | 542640   |
# | train/             |          |
# |    actor_loss      | -311     |
# |    critic_loss     | 7.42e+03 |
# |    ent_coef        | 0.416    |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 9.56e-05 |
# |    n_updates       | 542539   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 843      |
# | time/              |          |
# |    episodes        | 9048     |
# |    fps             | 63       |
# |    time_elapsed    | 8605     |
# |    total_timesteps | 542880   |
# | train/             |          |
# |    actor_loss      | -229     |
# |    critic_loss     | 4.49e+03 |
# |    ent_coef        | 0.416    |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 9.52e-05 |
# |    n_updates       | 542779   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 847      |
# | time/              |          |
# |    episodes        | 9052     |
# |    fps             | 63       |
# |    time_elapsed    | 8609     |
# |    total_timesteps | 543120   |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 7.48e+03 |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | -3.35    |
# |    learning_rate   | 9.48e-05 |
# |    n_updates       | 543019   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 850      |
# | time/              |          |
# |    episodes        | 9056     |
# |    fps             | 63       |
# |    time_elapsed    | 8613     |
# |    total_timesteps | 543360   |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 1.42e+04 |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | 0.678    |
# |    learning_rate   | 9.44e-05 |
# |    n_updates       | 543259   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 839      |
# | time/              |          |
# |    episodes        | 9060     |
# |    fps             | 63       |
# |    time_elapsed    | 8617     |
# |    total_timesteps | 543600   |
# | train/             |          |
# |    actor_loss      | -376     |
# |    critic_loss     | 3.61e+03 |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | 2.1      |
# |    learning_rate   | 9.4e-05  |
# |    n_updates       | 543499   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 842      |
# | time/              |          |
# |    episodes        | 9064     |
# |    fps             | 63       |
# |    time_elapsed    | 8621     |
# |    total_timesteps | 543840   |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 3.35e+03 |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 9.36e-05 |
# |    n_updates       | 543739   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 840      |
# | time/              |          |
# |    episodes        | 9068     |
# |    fps             | 63       |
# |    time_elapsed    | 8624     |
# |    total_timesteps | 544080   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 3.49e+03 |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 9.32e-05 |
# |    n_updates       | 543979   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 835      |
# | time/              |          |
# |    episodes        | 9072     |
# |    fps             | 63       |
# |    time_elapsed    | 8628     |
# |    total_timesteps | 544320   |
# | train/             |          |
# |    actor_loss      | -264     |
# |    critic_loss     | 4.85e+03 |
# |    ent_coef        | 0.423    |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 9.28e-05 |
# |    n_updates       | 544219   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 836      |
# | time/              |          |
# |    episodes        | 9076     |
# |    fps             | 63       |
# |    time_elapsed    | 8632     |
# |    total_timesteps | 544560   |
# | train/             |          |
# |    actor_loss      | -267     |
# |    critic_loss     | 8.11e+03 |
# |    ent_coef        | 0.424    |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 9.24e-05 |
# |    n_updates       | 544459   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 9080     |
# |    fps             | 63       |
# |    time_elapsed    | 8636     |
# |    total_timesteps | 544800   |
# | train/             |          |
# |    actor_loss      | -366     |
# |    critic_loss     | 3.05e+03 |
# |    ent_coef        | 0.425    |
# |    ent_coef_loss   | 0.406    |
# |    learning_rate   | 9.2e-05  |
# |    n_updates       | 544699   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 9084     |
# |    fps             | 63       |
# |    time_elapsed    | 8639     |
# |    total_timesteps | 545040   |
# | train/             |          |
# |    actor_loss      | -259     |
# |    critic_loss     | 4.33e+04 |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | 0.215    |
# |    learning_rate   | 9.16e-05 |
# |    n_updates       | 544939   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 9088     |
# |    fps             | 63       |
# |    time_elapsed    | 8643     |
# |    total_timesteps | 545280   |
# | train/             |          |
# |    actor_loss      | -273     |
# |    critic_loss     | 7.64e+03 |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | -0.1     |
# |    learning_rate   | 9.12e-05 |
# |    n_updates       | 545179   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 815      |
# | time/              |          |
# |    episodes        | 9092     |
# |    fps             | 63       |
# |    time_elapsed    | 8647     |
# |    total_timesteps | 545520   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 4.91e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 9.08e-05 |
# |    n_updates       | 545419   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 817      |
# | time/              |          |
# |    episodes        | 9096     |
# |    fps             | 63       |
# |    time_elapsed    | 8651     |
# |    total_timesteps | 545760   |
# | train/             |          |
# |    actor_loss      | -230     |
# |    critic_loss     | 7.62e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 9.04e-05 |
# |    n_updates       | 545659   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 809      |
# | time/              |          |
# |    episodes        | 9100     |
# |    fps             | 63       |
# |    time_elapsed    | 8655     |
# |    total_timesteps | 546000   |
# | train/             |          |
# |    actor_loss      | -238     |
# |    critic_loss     | 6.97e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.926    |
# |    learning_rate   | 9e-05    |
# |    n_updates       | 545899   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 800      |
# | time/              |          |
# |    episodes        | 9104     |
# |    fps             | 63       |
# |    time_elapsed    | 8658     |
# |    total_timesteps | 546240   |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 4.79e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 8.96e-05 |
# |    n_updates       | 546139   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 804      |
# | time/              |          |
# |    episodes        | 9108     |
# |    fps             | 63       |
# |    time_elapsed    | 8662     |
# |    total_timesteps | 546480   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 4.96e+03 |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | 0.733    |
# |    learning_rate   | 8.92e-05 |
# |    n_updates       | 546379   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 799      |
# | time/              |          |
# |    episodes        | 9112     |
# |    fps             | 63       |
# |    time_elapsed    | 8666     |
# |    total_timesteps | 546720   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 4.77e+03 |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 8.88e-05 |
# |    n_updates       | 546619   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 796      |
# | time/              |          |
# |    episodes        | 9116     |
# |    fps             | 63       |
# |    time_elapsed    | 8670     |
# |    total_timesteps | 546960   |
# | train/             |          |
# |    actor_loss      | -210     |
# |    critic_loss     | 4.33e+03 |
# |    ent_coef        | 0.434    |
# |    ent_coef_loss   | -0.00631 |
# |    learning_rate   | 8.84e-05 |
# |    n_updates       | 546859   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 797      |
# | time/              |          |
# |    episodes        | 9120     |
# |    fps             | 63       |
# |    time_elapsed    | 8674     |
# |    total_timesteps | 547200   |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 3.63e+03 |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 8.8e-05  |
# |    n_updates       | 547099   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 795      |
# | time/              |          |
# |    episodes        | 9124     |
# |    fps             | 63       |
# |    time_elapsed    | 8677     |
# |    total_timesteps | 547440   |
# | train/             |          |
# |    actor_loss      | -320     |
# |    critic_loss     | 1.15e+04 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.489    |
# |    learning_rate   | 8.76e-05 |
# |    n_updates       | 547339   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 791      |
# | time/              |          |
# |    episodes        | 9128     |
# |    fps             | 63       |
# |    time_elapsed    | 8681     |
# |    total_timesteps | 547680   |
# | train/             |          |
# |    actor_loss      | -323     |
# |    critic_loss     | 2.43e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 1.63     |
# |    learning_rate   | 8.72e-05 |
# |    n_updates       | 547579   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 788      |
# | time/              |          |
# |    episodes        | 9132     |
# |    fps             | 63       |
# |    time_elapsed    | 8685     |
# |    total_timesteps | 547920   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 2.06e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.475    |
# |    learning_rate   | 8.68e-05 |
# |    n_updates       | 547819   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 784      |
# | time/              |          |
# |    episodes        | 9136     |
# |    fps             | 63       |
# |    time_elapsed    | 8689     |
# |    total_timesteps | 548160   |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 4.84e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 8.64e-05 |
# |    n_updates       | 548059   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 779      |
# | time/              |          |
# |    episodes        | 9140     |
# |    fps             | 63       |
# |    time_elapsed    | 8692     |
# |    total_timesteps | 548400   |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 5.27e+03 |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | -0.785   |
# |    learning_rate   | 8.6e-05  |
# |    n_updates       | 548299   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 777      |
# | time/              |          |
# |    episodes        | 9144     |
# |    fps             | 63       |
# |    time_elapsed    | 8696     |
# |    total_timesteps | 548640   |
# | train/             |          |
# |    actor_loss      | -241     |
# |    critic_loss     | 5.88e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.649    |
# |    learning_rate   | 8.56e-05 |
# |    n_updates       | 548539   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 766      |
# | time/              |          |
# |    episodes        | 9148     |
# |    fps             | 63       |
# |    time_elapsed    | 8700     |
# |    total_timesteps | 548880   |
# | train/             |          |
# |    actor_loss      | -184     |
# |    critic_loss     | 4.62e+03 |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | -0.554   |
# |    learning_rate   | 8.52e-05 |
# |    n_updates       | 548779   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 763      |
# | time/              |          |
# |    episodes        | 9152     |
# |    fps             | 63       |
# |    time_elapsed    | 8704     |
# |    total_timesteps | 549120   |
# | train/             |          |
# |    actor_loss      | -278     |
# |    critic_loss     | 3.99e+03 |
# |    ent_coef        | 0.434    |
# |    ent_coef_loss   | -0.0616  |
# |    learning_rate   | 8.48e-05 |
# |    n_updates       | 549019   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 763      |
# | time/              |          |
# |    episodes        | 9156     |
# |    fps             | 63       |
# |    time_elapsed    | 8708     |
# |    total_timesteps | 549360   |
# | train/             |          |
# |    actor_loss      | -326     |
# |    critic_loss     | 1.89e+04 |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 8.44e-05 |
# |    n_updates       | 549259   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 773      |
# | time/              |          |
# |    episodes        | 9160     |
# |    fps             | 63       |
# |    time_elapsed    | 8711     |
# |    total_timesteps | 549600   |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 8.74e+03 |
# |    ent_coef        | 0.436    |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 8.4e-05  |
# |    n_updates       | 549499   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 770      |
# | time/              |          |
# |    episodes        | 9164     |
# |    fps             | 63       |
# |    time_elapsed    | 8715     |
# |    total_timesteps | 549840   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 1.16e+04 |
# |    ent_coef        | 0.436    |
# |    ent_coef_loss   | -0.633   |
# |    learning_rate   | 8.36e-05 |
# |    n_updates       | 549739   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 772      |
# | time/              |          |
# |    episodes        | 9168     |
# |    fps             | 63       |
# |    time_elapsed    | 8719     |
# |    total_timesteps | 550080   |
# | train/             |          |
# |    actor_loss      | -253     |
# |    critic_loss     | 8.41e+03 |
# |    ent_coef        | 0.436    |
# |    ent_coef_loss   | -0.573   |
# |    learning_rate   | 8.32e-05 |
# |    n_updates       | 549979   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 778      |
# | time/              |          |
# |    episodes        | 9172     |
# |    fps             | 63       |
# |    time_elapsed    | 8723     |
# |    total_timesteps | 550320   |
# | train/             |          |
# |    actor_loss      | -274     |
# |    critic_loss     | 6.4e+03  |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -2.95    |
# |    learning_rate   | 8.28e-05 |
# |    n_updates       | 550219   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 776      |
# | time/              |          |
# |    episodes        | 9176     |
# |    fps             | 63       |
# |    time_elapsed    | 8726     |
# |    total_timesteps | 550560   |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 8.55e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | 0.0918   |
# |    learning_rate   | 8.24e-05 |
# |    n_updates       | 550459   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 783      |
# | time/              |          |
# |    episodes        | 9180     |
# |    fps             | 63       |
# |    time_elapsed    | 8730     |
# |    total_timesteps | 550800   |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 4.17e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | 1.51     |
# |    learning_rate   | 8.2e-05  |
# |    n_updates       | 550699   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 783      |
# | time/              |          |
# |    episodes        | 9184     |
# |    fps             | 63       |
# |    time_elapsed    | 8734     |
# |    total_timesteps | 551040   |
# | train/             |          |
# |    actor_loss      | -333     |
# |    critic_loss     | 2.84e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | 0.437    |
# |    learning_rate   | 8.16e-05 |
# |    n_updates       | 550939   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 791      |
# | time/              |          |
# |    episodes        | 9188     |
# |    fps             | 63       |
# |    time_elapsed    | 8738     |
# |    total_timesteps | 551280   |
# | train/             |          |
# |    actor_loss      | -282     |
# |    critic_loss     | 3.64e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 8.12e-05 |
# |    n_updates       | 551179   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 789      |
# | time/              |          |
# |    episodes        | 9192     |
# |    fps             | 63       |
# |    time_elapsed    | 8741     |
# |    total_timesteps | 551520   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 4.28e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | 0.792    |
# |    learning_rate   | 8.08e-05 |
# |    n_updates       | 551419   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 788      |
# | time/              |          |
# |    episodes        | 9196     |
# |    fps             | 63       |
# |    time_elapsed    | 8745     |
# |    total_timesteps | 551760   |
# | train/             |          |
# |    actor_loss      | -261     |
# |    critic_loss     | 1.28e+04 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | 2.01     |
# |    learning_rate   | 8.04e-05 |
# |    n_updates       | 551659   |
# |    std             | 0.0519   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 795      |
# ...
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 1.72e+04 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 1e-05    |
# |    n_updates       | 593899   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 9904     |
# |    fps             | 63       |
# |    time_elapsed    | 9416     |
# |    total_timesteps | 594240   |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 4.14e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -2.04    |
# |    learning_rate   | 9.6e-06  |
# |    n_updates       | 594139   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 823      |
# | time/              |          |
# |    episodes        | 9908     |
# |    fps             | 63       |
# |    time_elapsed    | 9420     |
# |    total_timesteps | 594480   |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 3.16e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 9.2e-06  |
# |    n_updates       | 594379   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 822      |
# | time/              |          |
# |    episodes        | 9912     |
# |    fps             | 63       |
# |    time_elapsed    | 9424     |
# |    total_timesteps | 594720   |
# | train/             |          |
# |    actor_loss      | -356     |
# |    critic_loss     | 3.66e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 8.8e-06  |
# |    n_updates       | 594619   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 820      |
# | time/              |          |
# |    episodes        | 9916     |
# |    fps             | 63       |
# |    time_elapsed    | 9428     |
# |    total_timesteps | 594960   |
# | train/             |          |
# |    actor_loss      | -276     |
# |    critic_loss     | 7.97e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | -3.82    |
# |    learning_rate   | 8.4e-06  |
# |    n_updates       | 594859   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 822      |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 63       |
# |    time_elapsed    | 9431     |
# |    total_timesteps | 595200   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 4.11e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 8e-06    |
# |    n_updates       | 595099   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 824      |
# | time/              |          |
# |    episodes        | 9924     |
# |    fps             | 63       |
# |    time_elapsed    | 9435     |
# |    total_timesteps | 595440   |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 4.85e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.121    |
# |    learning_rate   | 7.6e-06  |
# |    n_updates       | 595339   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 9928     |
# |    fps             | 63       |
# |    time_elapsed    | 9439     |
# |    total_timesteps | 595680   |
# | train/             |          |
# |    actor_loss      | -346     |
# |    critic_loss     | 3.84e+03 |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | 0.203    |
# |    learning_rate   | 7.2e-06  |
# |    n_updates       | 595579   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 827      |
# | time/              |          |
# |    episodes        | 9932     |
# |    fps             | 63       |
# |    time_elapsed    | 9443     |
# |    total_timesteps | 595920   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 5.11e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.861   |
# |    learning_rate   | 6.8e-06  |
# |    n_updates       | 595819   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 9936     |
# |    fps             | 63       |
# |    time_elapsed    | 9446     |
# |    total_timesteps | 596160   |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 3.65e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -3.39    |
# |    learning_rate   | 6.4e-06  |
# |    n_updates       | 596059   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 831      |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 63       |
# |    time_elapsed    | 9450     |
# |    total_timesteps | 596400   |
# | train/             |          |
# |    actor_loss      | -192     |
# |    critic_loss     | 1.59e+04 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 6e-06    |
# |    n_updates       | 596299   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 9944     |
# |    fps             | 63       |
# |    time_elapsed    | 9454     |
# |    total_timesteps | 596640   |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 4.52e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 5.6e-06  |
# |    n_updates       | 596539   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 9948     |
# |    fps             | 63       |
# |    time_elapsed    | 9458     |
# |    total_timesteps | 596880   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 5.69e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.832   |
# |    learning_rate   | 5.2e-06  |
# |    n_updates       | 596779   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 9952     |
# |    fps             | 63       |
# |    time_elapsed    | 9462     |
# |    total_timesteps | 597120   |
# | train/             |          |
# |    actor_loss      | -232     |
# |    critic_loss     | 5.01e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.39     |
# |    learning_rate   | 4.8e-06  |
# |    n_updates       | 597019   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 832      |
# | time/              |          |
# |    episodes        | 9956     |
# |    fps             | 63       |
# |    time_elapsed    | 9465     |
# |    total_timesteps | 597360   |
# | train/             |          |
# |    actor_loss      | -251     |
# |    critic_loss     | 3.15e+04 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.209   |
# |    learning_rate   | 4.4e-06  |
# |    n_updates       | 597259   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 63       |
# |    time_elapsed    | 9469     |
# |    total_timesteps | 597600   |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 2.47e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.576    |
# |    learning_rate   | 4e-06    |
# |    n_updates       | 597499   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 831      |
# | time/              |          |
# |    episodes        | 9964     |
# |    fps             | 63       |
# |    time_elapsed    | 9473     |
# |    total_timesteps | 597840   |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 6.19e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 1.95     |
# |    learning_rate   | 3.6e-06  |
# |    n_updates       | 597739   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 827      |
# | time/              |          |
# |    episodes        | 9968     |
# |    fps             | 63       |
# |    time_elapsed    | 9477     |
# |    total_timesteps | 598080   |
# | train/             |          |
# |    actor_loss      | -360     |
# |    critic_loss     | 4.5e+03  |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 3.2e-06  |
# |    n_updates       | 597979   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 9972     |
# |    fps             | 63       |
# |    time_elapsed    | 9480     |
# |    total_timesteps | 598320   |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 5.96e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.876    |
# |    learning_rate   | 2.8e-06  |
# |    n_updates       | 598219   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 832      |
# | time/              |          |
# |    episodes        | 9976     |
# |    fps             | 63       |
# |    time_elapsed    | 9484     |
# |    total_timesteps | 598560   |
# | train/             |          |
# |    actor_loss      | -259     |
# |    critic_loss     | 4.05e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -2.49    |
# |    learning_rate   | 2.4e-06  |
# |    n_updates       | 598459   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 836      |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 63       |
# |    time_elapsed    | 9488     |
# |    total_timesteps | 598800   |
# | train/             |          |
# |    actor_loss      | -289     |
# |    critic_loss     | 3.93e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.0282  |
# |    learning_rate   | 2e-06    |
# |    n_updates       | 598699   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 9984     |
# |    fps             | 63       |
# |    time_elapsed    | 9492     |
# |    total_timesteps | 599040   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 4.18e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 1.36     |
# |    learning_rate   | 1.6e-06  |
# |    n_updates       | 598939   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 836      |
# | time/              |          |
# |    episodes        | 9988     |
# |    fps             | 63       |
# |    time_elapsed    | 9496     |
# |    total_timesteps | 599280   |
# | train/             |          |
# |    actor_loss      | -349     |
# |    critic_loss     | 2.13e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.534    |
# |    learning_rate   | 1.2e-06  |
# |    n_updates       | 599179   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 825      |
# | time/              |          |
# |    episodes        | 9992     |
# |    fps             | 63       |
# |    time_elapsed    | 9499     |
# |    total_timesteps | 599520   |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 2.36e+04 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.826    |
# |    learning_rate   | 8.02e-07 |
# |    n_updates       | 599419   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 9996     |
# |    fps             | 63       |
# |    time_elapsed    | 9503     |
# |    total_timesteps | 599760   |
# | train/             |          |
# |    actor_loss      | -255     |
# |    critic_loss     | 3.66e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.897    |
# |    learning_rate   | 4.02e-07 |
# |    n_updates       | 599659   |
# |    std             | 0.0518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 832      |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 63       |
# |    time_elapsed    | 9507     |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | -280     |
# |    critic_loss     | 2.16e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -1.64    |
# |    learning_rate   | 1.67e-09 |
# |    n_updates       | 599899   |
# |    std             | 0.0518   |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Green",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ")
# Out:
# Model name: SAC, Steps: 600000, Mean: -441.3301, IQR: 276.0, CVaR: -35326.494736842105

# %%
print(model.policy)
# Out:
# MultiInputPolicy(
#   (actor): Actor(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=52, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Sequential(
#       (0): Linear(in_features=256, out_features=4, bias=True)
#       (1): Hardtanh(min_val=-2.0, max_val=2.0)
#     )
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  895
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1      -2             0                  0  1102.956495   -2
# 1          2       0             0                  0   924.970608    0
# 2          3      -2             0                  0  1977.080431   -2
# 3          4      -4             0                  0  3031.085412   -4
# 4          5      -2             0                  0  3002.574229   -2
# 5          6       0             0                  0  2676.483363    0
# 6          7       1             0                  0  2081.126426    1
# 7          8       4             0                  0  1580.640800    4
# 8          9       5             0                  0  1217.337808    5
# 9         10       5             0                  0  1802.247075    5
# 10        11       7             0                  0  1175.680657    7
# 11        12      10             0                  0   484.688394   10
# 12        13      10             0                  0   532.679776   10
# 13        14      10             0                  0   673.272641   10
# 14        15      11             0                  0   -42.716636   11
# 15        16      13             0                  0  -759.048396   13
# 16        17      14             0                  0 -1368.161448   14
# 17        18      14             0                  0 -1588.401427   14
# 18        19      14             0                  0 -1298.526368   14
# 19        20      13             0                  0 -1069.544312   13
# 20        21      10             0                  0   149.124389   10
# 21        22       9             0                  0   341.455890    9
# 22        23       9             0                  0   579.057433    9
# 23        24       9             0                  0   831.070415    9
# 24        25       8             0                  0  1104.383197    8
# 25        26      11             0                  0   401.345363   11
# 26        27      10             0                  0   709.081275   10
# 27        28      13             0                  0    62.473746   13
# 28        29      12             0                  0   480.762948   12
# 29        30      12             0                  0   914.960979   12
# 30        31      12             0                  0  1386.649286   12
# 31        32      14             0                  0   812.394775   14
# 32        33      16             0                  0   133.719086   16
# 33        34      16             0                  0   530.290819   16
# 34        35      15             0                  0   963.245956   15
# 35        36      17             0                  0   427.438532   17
# 36        37      17             0                  0   921.383123   17
# 37        38      16             0                  0  1374.298040   16
# 38        39      19             0                  0   850.757818   19
# 39        40      18             0                  0  1353.870245   18
# 40        41      20             0                  0   847.368925   20
# 41        42      22             0                  0   352.746191   22
# 42        43      21             0                  0   697.703512   21
# 43        44      23             0                  0    59.577024   23
# 44        45      23             0                  0   477.275661   23
# 45        46      22             0                  0   983.218960   22
# 46        47      22             0                  0  1433.367085   22
# 47        48      24             0                  0   934.362110   24
# 48        49      26             0                  0   397.703472   26
# 49        50      25             0                  0   818.390148   25
# 50        51      27             0                  0   250.530270   27
# 51        52      26             0                  0   721.701870   26
# 52        53      29             0                  0   177.658382   29
# 53        54      28             0                  0   777.022559   28
# 54        55      25             0                  0  2246.720855   25
# 55        56      27             0                  0  1685.355430   27
# 56        57      28             0                  0  1804.359332   28
# 57        58      30             0                  0  1689.831081   30
# 58        59      31             0                  0  1922.880696   31
# 59        60      32             0                  0  2078.754212   32
#
#        income  funding_cost  total_funding  total_mortgages
# 0    0.000000     -2.177117          -1101                0
# 1    3.678291     -3.598166          -1921             1000
# 2    3.678291     -5.826755          -2971             1000
# 3    3.678291     -7.772998          -4024             1000
# 4    7.287751     -9.389898          -4993             2000
# 5   10.001191    -10.475901          -5665             3000
# 6   12.854383    -11.252003          -6067             4000
# 7   16.329971    -12.198707          -6565             5000
# 8   19.277615    -13.323033          -7200             6000
# 9   19.277615    -14.196072          -7782             6000
# 10  22.495893    -14.771667          -8154             7000
# 11  25.432141    -15.271043          -8461             8000
# 12  25.432141    -15.196096          -8507             8000
# 13  25.432141    -15.361815          -8645             8000
# 14  25.432141    -13.718050          -7928             8000
# 15  25.432141    -12.273669          -7210             8000
# 16  25.432141    -11.201657          -6598             8000
# 17  25.432141    -10.821972          -6376             8000
# 18  25.432141    -11.200772          -6664             8000
# 19  25.432141    -11.500101          -6892             8000
# 20  21.956552    -11.764481          -7109             7000
# 21  21.956552    -12.021035          -7300             7000
# 22  21.956552    -12.335788          -7535             7000
# 23  21.956552    -12.662120          -7786             7000
# 24  21.956552    -12.984095          -8057             7000
# 25  24.566885    -13.326951          -8352             8000
# 26  24.566885    -13.665249          -8659             8000
# 27  27.110293    -14.031831          -9011             9000
# 28  27.110293    -14.346646          -9426             9000
# 29  27.110293    -14.667909          -9858             9000
# 30  27.110293    -15.044669         -10328             9000
# 31  29.799585    -15.476281         -10752            10000
# 32  32.426643    -15.826476         -11072            11000
# 33  32.426643    -16.178057         -11466            11000
# 34  32.426643    -16.552956         -11897            11000
# 35  34.866926    -16.986976         -12360            12000
# 36  34.866926    -17.518738         -12851            12000
# 37  34.866926    -18.009870         -13303            12000
# 38  37.563844    -18.532446         -13777            13000
# 39  37.563844    -19.034497         -14278            13000
# 40  40.019450    -19.649990         -14770            14000
# 41  42.704015    -20.421502         -15273            15000
# 42  42.704015    -20.913162         -15616            15000
# 43  45.337275    -21.406055         -15976            16000
# 44  45.337275    -21.818818         -16392            16000
# 45  45.337275    -22.345768         -16896            16000
# 46  45.337275    -22.884623         -17344            16000
# 47  48.229570    -23.571238         -17843            17000
# 48  50.675675    -24.204388         -18304            18000
# 49  50.675675    -24.869662         -18722            18000
# 50  53.205178    -25.581811         -19152            19000
# 51  53.205178    -26.338199         -19621            19000
# 52  56.147930    -27.122717         -20075            20000
# 53  56.147930    -27.646719         -20672            20000
# 54  53.463366    -28.205990         -21140            19000
# 55  56.310013    -28.815515         -21576            20000
# 56  58.893649    -30.431029         -22694            21000
# 57  61.781668    -31.778289         -23577            22000
# 58  64.675250    -33.643819         -24808            23000
# 59  67.478602    -35.475841         -25962            24000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=808.98 Expected Shortfall=477.80 Interquartile Range=164.50

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")
