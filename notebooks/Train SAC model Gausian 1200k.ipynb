# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20SAC%20model%20Gausian%201200k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train SAC RL model
#
# The SAC (Soft Actor-Critic) algorithm is an off-policy reinforcement learning method designed for continuous action spaces. It combines the benefits of both policy-based and value-based methods and is known for its sample efficiency and stability.
#
# The actor in SAC is responsible for selecting actions in the environment. It typically uses a neural network to learn a policy that maps observations to continuous actions.
# SAC uses a stochastic policy, which means it outputs a probability distribution over the available actions, often modeled as a Gaussian distribution.
# This stochasticity helps exploration during training.
#
# Critic: SAC also includes two critics, referred to as Q-networks. These networks estimate the state-action value function, providing two independent value estimates.
# Having multiple critics helps stabilize the training process.
#
# SAC collects data by interacting with the environment. The actor's stochastic policy is used to sample actions,
# and these actions are executed in the environment to collect state-action-reward transitions.
# SAC uses an experience replay buffer to store and sample past experiences.
# This buffer allows the algorithm to learn from a diverse set of experiences and reduce sample correlations.
#
# SAC employs a variant of the Bellman equation to update the critics. The key innovation in SAC is the use of a "soft" Bellman backup.
# This involves minimizing a loss that aims to make the critics agree with each other and be close to the minimum of the Bellman error.
#
# The actor's policy is updated based on the soft Q-values from the critics. The objective is to maximize the expected reward, including an entropy term.
# The entropy term encourages exploration by discouraging overly deterministic policies.
#
# SAC introduces a temperature parameter that scales the entropy term in the policy update. This temperature parameter can be learned or adjusted during training.
# It helps balance exploration and exploitation by controlling the level of stochasticity in the policy.
#
# These steps are repeated iteratively, allowing the agent to improve its policy and value functions over time. The process continues until convergence or a specified number of iterations.
#
# SAC's main advantages include:
#
# It can handle continuous action spaces efficiently.
# It provides a good balance between exploration and exploitation, thanks to the entropy term.
# It benefits from experience replay, which reduces sample correlations and enhances learning stability.
# It can be used in combination with target value networks for even more stability.
#
# https://arxiv.org/pdf/1801.01290.pdf

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Nov 16 10:15:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 850, done.
# remote: Counting objects: 100% (850/850), done.
# remote: Compressing objects: 100% (500/500), done.
# remote: Total 850 (delta 447), reused 701 (delta 342), pack-reused 0
# Receiving objects: 100% (850/850), 21.90 MiB | 35.42 MiB/s, done.
# Resolving deltas: 100% (447/447), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.0 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.1.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import SAC

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %%
# Change Path settings to output results to gdrive

MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/models')
DATA_MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/data/model')
FIGURES_PATH = Path('/content/gdrive/MyDrive/rl-alm/reports/figures')
NOTEBOOK_PATH = Path('/content/gdrive/MyDrive/rl-alm/notebooks')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-11-16 10:16:10.007 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-16 10:16:11.659 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# /content/rl-alm/src/data/zerocurve.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_on["rate"] = np.NaN
# /content/rl-alm/src/data/zerocurve.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_on["tenor"] = 0
# /content/rl-alm/src/data/zerocurve.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_on["value_dt"] = df_on["rate_dt"] + BDay(1)
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# steps: 60, score: -8643

# %% [markdown]
# Define the model. For the initial model we use the A2C model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'SAC_Gausian'
ent_coef= 0.001

model = SAC(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        ent_coef='auto',
        use_sde = False, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2023-11-16 10:16:14.762 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-16 10:16:16.047 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 1_200_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    n_updates       | 1129339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18828    |
# |    fps             | 71       |
# |    time_elapsed    | 15856    |
# |    total_timesteps | 1129680  |
# | train/             |          |
# |    actor_loss      | -570     |
# |    critic_loss     | 771      |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 5.86e-05 |
# |    n_updates       | 1129579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18832    |
# |    fps             | 71       |
# |    time_elapsed    | 15859    |
# |    total_timesteps | 1129920  |
# | train/             |          |
# |    actor_loss      | -562     |
# |    critic_loss     | 877      |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | -0.179   |
# |    learning_rate   | 5.84e-05 |
# |    n_updates       | 1129819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18836    |
# |    fps             | 71       |
# |    time_elapsed    | 15863    |
# |    total_timesteps | 1130160  |
# | train/             |          |
# |    actor_loss      | -565     |
# |    critic_loss     | 440      |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | -0.226   |
# |    learning_rate   | 5.82e-05 |
# |    n_updates       | 1130059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18840    |
# |    fps             | 71       |
# |    time_elapsed    | 15866    |
# |    total_timesteps | 1130400  |
# | train/             |          |
# |    actor_loss      | -570     |
# |    critic_loss     | 883      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.0464  |
# |    learning_rate   | 5.8e-05  |
# |    n_updates       | 1130299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18844    |
# |    fps             | 71       |
# |    time_elapsed    | 15869    |
# |    total_timesteps | 1130640  |
# | train/             |          |
# |    actor_loss      | -522     |
# |    critic_loss     | 1.14e+03 |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0487   |
# |    learning_rate   | 5.78e-05 |
# |    n_updates       | 1130539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18848    |
# |    fps             | 71       |
# |    time_elapsed    | 15873    |
# |    total_timesteps | 1130880  |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 447      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.0531  |
# |    learning_rate   | 5.76e-05 |
# |    n_updates       | 1130779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18852    |
# |    fps             | 71       |
# |    time_elapsed    | 15876    |
# |    total_timesteps | 1131120  |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 306      |
# |    ent_coef        | 0.416    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 5.74e-05 |
# |    n_updates       | 1131019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18856    |
# |    fps             | 71       |
# |    time_elapsed    | 15880    |
# |    total_timesteps | 1131360  |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 385      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | 0.000318 |
# |    learning_rate   | 5.72e-05 |
# |    n_updates       | 1131259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18860    |
# |    fps             | 71       |
# |    time_elapsed    | 15883    |
# |    total_timesteps | 1131600  |
# | train/             |          |
# |    actor_loss      | -573     |
# |    critic_loss     | 448      |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | -0.0315  |
# |    learning_rate   | 5.7e-05  |
# |    n_updates       | 1131499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18864    |
# |    fps             | 71       |
# |    time_elapsed    | 15886    |
# |    total_timesteps | 1131840  |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 412      |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | -0.083   |
# |    learning_rate   | 5.68e-05 |
# |    n_updates       | 1131739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18868    |
# |    fps             | 71       |
# |    time_elapsed    | 15890    |
# |    total_timesteps | 1132080  |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 344      |
# |    ent_coef        | 0.407    |
# |    ent_coef_loss   | -0.278   |
# |    learning_rate   | 5.66e-05 |
# |    n_updates       | 1131979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 18872    |
# |    fps             | 71       |
# |    time_elapsed    | 15893    |
# |    total_timesteps | 1132320  |
# | train/             |          |
# |    actor_loss      | -565     |
# |    critic_loss     | 820      |
# |    ent_coef        | 0.403    |
# |    ent_coef_loss   | 0.00978  |
# |    learning_rate   | 5.64e-05 |
# |    n_updates       | 1132219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18876    |
# |    fps             | 71       |
# |    time_elapsed    | 15896    |
# |    total_timesteps | 1132560  |
# | train/             |          |
# |    actor_loss      | -565     |
# |    critic_loss     | 1.14e+03 |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -0.0209  |
# |    learning_rate   | 5.62e-05 |
# |    n_updates       | 1132459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18880    |
# |    fps             | 71       |
# |    time_elapsed    | 15900    |
# |    total_timesteps | 1132800  |
# | train/             |          |
# |    actor_loss      | -560     |
# |    critic_loss     | 726      |
# |    ent_coef        | 0.401    |
# |    ent_coef_loss   | 0.0209   |
# |    learning_rate   | 5.6e-05  |
# |    n_updates       | 1132699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18884    |
# |    fps             | 71       |
# |    time_elapsed    | 15903    |
# |    total_timesteps | 1133040  |
# | train/             |          |
# |    actor_loss      | -577     |
# |    critic_loss     | 804      |
# |    ent_coef        | 0.403    |
# |    ent_coef_loss   | 0.216    |
# |    learning_rate   | 5.58e-05 |
# |    n_updates       | 1132939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18888    |
# |    fps             | 71       |
# |    time_elapsed    | 15906    |
# |    total_timesteps | 1133280  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 436      |
# |    ent_coef        | 0.4      |
# |    ent_coef_loss   | -0.157   |
# |    learning_rate   | 5.56e-05 |
# |    n_updates       | 1133179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18892    |
# |    fps             | 71       |
# |    time_elapsed    | 15910    |
# |    total_timesteps | 1133520  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 572      |
# |    ent_coef        | 0.398    |
# |    ent_coef_loss   | 0.184    |
# |    learning_rate   | 5.54e-05 |
# |    n_updates       | 1133419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18896    |
# |    fps             | 71       |
# |    time_elapsed    | 15913    |
# |    total_timesteps | 1133760  |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 594      |
# |    ent_coef        | 0.398    |
# |    ent_coef_loss   | 0.133    |
# |    learning_rate   | 5.52e-05 |
# |    n_updates       | 1133659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18900    |
# |    fps             | 71       |
# |    time_elapsed    | 15916    |
# |    total_timesteps | 1134000  |
# | train/             |          |
# |    actor_loss      | -544     |
# |    critic_loss     | 1.4e+03  |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | 0.171    |
# |    learning_rate   | 5.5e-05  |
# |    n_updates       | 1133899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18904    |
# |    fps             | 71       |
# |    time_elapsed    | 15920    |
# |    total_timesteps | 1134240  |
# | train/             |          |
# |    actor_loss      | -576     |
# |    critic_loss     | 543      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 5.48e-05 |
# |    n_updates       | 1134139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18908    |
# |    fps             | 71       |
# |    time_elapsed    | 15923    |
# |    total_timesteps | 1134480  |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 574      |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | 0.0793   |
# |    learning_rate   | 5.46e-05 |
# |    n_updates       | 1134379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18912    |
# |    fps             | 71       |
# |    time_elapsed    | 15926    |
# |    total_timesteps | 1134720  |
# | train/             |          |
# |    actor_loss      | -539     |
# |    critic_loss     | 570      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | 0.0171   |
# |    learning_rate   | 5.44e-05 |
# |    n_updates       | 1134619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18916    |
# |    fps             | 71       |
# |    time_elapsed    | 15930    |
# |    total_timesteps | 1134960  |
# | train/             |          |
# |    actor_loss      | -557     |
# |    critic_loss     | 436      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 5.42e-05 |
# |    n_updates       | 1134859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18920    |
# |    fps             | 71       |
# |    time_elapsed    | 15933    |
# |    total_timesteps | 1135200  |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 566      |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | 0.177    |
# |    learning_rate   | 5.4e-05  |
# |    n_updates       | 1135099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18924    |
# |    fps             | 71       |
# |    time_elapsed    | 15936    |
# |    total_timesteps | 1135440  |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 1.25e+03 |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 5.38e-05 |
# |    n_updates       | 1135339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18928    |
# |    fps             | 71       |
# |    time_elapsed    | 15940    |
# |    total_timesteps | 1135680  |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 515      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -0.0313  |
# |    learning_rate   | 5.36e-05 |
# |    n_updates       | 1135579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18932    |
# |    fps             | 71       |
# |    time_elapsed    | 15943    |
# |    total_timesteps | 1135920  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 653      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.0713  |
# |    learning_rate   | 5.34e-05 |
# |    n_updates       | 1135819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18936    |
# |    fps             | 71       |
# |    time_elapsed    | 15946    |
# |    total_timesteps | 1136160  |
# | train/             |          |
# |    actor_loss      | -544     |
# |    critic_loss     | 331      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 5.32e-05 |
# |    n_updates       | 1136059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18940    |
# |    fps             | 71       |
# |    time_elapsed    | 15950    |
# |    total_timesteps | 1136400  |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 688      |
# |    ent_coef        | 0.424    |
# |    ent_coef_loss   | 0.27     |
# |    learning_rate   | 5.3e-05  |
# |    n_updates       | 1136299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 18944    |
# |    fps             | 71       |
# |    time_elapsed    | 15953    |
# |    total_timesteps | 1136640  |
# | train/             |          |
# |    actor_loss      | -579     |
# |    critic_loss     | 1.12e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.248    |
# |    learning_rate   | 5.28e-05 |
# |    n_updates       | 1136539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 18948    |
# |    fps             | 71       |
# |    time_elapsed    | 15956    |
# |    total_timesteps | 1136880  |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 618      |
# |    ent_coef        | 0.431    |
# |    ent_coef_loss   | -0.0175  |
# |    learning_rate   | 5.26e-05 |
# |    n_updates       | 1136779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18952    |
# |    fps             | 71       |
# |    time_elapsed    | 15960    |
# |    total_timesteps | 1137120  |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 548      |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | -0.0212  |
# |    learning_rate   | 5.24e-05 |
# |    n_updates       | 1137019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 18956    |
# |    fps             | 71       |
# |    time_elapsed    | 15963    |
# |    total_timesteps | 1137360  |
# | train/             |          |
# |    actor_loss      | -564     |
# |    critic_loss     | 326      |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.00919  |
# |    learning_rate   | 5.22e-05 |
# |    n_updates       | 1137259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 18960    |
# |    fps             | 71       |
# |    time_elapsed    | 15966    |
# |    total_timesteps | 1137600  |
# | train/             |          |
# |    actor_loss      | -557     |
# |    critic_loss     | 433      |
# |    ent_coef        | 0.424    |
# |    ent_coef_loss   | -0.231   |
# |    learning_rate   | 5.2e-05  |
# |    n_updates       | 1137499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 18964    |
# |    fps             | 71       |
# |    time_elapsed    | 15970    |
# |    total_timesteps | 1137840  |
# | train/             |          |
# |    actor_loss      | -575     |
# |    critic_loss     | 292      |
# |    ent_coef        | 0.423    |
# |    ent_coef_loss   | -0.00872 |
# |    learning_rate   | 5.18e-05 |
# |    n_updates       | 1137739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18968    |
# |    fps             | 71       |
# |    time_elapsed    | 15973    |
# |    total_timesteps | 1138080  |
# | train/             |          |
# |    actor_loss      | -544     |
# |    critic_loss     | 683      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.0503  |
# |    learning_rate   | 5.16e-05 |
# |    n_updates       | 1137979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18972    |
# |    fps             | 71       |
# |    time_elapsed    | 15976    |
# |    total_timesteps | 1138320  |
# | train/             |          |
# |    actor_loss      | -554     |
# |    critic_loss     | 1.39e+03 |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 5.14e-05 |
# |    n_updates       | 1138219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18976    |
# |    fps             | 71       |
# |    time_elapsed    | 15980    |
# |    total_timesteps | 1138560  |
# | train/             |          |
# |    actor_loss      | -561     |
# |    critic_loss     | 564      |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | -0.088   |
# |    learning_rate   | 5.12e-05 |
# |    n_updates       | 1138459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 18980    |
# |    fps             | 71       |
# |    time_elapsed    | 15983    |
# |    total_timesteps | 1138800  |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 458      |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 5.1e-05  |
# |    n_updates       | 1138699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18984    |
# |    fps             | 71       |
# |    time_elapsed    | 15986    |
# |    total_timesteps | 1139040  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 620      |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | 0.352    |
# |    learning_rate   | 5.08e-05 |
# |    n_updates       | 1138939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18988    |
# |    fps             | 71       |
# |    time_elapsed    | 15990    |
# |    total_timesteps | 1139280  |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 794      |
# |    ent_coef        | 0.411    |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 5.06e-05 |
# |    n_updates       | 1139179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18992    |
# |    fps             | 71       |
# |    time_elapsed    | 15993    |
# |    total_timesteps | 1139520  |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 827      |
# |    ent_coef        | 0.411    |
# |    ent_coef_loss   | 0.274    |
# |    learning_rate   | 5.04e-05 |
# |    n_updates       | 1139419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 18996    |
# |    fps             | 71       |
# |    time_elapsed    | 15996    |
# |    total_timesteps | 1139760  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 493      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | 0.194    |
# |    learning_rate   | 5.02e-05 |
# |    n_updates       | 1139659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19000    |
# |    fps             | 71       |
# |    time_elapsed    | 16000    |
# |    total_timesteps | 1140000  |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 917      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.0716  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1139899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19004    |
# |    fps             | 71       |
# |    time_elapsed    | 16003    |
# |    total_timesteps | 1140240  |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 536      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.0362  |
# |    learning_rate   | 4.98e-05 |
# |    n_updates       | 1140139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19008    |
# |    fps             | 71       |
# |    time_elapsed    | 16006    |
# |    total_timesteps | 1140480  |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 441      |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | 0.0794   |
# |    learning_rate   | 4.96e-05 |
# |    n_updates       | 1140379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19012    |
# |    fps             | 71       |
# |    time_elapsed    | 16010    |
# |    total_timesteps | 1140720  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 343      |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 4.94e-05 |
# |    n_updates       | 1140619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19016    |
# |    fps             | 71       |
# |    time_elapsed    | 16013    |
# |    total_timesteps | 1140960  |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 876      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | 0.0639   |
# |    learning_rate   | 4.92e-05 |
# |    n_updates       | 1140859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19020    |
# |    fps             | 71       |
# |    time_elapsed    | 16016    |
# |    total_timesteps | 1141200  |
# | train/             |          |
# |    actor_loss      | -559     |
# |    critic_loss     | 826      |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | 0.0553   |
# |    learning_rate   | 4.9e-05  |
# |    n_updates       | 1141099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19024    |
# |    fps             | 71       |
# |    time_elapsed    | 16020    |
# |    total_timesteps | 1141440  |
# | train/             |          |
# |    actor_loss      | -590     |
# |    critic_loss     | 476      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 4.88e-05 |
# |    n_updates       | 1141339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19028    |
# |    fps             | 71       |
# |    time_elapsed    | 16023    |
# |    total_timesteps | 1141680  |
# | train/             |          |
# |    actor_loss      | -536     |
# |    critic_loss     | 365      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.133   |
# |    learning_rate   | 4.86e-05 |
# |    n_updates       | 1141579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19032    |
# |    fps             | 71       |
# |    time_elapsed    | 16026    |
# |    total_timesteps | 1141920  |
# | train/             |          |
# |    actor_loss      | -560     |
# |    critic_loss     | 713      |
# |    ent_coef        | 0.41     |
# |    ent_coef_loss   | -0.0739  |
# |    learning_rate   | 4.84e-05 |
# |    n_updates       | 1141819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19036    |
# |    fps             | 71       |
# |    time_elapsed    | 16030    |
# |    total_timesteps | 1142160  |
# | train/             |          |
# |    actor_loss      | -569     |
# |    critic_loss     | 230      |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | 0.0533   |
# |    learning_rate   | 4.82e-05 |
# |    n_updates       | 1142059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19040    |
# |    fps             | 71       |
# |    time_elapsed    | 16033    |
# |    total_timesteps | 1142400  |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 400      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.114    |
# |    learning_rate   | 4.8e-05  |
# |    n_updates       | 1142299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19044    |
# |    fps             | 71       |
# |    time_elapsed    | 16036    |
# |    total_timesteps | 1142640  |
# | train/             |          |
# |    actor_loss      | -529     |
# |    critic_loss     | 772      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 4.78e-05 |
# |    n_updates       | 1142539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19048    |
# |    fps             | 71       |
# |    time_elapsed    | 16040    |
# |    total_timesteps | 1142880  |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 373      |
# |    ent_coef        | 0.418    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 4.76e-05 |
# |    n_updates       | 1142779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19052    |
# |    fps             | 71       |
# |    time_elapsed    | 16043    |
# |    total_timesteps | 1143120  |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 994      |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | 0.074    |
# |    learning_rate   | 4.74e-05 |
# |    n_updates       | 1143019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19056    |
# |    fps             | 71       |
# |    time_elapsed    | 16046    |
# |    total_timesteps | 1143360  |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 1.13e+03 |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | -0.0713  |
# |    learning_rate   | 4.72e-05 |
# |    n_updates       | 1143259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19060    |
# |    fps             | 71       |
# |    time_elapsed    | 16050    |
# |    total_timesteps | 1143600  |
# | train/             |          |
# |    actor_loss      | -539     |
# |    critic_loss     | 1.1e+03  |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.304   |
# |    learning_rate   | 4.7e-05  |
# |    n_updates       | 1143499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19064    |
# |    fps             | 71       |
# |    time_elapsed    | 16053    |
# |    total_timesteps | 1143840  |
# | train/             |          |
# |    actor_loss      | -564     |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | 0.0588   |
# |    learning_rate   | 4.68e-05 |
# |    n_updates       | 1143739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19068    |
# |    fps             | 71       |
# |    time_elapsed    | 16057    |
# |    total_timesteps | 1144080  |
# | train/             |          |
# |    actor_loss      | -576     |
# |    critic_loss     | 537      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.144   |
# |    learning_rate   | 4.66e-05 |
# |    n_updates       | 1143979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19072    |
# |    fps             | 71       |
# |    time_elapsed    | 16060    |
# |    total_timesteps | 1144320  |
# | train/             |          |
# |    actor_loss      | -552     |
# |    critic_loss     | 558      |
# |    ent_coef        | 0.405    |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 4.64e-05 |
# |    n_updates       | 1144219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19076    |
# |    fps             | 71       |
# |    time_elapsed    | 16063    |
# |    total_timesteps | 1144560  |
# | train/             |          |
# |    actor_loss      | -559     |
# |    critic_loss     | 447      |
# |    ent_coef        | 0.405    |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 4.62e-05 |
# |    n_updates       | 1144459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19080    |
# |    fps             | 71       |
# |    time_elapsed    | 16067    |
# |    total_timesteps | 1144800  |
# | train/             |          |
# |    actor_loss      | -546     |
# |    critic_loss     | 231      |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 4.6e-05  |
# |    n_updates       | 1144699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19084    |
# |    fps             | 71       |
# |    time_elapsed    | 16070    |
# |    total_timesteps | 1145040  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 410      |
# |    ent_coef        | 0.404    |
# |    ent_coef_loss   | 0.226    |
# |    learning_rate   | 4.58e-05 |
# |    n_updates       | 1144939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19088    |
# |    fps             | 71       |
# |    time_elapsed    | 16073    |
# |    total_timesteps | 1145280  |
# | train/             |          |
# |    actor_loss      | -566     |
# |    critic_loss     | 326      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.0162  |
# |    learning_rate   | 4.56e-05 |
# |    n_updates       | 1145179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19092    |
# |    fps             | 71       |
# |    time_elapsed    | 16077    |
# |    total_timesteps | 1145520  |
# | train/             |          |
# |    actor_loss      | -564     |
# |    critic_loss     | 498      |
# |    ent_coef        | 0.412    |
# |    ent_coef_loss   | 0.0812   |
# |    learning_rate   | 4.54e-05 |
# |    n_updates       | 1145419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 19096    |
# |    fps             | 71       |
# |    time_elapsed    | 16080    |
# |    total_timesteps | 1145760  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 403      |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | 0.253    |
# |    learning_rate   | 4.52e-05 |
# |    n_updates       | 1145659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19100    |
# |    fps             | 71       |
# |    time_elapsed    | 16083    |
# |    total_timesteps | 1146000  |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 439      |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | -0.0886  |
# |    learning_rate   | 4.5e-05  |
# |    n_updates       | 1145899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19104    |
# |    fps             | 71       |
# |    time_elapsed    | 16087    |
# |    total_timesteps | 1146240  |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 946      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.0575   |
# |    learning_rate   | 4.48e-05 |
# |    n_updates       | 1146139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19108    |
# |    fps             | 71       |
# |    time_elapsed    | 16090    |
# |    total_timesteps | 1146480  |
# | train/             |          |
# |    actor_loss      | -578     |
# |    critic_loss     | 1.1e+03  |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.0645   |
# |    learning_rate   | 4.46e-05 |
# |    n_updates       | 1146379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19112    |
# |    fps             | 71       |
# |    time_elapsed    | 16093    |
# |    total_timesteps | 1146720  |
# | train/             |          |
# |    actor_loss      | -537     |
# |    critic_loss     | 761      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.0339  |
# |    learning_rate   | 4.44e-05 |
# |    n_updates       | 1146619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 19116    |
# |    fps             | 71       |
# |    time_elapsed    | 16097    |
# |    total_timesteps | 1146960  |
# | train/             |          |
# |    actor_loss      | -558     |
# |    critic_loss     | 681      |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | -0.373   |
# |    learning_rate   | 4.42e-05 |
# |    n_updates       | 1146859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19120    |
# |    fps             | 71       |
# |    time_elapsed    | 16100    |
# |    total_timesteps | 1147200  |
# | train/             |          |
# |    actor_loss      | -569     |
# |    critic_loss     | 657      |
# |    ent_coef        | 0.415    |
# |    ent_coef_loss   | -0.0412  |
# |    learning_rate   | 4.4e-05  |
# |    n_updates       | 1147099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19124    |
# |    fps             | 71       |
# |    time_elapsed    | 16104    |
# |    total_timesteps | 1147440  |
# | train/             |          |
# |    actor_loss      | -567     |
# |    critic_loss     | 479      |
# |    ent_coef        | 0.417    |
# |    ent_coef_loss   | 0.135    |
# |    learning_rate   | 4.38e-05 |
# |    n_updates       | 1147339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.19e+03 |
# | time/              |          |
# |    episodes        | 19128    |
# |    fps             | 71       |
# |    time_elapsed    | 16107    |
# |    total_timesteps | 1147680  |
# | train/             |          |
# |    actor_loss      | -569     |
# |    critic_loss     | 428      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | 0.121    |
# |    learning_rate   | 4.36e-05 |
# |    n_updates       | 1147579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19132    |
# |    fps             | 71       |
# |    time_elapsed    | 16110    |
# |    total_timesteps | 1147920  |
# | train/             |          |
# |    actor_loss      | -564     |
# |    critic_loss     | 432      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | 0.0483   |
# |    learning_rate   | 4.34e-05 |
# |    n_updates       | 1147819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19136    |
# |    fps             | 71       |
# |    time_elapsed    | 16114    |
# |    total_timesteps | 1148160  |
# | train/             |          |
# |    actor_loss      | -567     |
# |    critic_loss     | 779      |
# |    ent_coef        | 0.422    |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 4.32e-05 |
# |    n_updates       | 1148059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19140    |
# |    fps             | 71       |
# |    time_elapsed    | 16117    |
# |    total_timesteps | 1148400  |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 1.03e+03 |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.282   |
# |    learning_rate   | 4.3e-05  |
# |    n_updates       | 1148299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19144    |
# |    fps             | 71       |
# |    time_elapsed    | 16120    |
# |    total_timesteps | 1148640  |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 397      |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -0.0176  |
# |    learning_rate   | 4.28e-05 |
# |    n_updates       | 1148539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19148    |
# |    fps             | 71       |
# |    time_elapsed    | 16124    |
# |    total_timesteps | 1148880  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 1.3e+03  |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.051   |
# |    learning_rate   | 4.26e-05 |
# |    n_updates       | 1148779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.2e+03  |
# | time/              |          |
# |    episodes        | 19152    |
# |    fps             | 71       |
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19896    |
# |    fps             | 71       |
# |    time_elapsed    | 16751    |
# |    total_timesteps | 1193760  |
# | train/             |          |
# |    actor_loss      | -543     |
# |    critic_loss     | 364      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 5.2e-06  |
# |    n_updates       | 1193659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 71       |
# |    time_elapsed    | 16755    |
# |    total_timesteps | 1194000  |
# | train/             |          |
# |    actor_loss      | -564     |
# |    critic_loss     | 592      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -0.0629  |
# |    learning_rate   | 5e-06    |
# |    n_updates       | 1193899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19904    |
# |    fps             | 71       |
# |    time_elapsed    | 16758    |
# |    total_timesteps | 1194240  |
# | train/             |          |
# |    actor_loss      | -571     |
# |    critic_loss     | 362      |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | 0.00362  |
# |    learning_rate   | 4.8e-06  |
# |    n_updates       | 1194139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19908    |
# |    fps             | 71       |
# |    time_elapsed    | 16761    |
# |    total_timesteps | 1194480  |
# | train/             |          |
# |    actor_loss      | -561     |
# |    critic_loss     | 498      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.174    |
# |    learning_rate   | 4.6e-06  |
# |    n_updates       | 1194379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19912    |
# |    fps             | 71       |
# |    time_elapsed    | 16765    |
# |    total_timesteps | 1194720  |
# | train/             |          |
# |    actor_loss      | -570     |
# |    critic_loss     | 591      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.0763  |
# |    learning_rate   | 4.4e-06  |
# |    n_updates       | 1194619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19916    |
# |    fps             | 71       |
# |    time_elapsed    | 16768    |
# |    total_timesteps | 1194960  |
# | train/             |          |
# |    actor_loss      | -575     |
# |    critic_loss     | 582      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.343    |
# |    learning_rate   | 4.2e-06  |
# |    n_updates       | 1194859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19920    |
# |    fps             | 71       |
# |    time_elapsed    | 16771    |
# |    total_timesteps | 1195200  |
# | train/             |          |
# |    actor_loss      | -552     |
# |    critic_loss     | 579      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0333   |
# |    learning_rate   | 4e-06    |
# |    n_updates       | 1195099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 19924    |
# |    fps             | 71       |
# |    time_elapsed    | 16775    |
# |    total_timesteps | 1195440  |
# | train/             |          |
# |    actor_loss      | -522     |
# |    critic_loss     | 509      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0367   |
# |    learning_rate   | 3.8e-06  |
# |    n_updates       | 1195339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19928    |
# |    fps             | 71       |
# |    time_elapsed    | 16778    |
# |    total_timesteps | 1195680  |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 1.35e+03 |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0596   |
# |    learning_rate   | 3.6e-06  |
# |    n_updates       | 1195579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19932    |
# |    fps             | 71       |
# |    time_elapsed    | 16781    |
# |    total_timesteps | 1195920  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 954      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0453   |
# |    learning_rate   | 3.4e-06  |
# |    n_updates       | 1195819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19936    |
# |    fps             | 71       |
# |    time_elapsed    | 16785    |
# |    total_timesteps | 1196160  |
# | train/             |          |
# |    actor_loss      | -565     |
# |    critic_loss     | 419      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.0705  |
# |    learning_rate   | 3.2e-06  |
# |    n_updates       | 1196059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19940    |
# |    fps             | 71       |
# |    time_elapsed    | 16788    |
# |    total_timesteps | 1196400  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.00847 |
# |    learning_rate   | 3e-06    |
# |    n_updates       | 1196299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19944    |
# |    fps             | 71       |
# |    time_elapsed    | 16792    |
# |    total_timesteps | 1196640  |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 475      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 2.8e-06  |
# |    n_updates       | 1196539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19948    |
# |    fps             | 71       |
# |    time_elapsed    | 16795    |
# |    total_timesteps | 1196880  |
# | train/             |          |
# |    actor_loss      | -571     |
# |    critic_loss     | 891      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.261    |
# |    learning_rate   | 2.6e-06  |
# |    n_updates       | 1196779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19952    |
# |    fps             | 71       |
# |    time_elapsed    | 16798    |
# |    total_timesteps | 1197120  |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 1.12e+03 |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 2.4e-06  |
# |    n_updates       | 1197019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19956    |
# |    fps             | 71       |
# |    time_elapsed    | 16802    |
# |    total_timesteps | 1197360  |
# | train/             |          |
# |    actor_loss      | -599     |
# |    critic_loss     | 417      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.083    |
# |    learning_rate   | 2.2e-06  |
# |    n_updates       | 1197259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19960    |
# |    fps             | 71       |
# |    time_elapsed    | 16805    |
# |    total_timesteps | 1197600  |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 397      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.133   |
# |    learning_rate   | 2e-06    |
# |    n_updates       | 1197499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19964    |
# |    fps             | 71       |
# |    time_elapsed    | 16808    |
# |    total_timesteps | 1197840  |
# | train/             |          |
# |    actor_loss      | -562     |
# |    critic_loss     | 528      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.208   |
# |    learning_rate   | 1.8e-06  |
# |    n_updates       | 1197739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19968    |
# |    fps             | 71       |
# |    time_elapsed    | 16812    |
# |    total_timesteps | 1198080  |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 492      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.0319  |
# |    learning_rate   | 1.6e-06  |
# |    n_updates       | 1197979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19972    |
# |    fps             | 71       |
# |    time_elapsed    | 16815    |
# |    total_timesteps | 1198320  |
# | train/             |          |
# |    actor_loss      | -552     |
# |    critic_loss     | 833      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.0744  |
# |    learning_rate   | 1.4e-06  |
# |    n_updates       | 1198219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19976    |
# |    fps             | 71       |
# |    time_elapsed    | 16818    |
# |    total_timesteps | 1198560  |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 517      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 6.87e-06 |
# |    learning_rate   | 1.2e-06  |
# |    n_updates       | 1198459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19980    |
# |    fps             | 71       |
# |    time_elapsed    | 16822    |
# |    total_timesteps | 1198800  |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 610      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.071    |
# |    learning_rate   | 1e-06    |
# |    n_updates       | 1198699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19984    |
# |    fps             | 71       |
# |    time_elapsed    | 16825    |
# |    total_timesteps | 1199040  |
# | train/             |          |
# |    actor_loss      | -552     |
# |    critic_loss     | 443      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.000854 |
# |    learning_rate   | 8.01e-07 |
# |    n_updates       | 1198939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19988    |
# |    fps             | 71       |
# |    time_elapsed    | 16828    |
# |    total_timesteps | 1199280  |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 648      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0351   |
# |    learning_rate   | 6.01e-07 |
# |    n_updates       | 1199179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 19992    |
# |    fps             | 71       |
# |    time_elapsed    | 16832    |
# |    total_timesteps | 1199520  |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 870      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.01     |
# |    learning_rate   | 4.01e-07 |
# |    n_updates       | 1199419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 19996    |
# |    fps             | 71       |
# |    time_elapsed    | 16835    |
# |    total_timesteps | 1199760  |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 713      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | -0.061   |
# |    learning_rate   | 2.01e-07 |
# |    n_updates       | 1199659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 71       |
# |    time_elapsed    | 16838    |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -562     |
# |    critic_loss     | 569      |
# |    ent_coef        | 0.421    |
# |    ent_coef_loss   | 0.0231   |
# |    learning_rate   | 8.33e-10 |
# |    n_updates       | 1199899  |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Green",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ",
                       name = f"{model_name}_{steps}_rewards",
                       figurepath = FIGURES_PATH )
# Out:
# Model name: SAC_Gausian, Steps: 1200000, Mean: 1096.369, IQR: 227.0, CVaR: -2590.915789473684

# %% [markdown]
# Showing the results of the trained model

# %%
print(model.policy)
# Out:
# MultiInputPolicy(
#   (actor): Actor(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=52, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=4, bias=True)
#     (log_std): Linear(in_features=256, out_features=4, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  1366
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1      -2             0                  0  1362.869675   -2
# 1          2      -4             0                  0  2335.466589   -4
# 2          3      -5             0                  0  2507.540280   -5
# 3          4      -2             0                  0  1640.895835   -2
# 4          5       0             0                  0  1582.232701    0
# 5          6       0             0                  0  1561.458334    0
# 6          7       2             0                  0  1140.969730    2
# 7          8       3             0                  0   952.844753    3
# 8          9       5             0                  0   869.755428    5
# 9         10       6             0                  0   891.827476    6
# 10        11       8             0                  0   793.497880    8
# 11        12       9             0                  0  1044.339787    9
# 12        13      12             0                  0   376.555566   12
# 13        14      12             0                  0   950.427276   12
# 14        15      11             0                  0  1664.444921   11
# 15        16      13             0                  0  1105.499667   13
# 16        17      16             0                  0   787.001014   16
# 17        18      17             0                  0  1249.294787   17
# 18        19      20             0                  0  1058.449142   20
# 19        20      22             0                  0   502.635306   22
# 20        21      21             0                  0   985.963286   21
# 21        22      23             0                  0   385.009963   23
# 22        23      23             0                  0   561.469851   23
# 23        24      23             0                  0  1044.675974   23
# 24        25      25             0                  0   109.959944   25
# 25        26      24             0                  0   741.344595   24
# 26        27      24             0                  0   687.106619   24
# 27        28      24             0                  0  1117.915984   24
# 28        29      26             0                  0   692.769076   26
# 29        30      26             0                  0   868.638857   26
# 30        31      26             0                  0   860.365946   26
# 31        32      26             0                  0   853.488360   26
# 32        33      28             0                  0   292.344609   28
# 33        34      28             0                  0   561.288241   28
# 34        35      28             0                  0   769.657309   28
# 35        36      30             0                  0    70.973940   30
# 36        37      30             0                  0   283.250391   30
# 37        38      30             0                  0   684.568781   30
# 38        39      32             0                  0    72.967177   32
# 39        40      32             0                  0   490.885710   32
# 40        41      32             0                  0   884.287066   32
# 41        42      34             0                  0    96.124156   34
# 42        43      34             0                  0    97.637904   34
# 43        44      33             0                  0   290.120005   33
# 44        45      32             0                  0   666.775401   32
# 45        46      31             0                  0  1443.814700   31
# 46        47      33             0                  0   984.967066   33
# 47        48      35             0                  0   633.962977   35
# 48        49      36             0                  0   127.252871   36
# 49        50      35             0                  0   532.712590   35
# 50        51      34             0                  0  1269.694914   34
# 51        52      36             0                  0   644.560156   36
# 52        53      38             0                  0    79.303856   38
# 53        54      37             0                  0    16.415011   37
# 54        55      36             0                  0   636.110991   36
# 55        56      35             0                  0   884.160750   35
# 56        57      37             0                  0   307.243819   37
# 57        58      37             0                  0   384.114722   37
# 58        59      34             0                  0  1551.269492   34
# 59        60      35             0                  0   488.810500   35
#
#        income  funding_cost  total_funding  total_mortgages
# 0    0.000000     -2.935197          -1360                0
# 1    0.000000     -4.949238          -2331                0
# 2    0.000000     -5.282287          -2501                0
# 3    2.695167     -5.527186          -2632             1000
# 4    6.139471     -6.959407          -3571             2000
# 5    8.551884     -8.309329          -4549             3000
# 6   11.218943     -9.020522          -5126             4000
# 7   13.644896     -9.786821          -5936             5000
# 8   16.247179    -11.002396          -6851             6000
# 9   18.854018    -12.061901          -7871             7000
# 10  21.481685    -13.308396          -8771             8000
# 11  24.102487    -14.831966         -10019             9000
# 12  27.189029    -14.721055         -10350            10000
# 13  27.189029    -14.893415         -10923            10000
# 14  27.189029    -15.894950         -11634            10000
# 15  29.896772    -16.518591         -12073            11000
# 16  32.566665    -16.484254         -12752            12000
# 17  35.128623    -17.492210         -14212            13000
# 18  37.699097    -17.663243         -15020            14000
# 19  40.309680    -18.095445         -15461            15000
# 20  40.309680    -18.694559         -15942            15000
# 21  42.954803    -19.043174         -16338            16000
# 22  42.954803    -19.356255         -16512            16000
# 23  42.954803    -19.719811         -16993            16000
# 24  45.494863    -19.962052         -17057            17000
# 25  45.494863    -20.578662         -17686            17000
# 26  45.494863    -20.613214         -17631            17000
# 27  45.494863    -21.019978         -18059            17000
# 28  47.774612    -21.241870         -18632            18000
# 29  47.774612    -21.336232         -18805            18000
# 30  47.774612    -21.127159         -18794            18000
# 31  47.774612    -21.072830         -18785            18000
# 32  49.988518    -21.098555         -19222            19000
# 33  49.988518    -21.076740         -19490            19000
# 34  49.988518    -21.075372         -19697            19000
# 35  52.098115    -21.124043         -19997            20000
# 36  52.098115    -21.111446         -20207            20000
# 37  52.098115    -21.153657         -20606            20000
# 38  53.915109    -21.271272         -20991            21000
# 39  53.915109    -21.438685         -21407            21000
# 40  53.915109    -21.560597         -21799            21000
# 41  56.267422    -21.679491         -22009            22000
# 42  56.267422    -21.904828         -22008            22000
# 43  56.267422    -22.498690         -22199            22000
# 44  56.267422    -23.361191         -22574            22000
# 45  56.267422    -24.561139         -23349            22000
# 46  58.686457    -25.540022         -23889            23000
# 47  61.432167    -26.382266         -24536            24000
# 48  63.859792    -27.299612         -25027            25000
# 49  63.859792    -28.181813         -25430            25000
# 50  63.859792    -29.221275         -26165            25000
# 51  66.557766    -29.716097         -26538            26000
# 52  69.283015    -30.513935         -26971            27000
# 53  69.283015    -31.347048         -26906            27000
# 54  69.283015    -32.557300         -27523            27000
# 55  69.283015    -33.325733         -27769            27000
# 56  71.694705    -33.862091         -28190            28000
# 57  71.694705    -34.458808         -28264            28000
# 58  69.275670    -34.939934         -28429            27000
# 59  71.233477    -35.341514         -28365            28000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=1225.00 Expected Shortfall=796.20 Interquartile Range=185.50

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")

# %% [markdown]
# It would be great if we can store a local copy of the notebook after execution so I can easily look back at the performed actions...

# %%
from google.colab import runtime
runtime.unassign()
