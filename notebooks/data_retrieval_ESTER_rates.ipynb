# %% [markdown]
# # Data retrieval European Central Bank - Ester rates

# %%
import requests     # 2.18.4
import pandas as pd # 0.23.0
import io

# %%
DATAFLOW = "EST"
FREQ = "B"
DATA_TYPE_FM = "EU000A2QQF16.CR"
start_period = '2019-01-01'
end_period = '2023-03-09'
parameters = {
    "startPeriod": start_period,
    "endPeriod": end_period,
}
url = (
    f"https://sdw-wsrest.ecb.europa.eu/service/data/"
    f"{DATAFLOW}/{FREQ}.{DATA_TYPE_FM}"
)
response = requests.get(url, params=parameters,headers={"Accept": "text/csv"})
# Check if the response returns succesfully with response code 200
print(response)

# Print the full URL
print(response.url)
# Out:
# <Response [200]>
# https://sdw-wsrest.ecb.europa.eu/service/data/EST/B.EU000A2QQF16.CR?startPeriod=2019-01-01&endPeriod=2023-03-09

# %%
# Read the response as a file into a Pandas DataFrame
df = pd.read_csv(io.StringIO(response.text))

# %%
# Check the DataFrame's information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   KEY                880 non-null    object
#  1   FREQ               880 non-null    object
#  2   BENCHMARK_ITEM     880 non-null    object
#  3   DATA_TYPE_EST      880 non-null    object
#  4   TIME_PERIOD        880 non-null    object
#  5   OBS_VALUE          880 non-null    float64
#  6   OBS_STATUS         880 non-null    object
#  7   CONF_STATUS        880 non-null    object
#  8   PRE_BREAK_VALUE    0 non-null      float64
#  9   COMMENT_OBS        0 non-null      float64
#  10  CALCUL_START_DATE  0 non-null      float64
#  11  CALCUL_END_DATE    0 non-null      float64
#  12  TIME_FORMAT        880 non-null    object
#  13  BREAKS             0 non-null      float64
#  14  COMMENT_TS         0 non-null      float64
#  15  COMPILING_ORG      0 non-null      float64
#  16  COVERAGE           880 non-null    object
#  17  DATA_COMP          0 non-null      float64
#  18  DECIMALS           880 non-null    int64
#  19  DISS_ORG           0 non-null      float64
#  20  PUBL_ECB           0 non-null      float64
#  21  PUBL_MU            0 non-null      float64
#  22  PUBL_PUBLIC        0 non-null      float64
#  23  TIME_PER_COLLECT   0 non-null      float64
#  24  TITLE              880 non-null    object
#  25  TITLE_COMPL        880 non-null    object
#  26  UNIT_INDEX_BASE    0 non-null      float64
#  27  UNIT_MEASURE       0 non-null      float64
#  28  UNIT_MULT          880 non-null    int64
# dtypes: float64(16), int64(2), object(11)
# memory usage: 199.5+ KB

# %%
# Show the last 5 entries of the DataFrame
df.tail()
# Out:
#                        KEY FREQ BENCHMARK_ITEM DATA_TYPE_EST TIME_PERIOD  \
# 875  EST.B.EU000A2QQF16.CR    B   EU000A2QQF16            CR  2023-03-03
# 876  EST.B.EU000A2QQF16.CR    B   EU000A2QQF16            CR  2023-03-06
# 877  EST.B.EU000A2QQF16.CR    B   EU000A2QQF16            CR  2023-03-07
# 878  EST.B.EU000A2QQF16.CR    B   EU000A2QQF16            CR  2023-03-08
# 879  EST.B.EU000A2QQF16.CR    B   EU000A2QQF16            CR  2023-03-09
#
#      OBS_VALUE OBS_STATUS CONF_STATUS  PRE_BREAK_VALUE  COMMENT_OBS  ...  \
# 875    2.39712          A           F              NaN          NaN  ...
# 876    2.39798          A           F              NaN          NaN  ...
# 877    2.39812          A           F              NaN          NaN  ...
# 878    2.39955          A           F              NaN          NaN  ...
# 879    2.39970          A           F              NaN          NaN  ...
#
#      DISS_ORG  PUBL_ECB PUBL_MU  PUBL_PUBLIC  TIME_PER_COLLECT  \
# 875       NaN       NaN     NaN          NaN               NaN
# 876       NaN       NaN     NaN          NaN               NaN
# 877       NaN       NaN     NaN          NaN               NaN
# 878       NaN       NaN     NaN          NaN               NaN
# 879       NaN       NaN     NaN          NaN               NaN
#
#                                                  TITLE  \
# 875  Compounded euro short-term rate average rate, ...
# 876  Compounded euro short-term rate average rate, ...
# 877  Compounded euro short-term rate average rate, ...
# 878  Compounded euro short-term rate average rate, ...
# 879  Compounded euro short-term rate average rate, ...
#
#                                            TITLE_COMPL  UNIT_INDEX_BASE  \
# 875  Compounded euro short-term rate average rate, ...              NaN
# 876  Compounded euro short-term rate average rate, ...              NaN
# 877  Compounded euro short-term rate average rate, ...              NaN
# 878  Compounded euro short-term rate average rate, ...              NaN
# 879  Compounded euro short-term rate average rate, ...              NaN
#
#      UNIT_MEASURE  UNIT_MULT
# 875           NaN          0
# 876           NaN          0
# 877           NaN          0
# 878           NaN          0
# 879           NaN          0
#
# [5 rows x 29 columns]

# %%
# Create a new DataFrame called 'ts'
ts = df.filter(['TIME_PERIOD', 'BENCHMARK_ITEM', 'OBS_VALUE'], axis=1)
# 'TIME_PERIOD' was of type 'object' (as seen in df.info). Convert it to datetime first
ts['TIME_PERIOD'] = pd.to_datetime(ts['TIME_PERIOD'])
# Set 'TIME_PERIOD' to be the index
ts = ts.set_index('TIME_PERIOD')
# Print the last 5 rows to screen
ts.tail()
# Out:
#             BENCHMARK_ITEM  OBS_VALUE
# TIME_PERIOD
# 2023-03-03    EU000A2QQF16    2.39712
# 2023-03-06    EU000A2QQF16    2.39798
# 2023-03-07    EU000A2QQF16    2.39812
# 2023-03-08    EU000A2QQF16    2.39955
# 2023-03-09    EU000A2QQF16    2.39970

# %%
# %matplotlib inline
ts.plot()
# Out:
# <AxesSubplot:xlabel='TIME_PERIOD'>
