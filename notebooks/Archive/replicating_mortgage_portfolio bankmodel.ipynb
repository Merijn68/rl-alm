# %% [markdown]
# # Reinforcement Learning Environment for ALM
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### Simulating a mortgage portfolio
#
# Mortgages typically have a lineair interest rate model - where the monthly prepayment is fixed, or use an annualized schema - in which interest plus prepayment makes a fixed amount per month. To start, we model all mortgages with the lineair interest rate model.
#
# See also: https://riskatwork.nl/wp-content/uploads/2019/11/RAW-MortgagePrepayments.pdf
#
# Customers normally have the option to re-pay the mortgage earlier then the maturity / repricing data.  In general a bank loan may not be held until maturity because:
# * Customers repay the loan early (as a percentage of the loan, or fully when moving)
# * Customers can default on the loan - forcing the bank to write off the loan
#
# Growth and new business
# Customers can choose the fixed interest period they select. Their choice will be influenced by market expectations, and the rates offered by the bank.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
from dateutil.parser import parse

from src.models.bank_model import Bankmodel
from src.data.zerocurve import Zerocurve
from src.data.interest import Interest
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Create interest rates and zero curves

# %%
# Create data objects
zerocurve = Zerocurve()
interest = Interest()

# %% [markdown]
# Read data from the ECB Statistical Data Warehouse

# %%
# Get zero curve historic rates
zerocurve.read_data()
# Get mortgage historic rates
interest.read_data()
# Out:
# 2023-05-01 16:05:05.513 | INFO     | src.data.dataset:read_data:26 - reading zerocurve data from ESW.
# 2023-05-01 16:05:08.725 | INFO     | src.data.dataset:read_data:26 - reading interest data from ESW.
# <Response [200]>

# %%
interest.lineplot()

# %%
zerocurve.save_data()
interest.save_data()
# Out:
# 2023-05-01 16:05:28.891 | INFO     | src.data.dataset:save_data:55 - saving zerocurve data to file.
# 2023-05-01 16:05:29.265 | INFO     | src.data.dataset:save_data:55 - saving interest data to file.

# %%
# Load data from csv file - not directly from ECB
zerocurve.load_data()
interest.load_data()
# Out:
# 2023-05-01 16:05:36.262 | INFO     | src.data.dataset:load_data:45 - loading zerocurve data from file.
# 2023-05-01 16:05:36.470 | INFO     | src.data.dataset:load_data:45 - loading interest data from file.

# %% [markdown]
# Generate a Bank model

# %%
pos_date = zerocurve.df.index[-1]
bankmodel = Bankmodel(pos_date )

# %% [markdown]
# Generate Mortgage contracts

# %%
bankmodel.generate_mortgage_contracts(n = 100, df_i = interest.df,amount = 100000)
bankmodel.df_mortgages.head()
bankmodel.plot_contracts();
# Out:
# 2023-05-01 16:05:41.960 | INFO     | src.models.bank_model:generate_mortgage_contracts:134 - Added 100 mortgages to our portfolio.
# 2023-05-01 16:05:44.160 | INFO     | src.models.bank_model:generate_mortgage_contracts:138 - Added 35044 cashflows to our model.

# %% [markdown]
# ### Non Maturity Deposits
#
# This included saving and current accounts.
#
# - Core vs Non Core balances
#
# For saving deposits a cap on the average maturity of the core deposits is set at 4.5 years.
# In general 70% - 90% of the deposits can be classied as core capital. (See guidelines BCBS)

# %%
bankmodel.generate_nonmaturing_deposits(principal = 9000000, core = 0.4, maturity = 54)
# Out:
#    period  cashflow cashflow_type   value_dt      type rate_type  contract_no
# 0       1  -5400000     principal 2023-04-28  deposits     fixed            0
# 1       2  -3600000     principal 2027-10-27  deposits     fixed            0

# %% [markdown]
# ### Funding

# %%
pos_date = zerocurve.df.index[-1]
rate = zerocurve.df.loc[pos_date].query('tenor == 120')['rate'][0]
df_cashflows = bankmodel.generate_funding(principal = 1000000, rate = rate, maturity = 120)
df_cashflows
# Out:
# 2023-05-01 16:05:50.813 | INFO     | src.models.bank_model:generate_funding:362 - Added 1000000 amount in capital market funding to our model.
#     period   cashflow cashflow_type   value_dt     type rate_type  contract_no
# 0        0 1000000.00     principal 2023-04-27  Funding     fixed            0
# 1        0  -27534.00      interest 2023-04-27  Funding     fixed            0
# 2        1  -27534.00      interest 2024-04-29  Funding     fixed            0
# 3        2  -27534.00      interest 2025-04-28  Funding     fixed            0
# 4        3  -27534.00      interest 2026-04-27  Funding     fixed            0
# 5        4  -27534.00      interest 2027-04-27  Funding     fixed            0
# 6        5  -27534.00      interest 2028-04-27  Funding     fixed            0
# 7        6  -27534.00      interest 2029-04-27  Funding     fixed            0
# 8        7  -27534.00      interest 2030-04-29  Funding     fixed            0
# 9        8  -27534.00      interest 2031-04-28  Funding     fixed            0
# 10       9  -27534.00      interest 2032-04-27  Funding     fixed            0

# %% [markdown]
# ### Cashflow model of the bank

# %%
bankmodel.plot_cashflows()

# %% [markdown]
# ### npv calculation
#
# $$NPV = {{Cashflow} \over (1+i)^T}.$$
# $$DF_0^T = [1+R_{zc}]^{-T})$$
# where:
# - $DF_0^T$  = a discount factor with maturity T
# - $R_{zc}$ = A zero coupon interest rate
# - $T$ = Maturity of the zero rate, in years (calculated as days/365)

# %%
result = bankmodel.calculate_npv(zerocurve, bankmodel.df_cashflows, bankmodel.pos_date)
print (f"npv = {sum(result['npv']):,.0f}")
# Out:
# npv = -5,612,693

# %%
r1 = bankmodel.calculate_risk(zerocurve,200,'Parallel')
print (f"r1 = {r1:,.0f}")
# Out:
# r1 = -19,729

# %% [markdown]
# ### SOT (Supervisor Outlier Test)

# %%
bankmodel.step()
zerocurve.step()
result = bankmodel.calculate_npv(zerocurve,bankmodel.df_cashflows, bankmodel.pos_date)
print (f"npv = {sum(result['npv']):,.0f}")
r1 = bankmodel.calculate_risk(zerocurve,200,'Parallel')
print (f"r1 = {r1:,.0f}")
# Out:
# 2023-05-01 16:06:16.409 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2023-04-28 00:00:00.
# npv = -5,620,344
# r1 = -19,194

# %% [markdown]
# ### Calculate BPV
#
# Risk paramters include BPV (Base Point Value), also called DV01 (Dollar value of 1).
# This is the potential change in the EvE (Economic value of Equity), if we see a 1 bp (basispoint) shift in the zero curve.
#
# So we shift each point on the zero curve by one bp, and recalculate the NPV under each of these scenario's.
# The NPV is then calculated by sutracting the NPV under the base scenario from the NPV under the shifted scenario.

# %%
from src.data.definitions import DATA_RAW
from src.visualization import visualize
from pathlib import Path
bpv = bankmodel.calculate_bpv(zerocurve)
limits = pd.read_excel(Path(DATA_RAW,'limits.xlsx'))
visualize.bpvplot(bpv, limits, title = f'BPV Profile {pos_date:%d-%m-%Y}');

# %%
bankmodel.clear_swap_contracts()

# %%
bankmodel.generate_swap_contract('sell', 84, zerocurve, amount = 150000000)
bankmodel.generate_swap_contract('buy',48, zerocurve, amount = 150000000)
# Out:
# 2023-05-01 16:06:31.168 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 1 swaps in total.
# 2023-05-01 16:06:31.231 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 2 swaps in total.

# %%
result = bankmodel.calculate_npv(zerocurve, bankmodel.df_cashflows, bankmodel.pos_date)
print (f"npv = {sum(result['npv']):,.0f}")
# zerocurve.df.to_excel('zerocurve.xlsx')
# Out:
# npv = -5,849,118

# %%
bankmodel.generate_swap_contract('sell',120, zerocurve, amount = 2800000)
bankmodel.generate_swap_contract('sell',60, zerocurve, amount = 40000000)
bankmodel.generate_swap_contract('buy',48, zerocurve, amount = 40000000)
# Out:
# 2023-05-01 16:06:40.795 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 3 swaps in total.
# 2023-05-01 16:06:40.874 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 4 swaps in total.
# 2023-05-01 16:06:40.940 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 5 swaps in total.

# %%
bpv = bankmodel.calculate_bpv(zerocurve)
from src.data.definitions import DATA_RAW
from src.visualization import visualize
from pathlib import Path
limits = pd.read_excel(Path(DATA_RAW,'limits.xlsx'))
visualize.bpvplot(bpv, limits, title = f'BPV Profile {pos_date:%d-%m-%Y}');

# %%
result = bankmodel.calculate_npv(zerocurve, bankmodel.df_cashflows, bankmodel.pos_date)
print (f"npv = {sum(result['npv']):,.0f}")
# Out:
# npv = -5,903,585

# %% [markdown]
# # Running an episode
#
# Running an episode means we run through one possible trajectory of the bank - in the simualted environment.
# Offcourse now this is still without any steering.
#
# We use monte carlo simulation to step through a number of timesteps, and see the results in return and risk the bank is exposed to.
# In order to generate the scenario's for monte carlo simulation it is necesarry to tackle the challange of correlated variables in Monte Carlo simulations.
# Because in practice there is a strong correlation to these environmental factors. If we ignore this - the simulation would be made on unrealistic - unfeasible situations.
# There are several ways to do this.
#
# Multivariate distrubtion.
# Copulas may help if the correlation. But there is a simpler way. We can rely on historical simulation were we take growth rate sampled from the history. It is just important that we take the same sample date for each of the simulated variables.  That sounds very easy, and would work - if we have all factors for the same dates!
#
# There are several alternatives for creating simuation of the Zero Curves. Which take into account multiple correlation, and the specific dynamics assosiated with yield curve construction. In furter research we could analyze if this would make any difference.
# - Box-Muller Method
# - Iman-Conover Method
# - Vasicek factor 2 model
# - Georgian Brown Movements, with cholesky decomposition
# - Copulas (?)

# %%
# run an episode of 100 steps

for i in range(252):
#    bankmodel.step()
    zerocurve.step(1)
#    risk.append(bankmodel.calculate_risk(zerocurve,200,'Parallel'))    
zerocurve.lineplot()
# Out:
# 2023-05-01 16:49:41.826 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-01-06 00:00:00.
# 2023-05-01 16:49:41.872 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-01-20 00:00:00.
# 2023-05-01 16:49:41.901 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-02-03 00:00:00.
# 2023-05-01 16:49:41.922 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-02-17 00:00:00.
# 2023-05-01 16:49:41.939 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-03-03 00:00:00.
# 2023-05-01 16:49:41.956 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-03-17 00:00:00.
# 2023-05-01 16:49:41.975 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-03-31 00:00:00.
# 2023-05-01 16:49:41.991 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-04-14 00:00:00.
# 2023-05-01 16:49:42.016 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-04-28 00:00:00.
# 2023-05-01 16:49:42.045 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-05-12 00:00:00.
# 2023-05-01 16:49:42.069 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-05-26 00:00:00.
# 2023-05-01 16:49:42.092 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-06-09 00:00:00.
# 2023-05-01 16:49:42.107 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-06-23 00:00:00.
# 2023-05-01 16:49:42.123 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-07-07 00:00:00.
# 2023-05-01 16:49:42.145 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-07-21 00:00:00.
# 2023-05-01 16:49:42.167 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-08-04 00:00:00.
# 2023-05-01 16:49:42.187 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-08-18 00:00:00.
# 2023-05-01 16:49:42.209 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-09-01 00:00:00.
# 2023-05-01 16:49:42.230 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-09-15 00:00:00.
# 2023-05-01 16:49:42.249 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-09-29 00:00:00.
# 2023-05-01 16:49:42.268 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-10-13 00:00:00.
# 2023-05-01 16:49:42.289 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-10-27 00:00:00.
# 2023-05-01 16:49:42.312 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-11-10 00:00:00.
# 2023-05-01 16:49:42.333 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-11-24 00:00:00.
# 2023-05-01 16:49:42.352 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-12-08 00:00:00.
# 2023-05-01 16:49:42.370 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2033-12-22 00:00:00.
# 2023-05-01 16:49:42.391 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-01-05 00:00:00.
# 2023-05-01 16:49:42.408 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-01-19 00:00:00.
# 2023-05-01 16:49:42.427 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-02-02 00:00:00.
# 2023-05-01 16:49:42.443 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-02-16 00:00:00.
# 2023-05-01 16:49:42.462 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-03-02 00:00:00.
# 2023-05-01 16:49:42.484 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-03-16 00:00:00.
# 2023-05-01 16:49:42.507 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-03-30 00:00:00.
# 2023-05-01 16:49:42.523 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-04-13 00:00:00.
# 2023-05-01 16:49:42.540 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-04-27 00:00:00.
# 2023-05-01 16:49:42.555 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-05-11 00:00:00.
# 2023-05-01 16:49:42.571 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-05-25 00:00:00.
# 2023-05-01 16:49:42.589 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-06-08 00:00:00.
# 2023-05-01 16:49:42.606 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-06-22 00:00:00.
# 2023-05-01 16:49:42.624 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-07-06 00:00:00.
# 2023-05-01 16:49:42.640 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-07-20 00:00:00.
# 2023-05-01 16:49:42.662 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-08-03 00:00:00.
# 2023-05-01 16:49:42.694 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-08-17 00:00:00.
# 2023-05-01 16:49:42.711 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-08-31 00:00:00.
# 2023-05-01 16:49:42.727 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-09-14 00:00:00.
# 2023-05-01 16:49:42.742 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-09-28 00:00:00.
# 2023-05-01 16:49:42.758 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-10-12 00:00:00.
# 2023-05-01 16:49:42.774 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-10-26 00:00:00.
# 2023-05-01 16:49:42.789 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-11-09 00:00:00.
# 2023-05-01 16:49:42.808 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-11-23 00:00:00.
# 2023-05-01 16:49:42.826 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-12-07 00:00:00.
# 2023-05-01 16:49:42.842 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2034-12-21 00:00:00.
# 2023-05-01 16:49:42.857 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-01-04 00:00:00.
# 2023-05-01 16:49:42.873 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-01-18 00:00:00.
# 2023-05-01 16:49:42.889 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-02-01 00:00:00.
# 2023-05-01 16:49:42.908 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-02-15 00:00:00.
# 2023-05-01 16:49:42.924 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-03-01 00:00:00.
# 2023-05-01 16:49:42.940 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-03-15 00:00:00.
# 2023-05-01 16:49:42.956 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-03-29 00:00:00.
# 2023-05-01 16:49:43.008 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-04-12 00:00:00.
# 2023-05-01 16:49:43.034 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-04-26 00:00:00.
# 2023-05-01 16:49:43.060 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-05-10 00:00:00.
# 2023-05-01 16:49:43.087 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-05-24 00:00:00.
# 2023-05-01 16:49:43.108 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-06-07 00:00:00.
# 2023-05-01 16:49:43.126 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-06-21 00:00:00.
# 2023-05-01 16:49:43.145 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-07-05 00:00:00.
# 2023-05-01 16:49:43.163 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-07-19 00:00:00.
# 2023-05-01 16:49:43.182 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-08-02 00:00:00.
# 2023-05-01 16:49:43.200 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-08-16 00:00:00.
# 2023-05-01 16:49:43.219 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-08-30 00:00:00.
# 2023-05-01 16:49:43.236 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-09-13 00:00:00.
# 2023-05-01 16:49:43.254 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-09-27 00:00:00.
# 2023-05-01 16:49:43.272 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-10-11 00:00:00.
# 2023-05-01 16:49:43.289 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-10-25 00:00:00.
# 2023-05-01 16:49:43.307 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-11-08 00:00:00.
# 2023-05-01 16:49:43.328 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-11-22 00:00:00.
# 2023-05-01 16:49:43.348 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-12-06 00:00:00.
# 2023-05-01 16:49:43.366 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2035-12-20 00:00:00.
# 2023-05-01 16:49:43.385 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-01-03 00:00:00.
# 2023-05-01 16:49:43.407 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-01-17 00:00:00.
# 2023-05-01 16:49:43.425 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-01-31 00:00:00.
# 2023-05-01 16:49:43.441 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-02-14 00:00:00.
# 2023-05-01 16:49:43.458 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-02-28 00:00:00.
# 2023-05-01 16:49:43.474 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-03-13 00:00:00.
# 2023-05-01 16:49:43.490 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-03-27 00:00:00.
# 2023-05-01 16:49:43.505 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-04-10 00:00:00.
# 2023-05-01 16:49:43.521 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-04-24 00:00:00.
# 2023-05-01 16:49:43.538 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-05-08 00:00:00.
# 2023-05-01 16:49:43.556 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-05-22 00:00:00.
# 2023-05-01 16:49:43.576 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-06-05 00:00:00.
# 2023-05-01 16:49:43.596 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-06-19 00:00:00.
# 2023-05-01 16:49:43.614 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-07-03 00:00:00.
# 2023-05-01 16:49:43.633 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-07-17 00:00:00.
# 2023-05-01 16:49:43.650 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-07-31 00:00:00.
# 2023-05-01 16:49:43.674 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-08-14 00:00:00.
# 2023-05-01 16:49:43.693 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-08-28 00:00:00.
# 2023-05-01 16:49:43.710 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-09-11 00:00:00.
# 2023-05-01 16:49:43.726 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-09-25 00:00:00.
# 2023-05-01 16:49:43.742 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-10-09 00:00:00.
# 2023-05-01 16:49:43.757 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-10-23 00:00:00.
# 2023-05-01 16:49:43.774 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-11-06 00:00:00.
# 2023-05-01 16:49:43.790 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-11-20 00:00:00.
# 2023-05-01 16:49:43.810 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-12-04 00:00:00.
# 2023-05-01 16:49:43.827 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2036-12-18 00:00:00.
# 2023-05-01 16:49:43.844 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-01-01 00:00:00.
# 2023-05-01 16:49:43.859 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-01-15 00:00:00.
# 2023-05-01 16:49:43.874 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-01-29 00:00:00.
# 2023-05-01 16:49:43.893 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-02-12 00:00:00.
# 2023-05-01 16:49:43.909 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-02-26 00:00:00.
# 2023-05-01 16:49:43.925 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-03-12 00:00:00.
# 2023-05-01 16:49:43.942 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-03-26 00:00:00.
# 2023-05-01 16:49:43.959 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-04-09 00:00:00.
# 2023-05-01 16:49:43.978 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-04-23 00:00:00.
# 2023-05-01 16:49:43.995 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-05-07 00:00:00.
# 2023-05-01 16:49:44.012 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-05-21 00:00:00.
# 2023-05-01 16:49:44.027 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-06-04 00:00:00.
# 2023-05-01 16:49:44.043 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-06-18 00:00:00.
# 2023-05-01 16:49:44.063 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-07-02 00:00:00.
# 2023-05-01 16:49:44.080 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-07-16 00:00:00.
# 2023-05-01 16:49:44.097 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-07-30 00:00:00.
# 2023-05-01 16:49:44.113 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-08-13 00:00:00.
# 2023-05-01 16:49:44.129 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-08-27 00:00:00.
# 2023-05-01 16:49:44.144 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-09-10 00:00:00.
# 2023-05-01 16:49:44.160 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-09-24 00:00:00.
# 2023-05-01 16:49:44.186 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-10-08 00:00:00.
# 2023-05-01 16:49:44.202 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-10-22 00:00:00.
# 2023-05-01 16:49:44.219 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-11-05 00:00:00.
# 2023-05-01 16:49:44.235 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-11-19 00:00:00.
# 2023-05-01 16:49:44.252 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-12-03 00:00:00.
# 2023-05-01 16:49:44.271 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-12-17 00:00:00.
# 2023-05-01 16:49:44.286 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2037-12-31 00:00:00.
# 2023-05-01 16:49:44.303 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-01-14 00:00:00.
# 2023-05-01 16:49:44.319 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-01-28 00:00:00.
# 2023-05-01 16:49:44.336 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-02-11 00:00:00.
# 2023-05-01 16:49:44.353 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-02-25 00:00:00.
# 2023-05-01 16:49:44.368 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-03-11 00:00:00.
# 2023-05-01 16:49:44.388 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-03-25 00:00:00.
# 2023-05-01 16:49:44.403 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-04-08 00:00:00.
# 2023-05-01 16:49:44.420 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-04-22 00:00:00.
# 2023-05-01 16:49:44.436 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-05-06 00:00:00.
# 2023-05-01 16:49:44.453 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-05-20 00:00:00.
# 2023-05-01 16:49:44.470 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-06-03 00:00:00.
# 2023-05-01 16:49:44.486 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-06-17 00:00:00.
# 2023-05-01 16:49:44.501 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-07-01 00:00:00.
# 2023-05-01 16:49:44.519 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-07-15 00:00:00.
# 2023-05-01 16:49:44.537 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-07-29 00:00:00.
# 2023-05-01 16:49:44.553 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-08-12 00:00:00.
# 2023-05-01 16:49:44.571 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-08-26 00:00:00.
# 2023-05-01 16:49:44.588 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-09-09 00:00:00.
# 2023-05-01 16:49:44.603 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-09-23 00:00:00.
# 2023-05-01 16:49:44.619 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-10-07 00:00:00.
# 2023-05-01 16:49:44.636 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-10-21 00:00:00.
# 2023-05-01 16:49:44.655 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-11-04 00:00:00.
# 2023-05-01 16:49:44.679 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-11-18 00:00:00.
# 2023-05-01 16:49:44.703 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-12-02 00:00:00.
# 2023-05-01 16:49:44.732 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-12-16 00:00:00.
# 2023-05-01 16:49:44.760 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2038-12-30 00:00:00.
# 2023-05-01 16:49:44.790 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-01-13 00:00:00.
# 2023-05-01 16:49:44.812 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-01-27 00:00:00.
# 2023-05-01 16:49:44.836 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-02-10 00:00:00.
# 2023-05-01 16:49:44.854 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-02-24 00:00:00.
# 2023-05-01 16:49:44.871 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-03-10 00:00:00.
# 2023-05-01 16:49:44.889 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-03-24 00:00:00.
# 2023-05-01 16:49:44.906 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-04-07 00:00:00.
# 2023-05-01 16:49:44.922 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-04-21 00:00:00.
# 2023-05-01 16:49:44.939 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-05-05 00:00:00.
# 2023-05-01 16:49:44.956 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-05-19 00:00:00.
# 2023-05-01 16:49:44.972 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-06-02 00:00:00.
# 2023-05-01 16:49:44.988 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-06-16 00:00:00.
# 2023-05-01 16:49:45.006 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-06-30 00:00:00.
# 2023-05-01 16:49:45.030 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-07-14 00:00:00.
# 2023-05-01 16:49:45.050 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-07-28 00:00:00.
# 2023-05-01 16:49:45.071 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-08-11 00:00:00.
# 2023-05-01 16:49:45.092 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-08-25 00:00:00.
# 2023-05-01 16:49:45.115 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-09-08 00:00:00.
# 2023-05-01 16:49:45.135 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-09-22 00:00:00.
# 2023-05-01 16:49:45.153 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-10-06 00:00:00.
# 2023-05-01 16:49:45.171 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-10-20 00:00:00.
# 2023-05-01 16:49:45.185 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-11-03 00:00:00.
# 2023-05-01 16:49:45.204 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-11-17 00:00:00.
# 2023-05-01 16:49:45.221 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-12-01 00:00:00.
# 2023-05-01 16:49:45.238 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-12-15 00:00:00.
# 2023-05-01 16:49:45.255 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2039-12-29 00:00:00.
# 2023-05-01 16:49:45.272 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-01-12 00:00:00.
# 2023-05-01 16:49:45.290 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-01-26 00:00:00.
# 2023-05-01 16:49:45.306 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-02-09 00:00:00.
# 2023-05-01 16:49:45.328 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-02-23 00:00:00.
# 2023-05-01 16:49:45.348 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-03-08 00:00:00.
# 2023-05-01 16:49:45.367 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-03-22 00:00:00.
# 2023-05-01 16:49:45.382 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-04-05 00:00:00.
# 2023-05-01 16:49:45.404 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-04-19 00:00:00.
# 2023-05-01 16:49:45.427 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-05-03 00:00:00.
# 2023-05-01 16:49:45.446 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-05-17 00:00:00.
# 2023-05-01 16:49:45.465 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-05-31 00:00:00.
# 2023-05-01 16:49:45.486 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-06-14 00:00:00.
# 2023-05-01 16:49:45.506 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-06-28 00:00:00.
# 2023-05-01 16:49:45.522 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-07-12 00:00:00.
# 2023-05-01 16:49:45.540 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-07-26 00:00:00.
# 2023-05-01 16:49:45.558 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-08-09 00:00:00.
# 2023-05-01 16:49:45.574 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-08-23 00:00:00.
# 2023-05-01 16:49:45.590 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-09-06 00:00:00.
# 2023-05-01 16:49:45.607 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-09-20 00:00:00.
# 2023-05-01 16:49:45.623 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-10-04 00:00:00.
# 2023-05-01 16:49:45.653 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-10-18 00:00:00.
# 2023-05-01 16:49:45.673 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-11-01 00:00:00.
# 2023-05-01 16:49:45.690 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-11-15 00:00:00.
# 2023-05-01 16:49:45.706 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-11-29 00:00:00.
# 2023-05-01 16:49:45.722 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-12-13 00:00:00.
# 2023-05-01 16:49:45.737 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2040-12-27 00:00:00.
# 2023-05-01 16:49:45.754 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-01-10 00:00:00.
# 2023-05-01 16:49:45.770 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-01-24 00:00:00.
# 2023-05-01 16:49:45.788 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-02-07 00:00:00.
# 2023-05-01 16:49:45.803 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-02-21 00:00:00.
# 2023-05-01 16:49:45.819 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-03-07 00:00:00.
# 2023-05-01 16:49:45.836 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-03-21 00:00:00.
# 2023-05-01 16:49:45.856 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-04-04 00:00:00.
# 2023-05-01 16:49:45.874 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-04-18 00:00:00.
# 2023-05-01 16:49:45.895 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-05-02 00:00:00.
# 2023-05-01 16:49:45.912 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-05-16 00:00:00.
# 2023-05-01 16:49:45.928 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-05-30 00:00:00.
# 2023-05-01 16:49:45.945 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-06-13 00:00:00.
# 2023-05-01 16:49:45.963 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-06-27 00:00:00.
# 2023-05-01 16:49:45.979 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-07-11 00:00:00.
# 2023-05-01 16:49:45.995 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-07-25 00:00:00.
# 2023-05-01 16:49:46.014 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-08-08 00:00:00.
# 2023-05-01 16:49:46.035 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-08-22 00:00:00.
# 2023-05-01 16:49:46.054 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-09-05 00:00:00.
# 2023-05-01 16:49:46.074 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-09-19 00:00:00.
# 2023-05-01 16:49:46.092 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-10-03 00:00:00.
# 2023-05-01 16:49:46.108 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-10-17 00:00:00.
# 2023-05-01 16:49:46.124 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-10-31 00:00:00.
# 2023-05-01 16:49:46.143 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-11-14 00:00:00.
# 2023-05-01 16:49:46.163 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-11-28 00:00:00.
# 2023-05-01 16:49:46.180 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-12-12 00:00:00.
# 2023-05-01 16:49:46.197 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2041-12-26 00:00:00.
# 2023-05-01 16:49:46.213 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-01-09 00:00:00.
# 2023-05-01 16:49:46.229 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-01-23 00:00:00.
# 2023-05-01 16:49:46.247 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-02-06 00:00:00.
# 2023-05-01 16:49:46.266 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-02-20 00:00:00.
# 2023-05-01 16:49:46.281 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-03-06 00:00:00.
# 2023-05-01 16:49:46.297 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-03-20 00:00:00.
# 2023-05-01 16:49:46.314 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-04-03 00:00:00.
# 2023-05-01 16:49:46.331 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-04-17 00:00:00.
# 2023-05-01 16:49:46.348 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-05-01 00:00:00.
# 2023-05-01 16:49:46.366 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-05-15 00:00:00.
# 2023-05-01 16:49:46.382 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-05-29 00:00:00.
# 2023-05-01 16:49:46.399 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-06-12 00:00:00.
# 2023-05-01 16:49:46.416 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-06-26 00:00:00.
# 2023-05-01 16:49:46.434 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-07-10 00:00:00.
# 2023-05-01 16:49:46.453 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-07-24 00:00:00.
# 2023-05-01 16:49:46.470 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-08-07 00:00:00.
# 2023-05-01 16:49:46.489 | DEBUG    | src.data.zerocurve:step:123 - Stepping in zerocurve 2042-08-21 00:00:00.

# %% [markdown]
# At the end of the episode we need to reset the bank to the original situation.

# %%
bankmodel.reset()
zerocurve.reset()

# %% [markdown]
# Buy or Sell Swaps to steer the interest profile

# %%
# Buy Fixed 30 year / sell swap Float 6M 
# Example deal 5390831 25 mln
# Pay interest Annual Swaprate 20y = 2.3 contract rate 3.059 fixed (aprox -764,750 p.a.)
# Rec Semi Annual 6M EURIBOR (aprox 249.636 s.a.)

bankmodel.generate_swap_contract('Sell',120, zerocurve, amount = 100000)
bankmodel.generate_swap_contract('Sell',360, zerocurve, amount = 100000)
bankmodel.generate_swap_contract('Sell',12, zerocurve, amount = 100000)
bankmodel.df_swaps
# Out:
# 2023-05-01 16:07:19.110 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 6 swaps in total.
# 2023-05-01 16:07:19.198 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 7 swaps in total.
# 2023-05-01 16:07:19.259 | INFO     | src.models.bank_model:generate_swap_contract:264 - Added 1 swap contracts to our portfolio. 8 swaps in total.
#    contract_no    pay start_date     pay_freq    rec     rec_freq  principal  \
# 0        10001  float 2023-04-28  semi annual  fixed       annual  150000000
# 0        10002  fixed 2023-04-28       annual  float  semi annual  150000000
# 0        10003  float 2023-04-28  semi annual  fixed       annual    2800000
# 0        10004  float 2023-04-28  semi annual  fixed       annual   40000000
# 0        10005  fixed 2023-04-28       annual  float  semi annual   40000000
# 0        10006  float 2023-04-27  semi annual  fixed       annual     100000
# 0        10007  float 2023-04-27  semi annual  fixed       annual     100000
# 0        10008  float 2023-04-27  semi annual  fixed       annual     100000
#
#    tenor  base_rate  margin
# 0     84       2.41   -0.01
# 0     48       2.40    0.01
# 0    120       2.48   -0.01
# 0     60       2.38   -0.01
# 0     48       2.40    0.01
# 0    120       2.53   -0.01
# 0    360       2.49   -0.01
# 0     12       2.97   -0.01
