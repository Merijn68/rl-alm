# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20SAC%20model%20Gausian%203000k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train SAC RL model
#
# The SAC (Soft Actor-Critic) algorithm is an off-policy reinforcement learning method designed for continuous action spaces. It combines the benefits of both policy-based and value-based methods and is known for its sample efficiency and stability.
#
# The actor in SAC is responsible for selecting actions in the environment. It typically uses a neural network to learn a policy that maps observations to continuous actions.
# SAC uses a stochastic policy, which means it outputs a probability distribution over the available actions, often modeled as a Gaussian distribution.
# This stochasticity helps exploration during training.
#
# Critic: SAC also includes two critics, referred to as Q-networks. These networks estimate the state-action value function, providing two independent value estimates.
# Having multiple critics helps stabilize the training process.
#
# SAC collects data by interacting with the environment. The actor's stochastic policy is used to sample actions,
# and these actions are executed in the environment to collect state-action-reward transitions.
# SAC uses an experience replay buffer to store and sample past experiences.
# This buffer allows the algorithm to learn from a diverse set of experiences and reduce sample correlations.
#
# SAC employs a variant of the Bellman equation to update the critics. The key innovation in SAC is the use of a "soft" Bellman backup.
# This involves minimizing a loss that aims to make the critics agree with each other and be close to the minimum of the Bellman error.
#
# The actor's policy is updated based on the soft Q-values from the critics. The objective is to maximize the expected reward, including an entropy term.
# The entropy term encourages exploration by discouraging overly deterministic policies.
#
# SAC introduces a temperature parameter that scales the entropy term in the policy update. This temperature parameter can be learned or adjusted during training.
# It helps balance exploration and exploitation by controlling the level of stochasticity in the policy.
#
# These steps are repeated iteratively, allowing the agent to improve its policy and value functions over time. The process continues until convergence or a specified number of iterations.
#
# SAC's main advantages include:
#
# It can handle continuous action spaces efficiently.
# It provides a good balance between exploration and exploitation, thanks to the entropy term.
# It benefits from experience replay, which reduces sample correlations and enhances learning stability.
# It can be used in combination with target value networks for even more stability.
#
# https://arxiv.org/pdf/1801.01290.pdf

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Nov 17 08:39:59 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    43W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 854, done.
# remote: Counting objects: 100% (854/854), done.
# remote: Compressing objects: 100% (504/504), done.
# remote: Total 854 (delta 449), reused 700 (delta 342), pack-reused 0
# Receiving objects: 100% (854/854), 22.13 MiB | 11.25 MiB/s, done.
# Resolving deltas: 100% (449/449), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.2.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 3.8 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.2.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import SAC

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %%
# Change Path settings to output results to gdrive

MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/models')
DATA_MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/data/model')
FIGURES_PATH = Path('/content/gdrive/MyDrive/rl-alm/reports/figures')
NOTEBOOK_PATH = Path('/content/gdrive/MyDrive/rl-alm/notebooks')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-11-17 08:40:45.999 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-17 08:40:48.421 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# steps: 60, score: -13819

# %% [markdown]
# Define the model. For the initial model we use the A2C model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'SAC_Gausian'
ent_coef= 0.001

model = SAC(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        ent_coef='auto',
        use_sde = False, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2023-11-17 08:40:52.422 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-17 08:40:54.215 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2023-09-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 3_000_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    n_updates       | 2929339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48828    |
# |    fps             | 70       |
# |    time_elapsed    | 41500    |
# |    total_timesteps | 2929680  |
# | train/             |          |
# |    actor_loss      | -718     |
# |    critic_loss     | 487      |
# |    ent_coef        | 0.573    |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 2.34e-05 |
# |    n_updates       | 2929579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 48832    |
# |    fps             | 70       |
# |    time_elapsed    | 41504    |
# |    total_timesteps | 2929920  |
# | train/             |          |
# |    actor_loss      | -693     |
# |    critic_loss     | 252      |
# |    ent_coef        | 0.574    |
# |    ent_coef_loss   | 0.0591   |
# |    learning_rate   | 2.34e-05 |
# |    n_updates       | 2929819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 48836    |
# |    fps             | 70       |
# |    time_elapsed    | 41507    |
# |    total_timesteps | 2930160  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 395      |
# |    ent_coef        | 0.574    |
# |    ent_coef_loss   | -0.0369  |
# |    learning_rate   | 2.33e-05 |
# |    n_updates       | 2930059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48840    |
# |    fps             | 70       |
# |    time_elapsed    | 41511    |
# |    total_timesteps | 2930400  |
# | train/             |          |
# |    actor_loss      | -723     |
# |    critic_loss     | 297      |
# |    ent_coef        | 0.573    |
# |    ent_coef_loss   | -0.0889  |
# |    learning_rate   | 2.32e-05 |
# |    n_updates       | 2930299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48844    |
# |    fps             | 70       |
# |    time_elapsed    | 41514    |
# |    total_timesteps | 2930640  |
# | train/             |          |
# |    actor_loss      | -707     |
# |    critic_loss     | 399      |
# |    ent_coef        | 0.573    |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 2.31e-05 |
# |    n_updates       | 2930539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48848    |
# |    fps             | 70       |
# |    time_elapsed    | 41518    |
# |    total_timesteps | 2930880  |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 286      |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | -0.0751  |
# |    learning_rate   | 2.3e-05  |
# |    n_updates       | 2930779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48852    |
# |    fps             | 70       |
# |    time_elapsed    | 41521    |
# |    total_timesteps | 2931120  |
# | train/             |          |
# |    actor_loss      | -690     |
# |    critic_loss     | 283      |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | -0.0606  |
# |    learning_rate   | 2.3e-05  |
# |    n_updates       | 2931019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 48856    |
# |    fps             | 70       |
# |    time_elapsed    | 41524    |
# |    total_timesteps | 2931360  |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 886      |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | 0.0762   |
# |    learning_rate   | 2.29e-05 |
# |    n_updates       | 2931259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48860    |
# |    fps             | 70       |
# |    time_elapsed    | 41528    |
# |    total_timesteps | 2931600  |
# | train/             |          |
# |    actor_loss      | -714     |
# |    critic_loss     | 428      |
# |    ent_coef        | 0.576    |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 2.28e-05 |
# |    n_updates       | 2931499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48864    |
# |    fps             | 70       |
# |    time_elapsed    | 41531    |
# |    total_timesteps | 2931840  |
# | train/             |          |
# |    actor_loss      | -690     |
# |    critic_loss     | 410      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.0659  |
# |    learning_rate   | 2.27e-05 |
# |    n_updates       | 2931739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48868    |
# |    fps             | 70       |
# |    time_elapsed    | 41535    |
# |    total_timesteps | 2932080  |
# | train/             |          |
# |    actor_loss      | -718     |
# |    critic_loss     | 396      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.0158  |
# |    learning_rate   | 2.26e-05 |
# |    n_updates       | 2931979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48872    |
# |    fps             | 70       |
# |    time_elapsed    | 41538    |
# |    total_timesteps | 2932320  |
# | train/             |          |
# |    actor_loss      | -722     |
# |    critic_loss     | 442      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | 0.0866   |
# |    learning_rate   | 2.26e-05 |
# |    n_updates       | 2932219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48876    |
# |    fps             | 70       |
# |    time_elapsed    | 41541    |
# |    total_timesteps | 2932560  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 329      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | 0.0455   |
# |    learning_rate   | 2.25e-05 |
# |    n_updates       | 2932459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48880    |
# |    fps             | 70       |
# |    time_elapsed    | 41545    |
# |    total_timesteps | 2932800  |
# | train/             |          |
# |    actor_loss      | -724     |
# |    critic_loss     | 319      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -0.07    |
# |    learning_rate   | 2.24e-05 |
# |    n_updates       | 2932699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48884    |
# |    fps             | 70       |
# |    time_elapsed    | 41548    |
# |    total_timesteps | 2933040  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 450      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.0209   |
# |    learning_rate   | 2.23e-05 |
# |    n_updates       | 2932939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48888    |
# |    fps             | 70       |
# |    time_elapsed    | 41552    |
# |    total_timesteps | 2933280  |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 387      |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | 0.218    |
# |    learning_rate   | 2.22e-05 |
# |    n_updates       | 2933179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48892    |
# |    fps             | 70       |
# |    time_elapsed    | 41555    |
# |    total_timesteps | 2933520  |
# | train/             |          |
# |    actor_loss      | -728     |
# |    critic_loss     | 306      |
# |    ent_coef        | 0.586    |
# |    ent_coef_loss   | -0.0428  |
# |    learning_rate   | 2.22e-05 |
# |    n_updates       | 2933419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48896    |
# |    fps             | 70       |
# |    time_elapsed    | 41558    |
# |    total_timesteps | 2933760  |
# | train/             |          |
# |    actor_loss      | -665     |
# |    critic_loss     | 411      |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | -0.0948  |
# |    learning_rate   | 2.21e-05 |
# |    n_updates       | 2933659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48900    |
# |    fps             | 70       |
# |    time_elapsed    | 41562    |
# |    total_timesteps | 2934000  |
# | train/             |          |
# |    actor_loss      | -704     |
# |    critic_loss     | 680      |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | 0.0701   |
# |    learning_rate   | 2.2e-05  |
# |    n_updates       | 2933899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48904    |
# |    fps             | 70       |
# |    time_elapsed    | 41565    |
# |    total_timesteps | 2934240  |
# | train/             |          |
# |    actor_loss      | -705     |
# |    critic_loss     | 353      |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | 0.0593   |
# |    learning_rate   | 2.19e-05 |
# |    n_updates       | 2934139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48908    |
# |    fps             | 70       |
# |    time_elapsed    | 41568    |
# |    total_timesteps | 2934480  |
# | train/             |          |
# |    actor_loss      | -683     |
# |    critic_loss     | 460      |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | -0.0679  |
# |    learning_rate   | 2.18e-05 |
# |    n_updates       | 2934379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48912    |
# |    fps             | 70       |
# |    time_elapsed    | 41572    |
# |    total_timesteps | 2934720  |
# | train/             |          |
# |    actor_loss      | -703     |
# |    critic_loss     | 480      |
# |    ent_coef        | 0.585    |
# |    ent_coef_loss   | 0.0115   |
# |    learning_rate   | 2.18e-05 |
# |    n_updates       | 2934619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 48916    |
# |    fps             | 70       |
# |    time_elapsed    | 41575    |
# |    total_timesteps | 2934960  |
# | train/             |          |
# |    actor_loss      | -706     |
# |    critic_loss     | 415      |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | 0.0343   |
# |    learning_rate   | 2.17e-05 |
# |    n_updates       | 2934859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 48920    |
# |    fps             | 70       |
# |    time_elapsed    | 41579    |
# |    total_timesteps | 2935200  |
# | train/             |          |
# |    actor_loss      | -704     |
# |    critic_loss     | 439      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.000671 |
# |    learning_rate   | 2.16e-05 |
# |    n_updates       | 2935099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48924    |
# |    fps             | 70       |
# |    time_elapsed    | 41582    |
# |    total_timesteps | 2935440  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 356      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 2.15e-05 |
# |    n_updates       | 2935339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48928    |
# |    fps             | 70       |
# |    time_elapsed    | 41585    |
# |    total_timesteps | 2935680  |
# | train/             |          |
# |    actor_loss      | -670     |
# |    critic_loss     | 498      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | 0.0622   |
# |    learning_rate   | 2.14e-05 |
# |    n_updates       | 2935579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48932    |
# |    fps             | 70       |
# |    time_elapsed    | 41589    |
# |    total_timesteps | 2935920  |
# | train/             |          |
# |    actor_loss      | -676     |
# |    critic_loss     | 314      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | -0.035   |
# |    learning_rate   | 2.14e-05 |
# |    n_updates       | 2935819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48936    |
# |    fps             | 70       |
# |    time_elapsed    | 41592    |
# |    total_timesteps | 2936160  |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 571      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | 0.0901   |
# |    learning_rate   | 2.13e-05 |
# |    n_updates       | 2936059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48940    |
# |    fps             | 70       |
# |    time_elapsed    | 41596    |
# |    total_timesteps | 2936400  |
# | train/             |          |
# |    actor_loss      | -696     |
# |    critic_loss     | 278      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.0455  |
# |    learning_rate   | 2.12e-05 |
# |    n_updates       | 2936299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48944    |
# |    fps             | 70       |
# |    time_elapsed    | 41599    |
# |    total_timesteps | 2936640  |
# | train/             |          |
# |    actor_loss      | -702     |
# |    critic_loss     | 377      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 2.11e-05 |
# |    n_updates       | 2936539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48948    |
# |    fps             | 70       |
# |    time_elapsed    | 41603    |
# |    total_timesteps | 2936880  |
# | train/             |          |
# |    actor_loss      | -699     |
# |    critic_loss     | 554      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.0161  |
# |    learning_rate   | 2.1e-05  |
# |    n_updates       | 2936779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48952    |
# |    fps             | 70       |
# |    time_elapsed    | 41606    |
# |    total_timesteps | 2937120  |
# | train/             |          |
# |    actor_loss      | -717     |
# |    critic_loss     | 617      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.0814  |
# |    learning_rate   | 2.1e-05  |
# |    n_updates       | 2937019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 48956    |
# |    fps             | 70       |
# |    time_elapsed    | 41609    |
# |    total_timesteps | 2937360  |
# | train/             |          |
# |    actor_loss      | -744     |
# |    critic_loss     | 307      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | 0.0903   |
# |    learning_rate   | 2.09e-05 |
# |    n_updates       | 2937259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48960    |
# |    fps             | 70       |
# |    time_elapsed    | 41613    |
# |    total_timesteps | 2937600  |
# | train/             |          |
# |    actor_loss      | -651     |
# |    critic_loss     | 424      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 2.08e-05 |
# |    n_updates       | 2937499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 48964    |
# |    fps             | 70       |
# |    time_elapsed    | 41616    |
# |    total_timesteps | 2937840  |
# | train/             |          |
# |    actor_loss      | -706     |
# |    critic_loss     | 315      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.011   |
# |    learning_rate   | 2.07e-05 |
# |    n_updates       | 2937739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48968    |
# |    fps             | 70       |
# |    time_elapsed    | 41620    |
# |    total_timesteps | 2938080  |
# | train/             |          |
# |    actor_loss      | -675     |
# |    critic_loss     | 596      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.0736  |
# |    learning_rate   | 2.06e-05 |
# |    n_updates       | 2937979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48972    |
# |    fps             | 70       |
# |    time_elapsed    | 41623    |
# |    total_timesteps | 2938320  |
# | train/             |          |
# |    actor_loss      | -737     |
# |    critic_loss     | 340      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.0664  |
# |    learning_rate   | 2.06e-05 |
# |    n_updates       | 2938219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48976    |
# |    fps             | 70       |
# |    time_elapsed    | 41626    |
# |    total_timesteps | 2938560  |
# | train/             |          |
# |    actor_loss      | -697     |
# |    critic_loss     | 299      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | 0.127    |
# |    learning_rate   | 2.05e-05 |
# |    n_updates       | 2938459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48980    |
# |    fps             | 70       |
# |    time_elapsed    | 41630    |
# |    total_timesteps | 2938800  |
# | train/             |          |
# |    actor_loss      | -697     |
# |    critic_loss     | 319      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.0609  |
# |    learning_rate   | 2.04e-05 |
# |    n_updates       | 2938699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48984    |
# |    fps             | 70       |
# |    time_elapsed    | 41633    |
# |    total_timesteps | 2939040  |
# | train/             |          |
# |    actor_loss      | -662     |
# |    critic_loss     | 455      |
# |    ent_coef        | 0.576    |
# |    ent_coef_loss   | 0.117    |
# |    learning_rate   | 2.03e-05 |
# |    n_updates       | 2938939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48988    |
# |    fps             | 70       |
# |    time_elapsed    | 41637    |
# |    total_timesteps | 2939280  |
# | train/             |          |
# |    actor_loss      | -703     |
# |    critic_loss     | 332      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | 0.0618   |
# |    learning_rate   | 2.02e-05 |
# |    n_updates       | 2939179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48992    |
# |    fps             | 70       |
# |    time_elapsed    | 41640    |
# |    total_timesteps | 2939520  |
# | train/             |          |
# |    actor_loss      | -707     |
# |    critic_loss     | 359      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.00885 |
# |    learning_rate   | 2.02e-05 |
# |    n_updates       | 2939419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 48996    |
# |    fps             | 70       |
# |    time_elapsed    | 41643    |
# |    total_timesteps | 2939760  |
# | train/             |          |
# |    actor_loss      | -695     |
# |    critic_loss     | 775      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 2.01e-05 |
# |    n_updates       | 2939659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49000    |
# |    fps             | 70       |
# |    time_elapsed    | 41647    |
# |    total_timesteps | 2940000  |
# | train/             |          |
# |    actor_loss      | -700     |
# |    critic_loss     | 808      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | 0.0125   |
# |    learning_rate   | 2e-05    |
# |    n_updates       | 2939899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49004    |
# |    fps             | 70       |
# |    time_elapsed    | 41650    |
# |    total_timesteps | 2940240  |
# | train/             |          |
# |    actor_loss      | -719     |
# |    critic_loss     | 422      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.194    |
# |    learning_rate   | 1.99e-05 |
# |    n_updates       | 2940139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49008    |
# |    fps             | 70       |
# |    time_elapsed    | 41654    |
# |    total_timesteps | 2940480  |
# | train/             |          |
# |    actor_loss      | -691     |
# |    critic_loss     | 267      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.0227  |
# |    learning_rate   | 1.98e-05 |
# |    n_updates       | 2940379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49012    |
# |    fps             | 70       |
# |    time_elapsed    | 41657    |
# |    total_timesteps | 2940720  |
# | train/             |          |
# |    actor_loss      | -693     |
# |    critic_loss     | 370      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.139    |
# |    learning_rate   | 1.98e-05 |
# |    n_updates       | 2940619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49016    |
# |    fps             | 70       |
# |    time_elapsed    | 41660    |
# |    total_timesteps | 2940960  |
# | train/             |          |
# |    actor_loss      | -724     |
# |    critic_loss     | 303      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 1.97e-05 |
# |    n_updates       | 2940859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49020    |
# |    fps             | 70       |
# |    time_elapsed    | 41664    |
# |    total_timesteps | 2941200  |
# | train/             |          |
# |    actor_loss      | -725     |
# |    critic_loss     | 327      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.0229  |
# |    learning_rate   | 1.96e-05 |
# |    n_updates       | 2941099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49024    |
# |    fps             | 70       |
# |    time_elapsed    | 41667    |
# |    total_timesteps | 2941440  |
# | train/             |          |
# |    actor_loss      | -677     |
# |    critic_loss     | 460      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 1.95e-05 |
# |    n_updates       | 2941339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49028    |
# |    fps             | 70       |
# |    time_elapsed    | 41671    |
# |    total_timesteps | 2941680  |
# | train/             |          |
# |    actor_loss      | -723     |
# |    critic_loss     | 331      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | 0.0766   |
# |    learning_rate   | 1.94e-05 |
# |    n_updates       | 2941579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49032    |
# |    fps             | 70       |
# |    time_elapsed    | 41674    |
# |    total_timesteps | 2941920  |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 266      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 1.94e-05 |
# |    n_updates       | 2941819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49036    |
# |    fps             | 70       |
# |    time_elapsed    | 41677    |
# |    total_timesteps | 2942160  |
# | train/             |          |
# |    actor_loss      | -707     |
# |    critic_loss     | 362      |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 1.93e-05 |
# |    n_updates       | 2942059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49040    |
# |    fps             | 70       |
# |    time_elapsed    | 41681    |
# |    total_timesteps | 2942400  |
# | train/             |          |
# |    actor_loss      | -712     |
# |    critic_loss     | 455      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 1.92e-05 |
# |    n_updates       | 2942299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49044    |
# |    fps             | 70       |
# |    time_elapsed    | 41684    |
# |    total_timesteps | 2942640  |
# | train/             |          |
# |    actor_loss      | -704     |
# |    critic_loss     | 448      |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 1.91e-05 |
# |    n_updates       | 2942539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49048    |
# |    fps             | 70       |
# |    time_elapsed    | 41688    |
# |    total_timesteps | 2942880  |
# | train/             |          |
# |    actor_loss      | -691     |
# |    critic_loss     | 672      |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | 0.0642   |
# |    learning_rate   | 1.9e-05  |
# |    n_updates       | 2942779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49052    |
# |    fps             | 70       |
# |    time_elapsed    | 41691    |
# |    total_timesteps | 2943120  |
# | train/             |          |
# |    actor_loss      | -682     |
# |    critic_loss     | 370      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.155    |
# |    learning_rate   | 1.9e-05  |
# |    n_updates       | 2943019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49056    |
# |    fps             | 70       |
# |    time_elapsed    | 41694    |
# |    total_timesteps | 2943360  |
# | train/             |          |
# |    actor_loss      | -700     |
# |    critic_loss     | 420      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.172    |
# |    learning_rate   | 1.89e-05 |
# |    n_updates       | 2943259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49060    |
# |    fps             | 70       |
# |    time_elapsed    | 41698    |
# |    total_timesteps | 2943600  |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 306      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -0.0115  |
# |    learning_rate   | 1.88e-05 |
# |    n_updates       | 2943499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49064    |
# |    fps             | 70       |
# |    time_elapsed    | 41701    |
# |    total_timesteps | 2943840  |
# | train/             |          |
# |    actor_loss      | -677     |
# |    critic_loss     | 283      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -0.0696  |
# |    learning_rate   | 1.87e-05 |
# |    n_updates       | 2943739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49068    |
# |    fps             | 70       |
# |    time_elapsed    | 41705    |
# |    total_timesteps | 2944080  |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 406      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | -0.0585  |
# |    learning_rate   | 1.86e-05 |
# |    n_updates       | 2943979  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49072    |
# |    fps             | 70       |
# |    time_elapsed    | 41708    |
# |    total_timesteps | 2944320  |
# | train/             |          |
# |    actor_loss      | -734     |
# |    critic_loss     | 553      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | 0.0771   |
# |    learning_rate   | 1.86e-05 |
# |    n_updates       | 2944219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49076    |
# |    fps             | 70       |
# |    time_elapsed    | 41711    |
# |    total_timesteps | 2944560  |
# | train/             |          |
# |    actor_loss      | -675     |
# |    critic_loss     | 352      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.0775  |
# |    learning_rate   | 1.85e-05 |
# |    n_updates       | 2944459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49080    |
# |    fps             | 70       |
# |    time_elapsed    | 41715    |
# |    total_timesteps | 2944800  |
# | train/             |          |
# |    actor_loss      | -705     |
# |    critic_loss     | 318      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | 0.0757   |
# |    learning_rate   | 1.84e-05 |
# |    n_updates       | 2944699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49084    |
# |    fps             | 70       |
# |    time_elapsed    | 41718    |
# |    total_timesteps | 2945040  |
# | train/             |          |
# |    actor_loss      | -702     |
# |    critic_loss     | 374      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | 0.0312   |
# |    learning_rate   | 1.83e-05 |
# |    n_updates       | 2944939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49088    |
# |    fps             | 70       |
# |    time_elapsed    | 41722    |
# |    total_timesteps | 2945280  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 610      |
# |    ent_coef        | 0.576    |
# |    ent_coef_loss   | 0.0265   |
# |    learning_rate   | 1.82e-05 |
# |    n_updates       | 2945179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49092    |
# |    fps             | 70       |
# |    time_elapsed    | 41725    |
# |    total_timesteps | 2945520  |
# | train/             |          |
# |    actor_loss      | -662     |
# |    critic_loss     | 582      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | 0.101    |
# |    learning_rate   | 1.82e-05 |
# |    n_updates       | 2945419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49096    |
# |    fps             | 70       |
# |    time_elapsed    | 41728    |
# |    total_timesteps | 2945760  |
# | train/             |          |
# |    actor_loss      | -666     |
# |    critic_loss     | 400      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | 0.0819   |
# |    learning_rate   | 1.81e-05 |
# |    n_updates       | 2945659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.43e+03 |
# | time/              |          |
# |    episodes        | 49100    |
# |    fps             | 70       |
# |    time_elapsed    | 41732    |
# |    total_timesteps | 2946000  |
# | train/             |          |
# |    actor_loss      | -717     |
# |    critic_loss     | 532      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.0367  |
# |    learning_rate   | 1.8e-05  |
# |    n_updates       | 2945899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49104    |
# |    fps             | 70       |
# |    time_elapsed    | 41735    |
# |    total_timesteps | 2946240  |
# | train/             |          |
# |    actor_loss      | -707     |
# |    critic_loss     | 379      |
# |    ent_coef        | 0.577    |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 1.79e-05 |
# |    n_updates       | 2946139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49108    |
# |    fps             | 70       |
# |    time_elapsed    | 41739    |
# |    total_timesteps | 2946480  |
# | train/             |          |
# |    actor_loss      | -695     |
# |    critic_loss     | 434      |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.0451  |
# |    learning_rate   | 1.78e-05 |
# |    n_updates       | 2946379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49112    |
# |    fps             | 70       |
# |    time_elapsed    | 41742    |
# |    total_timesteps | 2946720  |
# | train/             |          |
# |    actor_loss      | -693     |
# |    critic_loss     | 397      |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | 0.0755   |
# |    learning_rate   | 1.78e-05 |
# |    n_updates       | 2946619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49116    |
# |    fps             | 70       |
# |    time_elapsed    | 41745    |
# |    total_timesteps | 2946960  |
# | train/             |          |
# |    actor_loss      | -748     |
# |    critic_loss     | 686      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 1.77e-05 |
# |    n_updates       | 2946859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49120    |
# |    fps             | 70       |
# |    time_elapsed    | 41749    |
# |    total_timesteps | 2947200  |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 418      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.00884 |
# |    learning_rate   | 1.76e-05 |
# |    n_updates       | 2947099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49124    |
# |    fps             | 70       |
# |    time_elapsed    | 41752    |
# |    total_timesteps | 2947440  |
# | train/             |          |
# |    actor_loss      | -718     |
# |    critic_loss     | 280      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | 0.174    |
# |    learning_rate   | 1.75e-05 |
# |    n_updates       | 2947339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49128    |
# |    fps             | 70       |
# |    time_elapsed    | 41756    |
# |    total_timesteps | 2947680  |
# | train/             |          |
# |    actor_loss      | -684     |
# |    critic_loss     | 666      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.0434  |
# |    learning_rate   | 1.74e-05 |
# |    n_updates       | 2947579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49132    |
# |    fps             | 70       |
# |    time_elapsed    | 41759    |
# |    total_timesteps | 2947920  |
# | train/             |          |
# |    actor_loss      | -698     |
# |    critic_loss     | 445      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | 0.0132   |
# |    learning_rate   | 1.74e-05 |
# |    n_updates       | 2947819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49136    |
# |    fps             | 70       |
# |    time_elapsed    | 41762    |
# |    total_timesteps | 2948160  |
# | train/             |          |
# |    actor_loss      | -704     |
# |    critic_loss     | 494      |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.0248  |
# |    learning_rate   | 1.73e-05 |
# |    n_updates       | 2948059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49140    |
# |    fps             | 70       |
# |    time_elapsed    | 41766    |
# |    total_timesteps | 2948400  |
# | train/             |          |
# |    actor_loss      | -739     |
# |    critic_loss     | 243      |
# |    ent_coef        | 0.581    |
# |    ent_coef_loss   | 0.0154   |
# |    learning_rate   | 1.72e-05 |
# |    n_updates       | 2948299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49144    |
# |    fps             | 70       |
# |    time_elapsed    | 41769    |
# |    total_timesteps | 2948640  |
# | train/             |          |
# |    actor_loss      | -695     |
# |    critic_loss     | 514      |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | 0.0511   |
# |    learning_rate   | 1.71e-05 |
# |    n_updates       | 2948539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49148    |
# |    fps             | 70       |
# |    time_elapsed    | 41773    |
# |    total_timesteps | 2948880  |
# | train/             |          |
# |    actor_loss      | -677     |
# |    critic_loss     | 754      |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | 0.0607   |
# |    learning_rate   | 1.7e-05  |
# |    n_updates       | 2948779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.47e+03 |
# | time/              |          |
# |    episodes        | 49152    |
# |    fps             | 70       |
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49896    |
# |    fps             | 70       |
# |    time_elapsed    | 42409    |
# |    total_timesteps | 2993760  |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 298      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0587   |
# |    learning_rate   | 2.08e-06 |
# |    n_updates       | 2993659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49900    |
# |    fps             | 70       |
# |    time_elapsed    | 42412    |
# |    total_timesteps | 2994000  |
# | train/             |          |
# |    actor_loss      | -673     |
# |    critic_loss     | 302      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.049   |
# |    learning_rate   | 2e-06    |
# |    n_updates       | 2993899  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49904    |
# |    fps             | 70       |
# |    time_elapsed    | 42415    |
# |    total_timesteps | 2994240  |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 357      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.00805 |
# |    learning_rate   | 1.92e-06 |
# |    n_updates       | 2994139  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49908    |
# |    fps             | 70       |
# |    time_elapsed    | 42419    |
# |    total_timesteps | 2994480  |
# | train/             |          |
# |    actor_loss      | -710     |
# |    critic_loss     | 258      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0449   |
# |    learning_rate   | 1.84e-06 |
# |    n_updates       | 2994379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49912    |
# |    fps             | 70       |
# |    time_elapsed    | 42422    |
# |    total_timesteps | 2994720  |
# | train/             |          |
# |    actor_loss      | -697     |
# |    critic_loss     | 317      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.24     |
# |    learning_rate   | 1.76e-06 |
# |    n_updates       | 2994619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49916    |
# |    fps             | 70       |
# |    time_elapsed    | 42426    |
# |    total_timesteps | 2994960  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 281      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.00489  |
# |    learning_rate   | 1.68e-06 |
# |    n_updates       | 2994859  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49920    |
# |    fps             | 70       |
# |    time_elapsed    | 42429    |
# |    total_timesteps | 2995200  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 349      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0172   |
# |    learning_rate   | 1.6e-06  |
# |    n_updates       | 2995099  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49924    |
# |    fps             | 70       |
# |    time_elapsed    | 42432    |
# |    total_timesteps | 2995440  |
# | train/             |          |
# |    actor_loss      | -745     |
# |    critic_loss     | 323      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0261   |
# |    learning_rate   | 1.52e-06 |
# |    n_updates       | 2995339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49928    |
# |    fps             | 70       |
# |    time_elapsed    | 42436    |
# |    total_timesteps | 2995680  |
# | train/             |          |
# |    actor_loss      | -712     |
# |    critic_loss     | 407      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0745  |
# |    learning_rate   | 1.44e-06 |
# |    n_updates       | 2995579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49932    |
# |    fps             | 70       |
# |    time_elapsed    | 42439    |
# |    total_timesteps | 2995920  |
# | train/             |          |
# |    actor_loss      | -753     |
# |    critic_loss     | 372      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.149    |
# |    learning_rate   | 1.36e-06 |
# |    n_updates       | 2995819  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49936    |
# |    fps             | 70       |
# |    time_elapsed    | 42442    |
# |    total_timesteps | 2996160  |
# | train/             |          |
# |    actor_loss      | -690     |
# |    critic_loss     | 360      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0941  |
# |    learning_rate   | 1.28e-06 |
# |    n_updates       | 2996059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49940    |
# |    fps             | 70       |
# |    time_elapsed    | 42446    |
# |    total_timesteps | 2996400  |
# | train/             |          |
# |    actor_loss      | -707     |
# |    critic_loss     | 353      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0637  |
# |    learning_rate   | 1.2e-06  |
# |    n_updates       | 2996299  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49944    |
# |    fps             | 70       |
# |    time_elapsed    | 42449    |
# |    total_timesteps | 2996640  |
# | train/             |          |
# |    actor_loss      | -701     |
# |    critic_loss     | 365      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0788   |
# |    learning_rate   | 1.12e-06 |
# |    n_updates       | 2996539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49948    |
# |    fps             | 70       |
# |    time_elapsed    | 42453    |
# |    total_timesteps | 2996880  |
# | train/             |          |
# |    actor_loss      | -692     |
# |    critic_loss     | 251      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.026    |
# |    learning_rate   | 1.04e-06 |
# |    n_updates       | 2996779  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49952    |
# |    fps             | 70       |
# |    time_elapsed    | 42456    |
# |    total_timesteps | 2997120  |
# | train/             |          |
# |    actor_loss      | -702     |
# |    critic_loss     | 563      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0646   |
# |    learning_rate   | 9.6e-07  |
# |    n_updates       | 2997019  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49956    |
# |    fps             | 70       |
# |    time_elapsed    | 42459    |
# |    total_timesteps | 2997360  |
# | train/             |          |
# |    actor_loss      | -687     |
# |    critic_loss     | 559      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.00794  |
# |    learning_rate   | 8.8e-07  |
# |    n_updates       | 2997259  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49960    |
# |    fps             | 70       |
# |    time_elapsed    | 42463    |
# |    total_timesteps | 2997600  |
# | train/             |          |
# |    actor_loss      | -697     |
# |    critic_loss     | 879      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0428   |
# |    learning_rate   | 8e-07    |
# |    n_updates       | 2997499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49964    |
# |    fps             | 70       |
# |    time_elapsed    | 42466    |
# |    total_timesteps | 2997840  |
# | train/             |          |
# |    actor_loss      | -695     |
# |    critic_loss     | 194      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0581  |
# |    learning_rate   | 7.2e-07  |
# |    n_updates       | 2997739  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 60        |
# |    ep_rew_mean     | 1.45e+03  |
# | time/              |           |
# |    episodes        | 49968     |
# |    fps             | 70        |
# |    time_elapsed    | 42470     |
# |    total_timesteps | 2998080   |
# | train/             |           |
# |    actor_loss      | -690      |
# |    critic_loss     | 341       |
# |    ent_coef        | 0.588     |
# |    ent_coef_loss   | -0.000909 |
# |    learning_rate   | 6.4e-07   |
# |    n_updates       | 2997979   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49972    |
# |    fps             | 70       |
# |    time_elapsed    | 42473    |
# |    total_timesteps | 2998320  |
# | train/             |          |
# |    actor_loss      | -681     |
# |    critic_loss     | 339      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0313  |
# |    learning_rate   | 5.6e-07  |
# |    n_updates       | 2998219  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49976    |
# |    fps             | 70       |
# |    time_elapsed    | 42476    |
# |    total_timesteps | 2998560  |
# | train/             |          |
# |    actor_loss      | -718     |
# |    critic_loss     | 684      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0234  |
# |    learning_rate   | 4.8e-07  |
# |    n_updates       | 2998459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 49980    |
# |    fps             | 70       |
# |    time_elapsed    | 42480    |
# |    total_timesteps | 2998800  |
# | train/             |          |
# |    actor_loss      | -721     |
# |    critic_loss     | 799      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.21     |
# |    learning_rate   | 4e-07    |
# |    n_updates       | 2998699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49984    |
# |    fps             | 70       |
# |    time_elapsed    | 42483    |
# |    total_timesteps | 2999040  |
# | train/             |          |
# |    actor_loss      | -732     |
# |    critic_loss     | 346      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0957   |
# |    learning_rate   | 3.2e-07  |
# |    n_updates       | 2998939  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49988    |
# |    fps             | 70       |
# |    time_elapsed    | 42487    |
# |    total_timesteps | 2999280  |
# | train/             |          |
# |    actor_loss      | -694     |
# |    critic_loss     | 330      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0326  |
# |    learning_rate   | 2.4e-07  |
# |    n_updates       | 2999179  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 49992    |
# |    fps             | 70       |
# |    time_elapsed    | 42490    |
# |    total_timesteps | 2999520  |
# | train/             |          |
# |    actor_loss      | -693     |
# |    critic_loss     | 329      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 1.6e-07  |
# |    n_updates       | 2999419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 49996    |
# |    fps             | 70       |
# |    time_elapsed    | 42493    |
# |    total_timesteps | 2999760  |
# | train/             |          |
# |    actor_loss      | -704     |
# |    critic_loss     | 291      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | -0.0336  |
# |    learning_rate   | 8.03e-08 |
# |    n_updates       | 2999659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.45e+03 |
# | time/              |          |
# |    episodes        | 50000    |
# |    fps             | 70       |
# |    time_elapsed    | 42497    |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -687     |
# |    critic_loss     | 816      |
# |    ent_coef        | 0.588    |
# |    ent_coef_loss   | 0.0486   |
# |    learning_rate   | 3.33e-10 |
# |    n_updates       | 2999899  |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Green",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ",
                       name = f"{model_name}_{steps}_rewards",
                       figurepath = FIGURES_PATH )
# Out:
# Model name: SAC_Gausian, Steps: 3000000, Mean: 1294.80786, IQR: 328.0, CVaR: -2465.8084210526317

# %% [markdown]
# Showing the results of the trained model

# %%
print(model.policy)
# Out:
# MultiInputPolicy(
#   (actor): Actor(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=52, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=4, bias=True)
#     (log_std): Linear(in_features=256, out_features=4, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  1580
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1       0             0                  0   232.906137    0
# 1          2       2             0                  0   290.881905    2
# 2          3       3             0                  0   115.352933    3
# 3          4       5             0                  0   104.520195    5
# 4          5       6             0                  0    99.684267    6
# 5          6       5             0                  0  1159.676016    5
# 6          7       7             0                  0  1156.933194    7
# 7          8       5             0                  0  2577.136641    5
# 8          9       5             0                  0  2943.285500    5
# 9         10       7             0                  0  2284.513782    7
# 10        11       7             0                  0  2657.863189    7
# 11        12      10             0                  0  1835.413920   10
# 12        13      11             0                  0  1186.272324   11
# 13        14      13             0                  0   684.807997   13
# 14        15      14             0                  0   506.505881   14
# 15        16      15             0                  0   -79.906702   15
# 16        17      15             0                  0   414.122580   15
# 17        18      17             0                  0   778.380190   17
# 18        19      18             0                  0   659.419495   18
# 19        20      21             0                  0    63.491381   21
# 20        21      21             0                  0   501.878392   21
# 21        22      24             0                  0   294.385013   24
# 22        23      23             0                  0   792.074971   23
# 23        24      22             0                  0  1420.248822   22
# 24        25      24             0                  0  1137.918157   24
# 25        26      26             0                  0   997.099046   26
# 26        27      25             0                  0  1588.185037   25
# 27        28      24             0                  0  2308.164888   24
# 28        29      26             0                  0  1716.741384   26
# 29        30      29             0                  0  1009.265211   29
# 30        31      28             0                  0  1354.438039   28
# 31        32      30             0                  0   332.883661   30
# 32        33      30             0                  0   701.863458   30
# 33        34      32             0                  0   226.556960   32
# 34        35      32             0                  0   612.686317   32
# 35        36      34             0                  0    82.399028   34
# 36        37      33             0                  0  1170.036281   33
# 37        38      31             0                  0  2329.277805   31
# 38        39      32             0                  0  2380.608053   32
# 39        40      33             0                  0  2420.695293   33
# 40        41      36             0                  0  2081.219471   36
# 41        42      39             0                  0  1130.280896   39
# 42        43      39             0                  0   573.546074   39
# 43        44      38             0                  0   763.717878   38
# 44        45      41             0                  0    69.228708   41
# 45        46      40             0                  0   704.669424   40
# 46        47      39             0                  0  1037.872950   39
# 47        48      41             0                  0   384.133616   41
# 48        49      41             0                  0  1047.711483   41
# 49        50      43             0                  0   801.474590   43
# 50        51      41             0                  0  1839.173446   41
# 51        52      43             0                  0  1940.836017   43
# 52        53      46             0                  0   982.690990   46
# 53        54      45             0                  0   814.478661   45
# 54        55      45             0                  0   921.015107   45
# 55        56      44             0                  0   696.947344   44
# 56        57      44             0                  0   352.063353   44
# 57        58      44             0                  0  -249.954767   44
# 58        59      43             0                  0    -3.261852   43
# 59        60      43             0                  0  -213.127595   43
#
#        income  funding_cost  total_funding  total_mortgages
# 0    3.648944     -2.665286          -1231             1000
# 1    7.454671     -4.840524          -2288             2000
# 2   10.149571     -6.395834          -3111             3000
# 3   13.753106     -8.099111          -4098             4000
# 4   16.530098     -9.686657          -5091             5000
# 5   16.530098    -11.077136          -6149             5000
# 6   19.480003    -12.275404          -7144             6000
# 7   19.480003    -14.019137          -8562             6000
# 8   19.480003    -14.461545          -8926             6000
# 9   22.678981    -14.746232          -9265             7000
# 10  22.678981    -15.049408          -9636             7000
# 11  25.918425    -15.267611          -9812             8000
# 12  25.109253    -13.480719          -9161             8000
# 13  25.109253    -11.926577          -8658             8000
# 14  25.109253    -11.086478          -8477             8000
# 15  25.109253     -9.741019          -7889             8000
# 16  25.109253     -9.298875          -8381             8000
# 17  27.883930    -10.015052          -9743             9000
# 18  27.883930     -9.063903          -9621             9000
# 19  30.836086     -8.922619         -10023            10000
# 20  30.836086     -8.949811         -10459            10000
# 21  33.866651     -9.428635         -11250            11000
# 22  33.866651    -10.180077         -11746            11000
# 23  33.866651    -10.956261         -12372            11000
# 24  36.550493    -11.834784         -13088            12000
# 25  39.234820    -12.967958         -13945            13000
# 26  39.234820    -13.918127         -14534            13000
# 27  39.234820    -15.186476         -15252            13000
# 28  42.062801    -15.380102         -15659            14000
# 29  44.824156    -15.777933         -15949            15000
# 30  44.824156    -16.564174         -16293            15000
# 31  47.599305    -16.788217         -16269            16000
# 32  47.599305    -17.088227         -16637            16000
# 33  50.337346    -17.798630         -17159            17000
# 34  50.337346    -17.962254         -17542            17000
# 35  53.359352    -18.404475         -18010            18000
# 36  53.359352    -20.241995         -19096            18000
# 37  53.359352    -22.262295         -20253            18000
# 38  56.351913    -23.977530         -21302            19000
# 39  59.315997    -25.608970         -22340            20000
# 40  62.455766    -26.027714         -23000            21000
# 41  65.480455    -26.231200         -23047            22000
# 42  65.480455    -26.266861         -22487            22000
# 43  65.480455    -26.738566         -22675            22000
# 44  68.732067    -27.098331         -22979            23000
# 45  68.732067    -28.650601         -23613            23000
# 46  68.732067    -29.070852         -23945            23000
# 47  71.458066    -29.620519         -24289            24000
# 48  71.458066    -30.211616         -24951            24000
# 49  74.623525    -31.178867         -25704            25000
# 50  74.623525    -32.647139         -26739            25000
# 51  77.866991    -34.304811         -27839            26000
# 52  80.975349    -34.408086         -27879            27000
# 53  80.975349    -35.812896         -27708            27000
# 54  80.975349    -35.965413         -27813            27000
# 55  80.975349    -36.271561         -27587            27000
# 56  80.975349    -36.767439         -27240            27000
# 57  80.975349    -36.876057         -26635            27000
# 58  80.975349    -37.380931         -26880            27000
# 59  80.975349    -37.886379         -26669            27000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=1447.44 Expected Shortfall=906.80 Interquartile Range=222.25

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")

# %% [markdown]
# It would be great if we can store a local copy of the notebook after execution so I can easily look back at the performed actions...

# %%
from google.colab import runtime
runtime.unassign()
