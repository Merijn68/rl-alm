# %% [markdown]
# <a href="https://colab.research.google.com/github/Merijn68/rl-alm/blob/main/notebooks/Train%20SAC%20model%20Gausian%20600k%202yshort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Train SAC RL model
#
# The SAC (Soft Actor-Critic) algorithm is an off-policy reinforcement learning method designed for continuous action spaces. It combines the benefits of both policy-based and value-based methods and is known for its sample efficiency and stability.
#
# The actor in SAC is responsible for selecting actions in the environment. It typically uses a neural network to learn a policy that maps observations to continuous actions.
# SAC uses a stochastic policy, which means it outputs a probability distribution over the available actions, often modeled as a Gaussian distribution.
# This stochasticity helps exploration during training.
#
# Critic: SAC also includes two critics, referred to as Q-networks. These networks estimate the state-action value function, providing two independent value estimates.
# Having multiple critics helps stabilize the training process.
#
# SAC collects data by interacting with the environment. The actor's stochastic policy is used to sample actions,
# and these actions are executed in the environment to collect state-action-reward transitions.
# SAC uses an experience replay buffer to store and sample past experiences.
# This buffer allows the algorithm to learn from a diverse set of experiences and reduce sample correlations.
#
# SAC employs a variant of the Bellman equation to update the critics. The key innovation in SAC is the use of a "soft" Bellman backup.
# This involves minimizing a loss that aims to make the critics agree with each other and be close to the minimum of the Bellman error.
#
# The actor's policy is updated based on the soft Q-values from the critics. The objective is to maximize the expected reward, including an entropy term.
# The entropy term encourages exploration by discouraging overly deterministic policies.
#
# SAC introduces a temperature parameter that scales the entropy term in the policy update. This temperature parameter can be learned or adjusted during training.
# It helps balance exploration and exploitation by controlling the level of stochasticity in the policy.
#
# These steps are repeated iteratively, allowing the agent to improve its policy and value functions over time. The process continues until convergence or a specified number of iterations.
#
# SAC's main advantages include:
#
# It can handle continuous action spaces efficiently.
# It provides a good balance between exploration and exploitation, thanks to the entropy term.
# It benefits from experience replay, which reduces sample correlations and enhances learning stability.
# It can be used in combination with target value networks for even more stability.
#
# https://arxiv.org/pdf/1801.01290.pdf

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Nov 14 17:40:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    48W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Merijn68/rl-alm.git
# Out:
# Cloning into 'rl-alm'...
# remote: Enumerating objects: 827, done.
# remote: Counting objects: 100% (827/827), done.
# remote: Compressing objects: 100% (479/479), done.
# remote: Total 827 (delta 434), reused 698 (delta 340), pack-reused 0
# Receiving objects: 100% (827/827), 21.12 MiB | 15.80 MiB/s, done.
# Resolving deltas: 100% (434/434), done.

# %%
# %cd /content/rl-alm/
# Out:
# /content/rl-alm

# %%
# !pip install stable_baselines3
# !pip install loguru
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.8 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 stable_baselines3-2.1.0
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext tensorboard
import os
import sys
from pathlib import Path
import pandas as pd
from stable_baselines3 import SAC

# Find the root directory by traversing up the directory tree
def find_project_root(current_path):
    if os.path.exists(os.path.join(current_path, "README.md")):
        return current_path
    parent_path = os.path.dirname(current_path)
    if parent_path == current_path:
        raise ValueError("Project root not found.")
    return find_project_root(parent_path)


current_dir = os.getcwd()
print(f"Current dirt: {current_dir}")
project_root = find_project_root(current_dir)
sys.path.append(str(project_root))
sys.path.append(os.path.join(project_root, 'src'))
print(f"Project root: {project_root}")

# # flake8: noqa  # Disable Flake8 for the following block
import gymnasium as gym

from src.models.bank_env import BankEnv
from src.visualization import visualize
import src.models.train as train
from src.tests import test_bankmodel_a2c_train as tests
from src.data.definitions import MODEL_PATH, TENSORBOARD_LOGS, DATA_MODEL_PATH
from src.models.evaluate import evaluate_policy
# Out:
# Current dirt: /content/rl-alm
# Project root: /content/rl-alm

# %%
# Change Path settings to output results to gdrive

MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/models')
DATA_MODEL_PATH = Path('/content/gdrive/MyDrive/rl-alm/data/model')
FIGURES_PATH = Path('/content/gdrive/MyDrive/rl-alm/reports/figures')
NOTEBOOK_PATH = Path('/content/gdrive/MyDrive/rl-alm/notebooks')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### First test - just take a random walk in the environment.
#
# Each episode consists of 60 months. Each timestep interest rates and swap rates are simulated and the bank enters into new mortgages.
# Each month the actor needs to decide on the funding strategy to fund the bank.

# %%
env_id = "bank-v3"
gym.register(id=env_id, entry_point=BankEnv, max_episode_steps=60)

# %%
# Random walk in the environment
tests.random_walk(env_id)
# Out:
# 2023-11-14 17:42:42.182 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-14 17:42:44.870 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# steps: 60, score: -5978

# %% [markdown]
# Define the model. For the initial model we use the A2C model.

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv

env = gym.make(env_id, render_mode="human")
# env = DummyVecEnv([lambda: env])

# Define a Lineair Learning Rate Scheduler
def linear_schedule(initial_value: float):
    """Linear learning rate schedule."""

    def func(progress_remaining: float) -> float:
        """Progress will decrease from 1 (beginning) to 0."""
        return progress_remaining * initial_value

    return func

initial_lr = 0.001
n_steps = 60
model_name = 'SAC_Gausian_s'
ent_coef= 0.001

model = SAC(
        "MultiInputPolicy",
        env,
        tensorboard_log=TENSORBOARD_LOGS,
        verbose=1,
        learning_rate=linear_schedule(initial_lr),
        ent_coef='auto',
        use_sde = False, # Use generalized State Dependent Exploration (gSDE) instead of action noise exploration,
        device='cuda'
    )
# Out:
# 2023-11-14 17:43:18.868 | INFO     | src.data.dataset:read_data:46 - reading interest data from ESW.
# 2023-11-14 17:43:21.206 | INFO     | src.data.dataset:read_data:46 - reading zerocurve data from ESW.
# Interest period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Zerocurve period:  (Timestamp('2010-06-01 00:00:00'), Timestamp('2021-12-01 00:00:00'))
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ##### Train the model in the environment and save it

# %%
steps = 600_000

model, mean, episode_iqr, episode_cvar, episode_rewards = train.train( model, env, total_timesteps=steps, conf_level=0.95, tb_log_name= TENSORBOARD_LOGS)
modelpath = Path(
        MODEL_PATH,
        model_name + "_" + str(steps) + ".zip",
    )
model.save(modelpath)
pd.DataFrame(episode_rewards).to_csv(Path(DATA_MODEL_PATH, model_name + "_" + str(steps) + ".csv"))

# episode_rewards = env.unwrapped.episode_rewards
# Out:
# Logging to /content/rl-alm/tensorboard_logs_1
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.reset_episode_statistics to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reset_episode_statistics` for environment variables or `env.get_wrapper_attr('reset_episode_statistics')` that will search the reminding wrappers.
#   logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    n_updates       | 529339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.01e+03 |
# | time/              |          |
# |    episodes        | 8828     |
# |    fps             | 70       |
# |    time_elapsed    | 7540     |
# |    total_timesteps | 529680   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 2.43e+03 |
# |    ent_coef        | 0.4      |
# |    ent_coef_loss   | -0.118   |
# |    learning_rate   | 0.000117 |
# |    n_updates       | 529579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1e+03    |
# | time/              |          |
# |    episodes        | 8832     |
# |    fps             | 70       |
# |    time_elapsed    | 7543     |
# |    total_timesteps | 529920   |
# | train/             |          |
# |    actor_loss      | -530     |
# |    critic_loss     | 4.26e+03 |
# |    ent_coef        | 0.393    |
# |    ent_coef_loss   | -0.464   |
# |    learning_rate   | 0.000117 |
# |    n_updates       | 529819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.01e+03 |
# | time/              |          |
# |    episodes        | 8836     |
# |    fps             | 70       |
# |    time_elapsed    | 7547     |
# |    total_timesteps | 530160   |
# | train/             |          |
# |    actor_loss      | -530     |
# |    critic_loss     | 2.17e+03 |
# |    ent_coef        | 0.386    |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 8840     |
# |    fps             | 70       |
# |    time_elapsed    | 7550     |
# |    total_timesteps | 530400   |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 3.53e+03 |
# |    ent_coef        | 0.383    |
# |    ent_coef_loss   | 0.217    |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 8844     |
# |    fps             | 70       |
# |    time_elapsed    | 7554     |
# |    total_timesteps | 530640   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 855      |
# |    ent_coef        | 0.38     |
# |    ent_coef_loss   | 0.427    |
# |    learning_rate   | 0.000116 |
# |    n_updates       | 530539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 8848     |
# |    fps             | 70       |
# |    time_elapsed    | 7557     |
# |    total_timesteps | 530880   |
# | train/             |          |
# |    actor_loss      | -522     |
# |    critic_loss     | 1.05e+03 |
# |    ent_coef        | 0.38     |
# |    ent_coef_loss   | 0.32     |
# |    learning_rate   | 0.000115 |
# |    n_updates       | 530779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.04e+03 |
# | time/              |          |
# |    episodes        | 8852     |
# |    fps             | 70       |
# |    time_elapsed    | 7561     |
# |    total_timesteps | 531120   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 965      |
# |    ent_coef        | 0.371    |
# |    ent_coef_loss   | -0.479   |
# |    learning_rate   | 0.000115 |
# |    n_updates       | 531019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.04e+03 |
# | time/              |          |
# |    episodes        | 8856     |
# |    fps             | 70       |
# |    time_elapsed    | 7564     |
# |    total_timesteps | 531360   |
# | train/             |          |
# |    actor_loss      | -530     |
# |    critic_loss     | 1.93e+03 |
# |    ent_coef        | 0.367    |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.05e+03 |
# | time/              |          |
# |    episodes        | 8860     |
# |    fps             | 70       |
# |    time_elapsed    | 7567     |
# |    total_timesteps | 531600   |
# | train/             |          |
# |    actor_loss      | -539     |
# |    critic_loss     | 753      |
# |    ent_coef        | 0.359    |
# |    ent_coef_loss   | -0.786   |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.06e+03 |
# | time/              |          |
# |    episodes        | 8864     |
# |    fps             | 70       |
# |    time_elapsed    | 7571     |
# |    total_timesteps | 531840   |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 1.13e+03 |
# |    ent_coef        | 0.352    |
# |    ent_coef_loss   | -0.355   |
# |    learning_rate   | 0.000114 |
# |    n_updates       | 531739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    episodes        | 8868     |
# |    fps             | 70       |
# |    time_elapsed    | 7574     |
# |    total_timesteps | 532080   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 1.5e+03  |
# |    ent_coef        | 0.346    |
# |    ent_coef_loss   | -0.141   |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 531979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.08e+03 |
# | time/              |          |
# |    episodes        | 8872     |
# |    fps             | 70       |
# |    time_elapsed    | 7578     |
# |    total_timesteps | 532320   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 652      |
# |    ent_coef        | 0.345    |
# |    ent_coef_loss   | -0.594   |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 532219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.09e+03 |
# | time/              |          |
# |    episodes        | 8876     |
# |    fps             | 70       |
# |    time_elapsed    | 7581     |
# |    total_timesteps | 532560   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 2.27e+03 |
# |    ent_coef        | 0.342    |
# |    ent_coef_loss   | -0.38    |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.1e+03  |
# | time/              |          |
# |    episodes        | 8880     |
# |    fps             | 70       |
# |    time_elapsed    | 7585     |
# |    total_timesteps | 532800   |
# | train/             |          |
# |    actor_loss      | -548     |
# |    critic_loss     | 2.07e+03 |
# |    ent_coef        | 0.338    |
# |    ent_coef_loss   | -0.394   |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 8884     |
# |    fps             | 70       |
# |    time_elapsed    | 7588     |
# |    total_timesteps | 533040   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 3.94e+03 |
# |    ent_coef        | 0.336    |
# |    ent_coef_loss   | -0.138   |
# |    learning_rate   | 0.000112 |
# |    n_updates       | 532939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.12e+03 |
# | time/              |          |
# |    episodes        | 8888     |
# |    fps             | 70       |
# |    time_elapsed    | 7592     |
# |    total_timesteps | 533280   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 1.47e+03 |
# |    ent_coef        | 0.337    |
# |    ent_coef_loss   | 0.48     |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 533179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.13e+03 |
# | time/              |          |
# |    episodes        | 8892     |
# |    fps             | 70       |
# |    time_elapsed    | 7595     |
# |    total_timesteps | 533520   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 1.55e+03 |
# |    ent_coef        | 0.339    |
# |    ent_coef_loss   | 0.543    |
# |    learning_rate   | 0.000111 |
# |    n_updates       | 533419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8896     |
# |    fps             | 70       |
# |    time_elapsed    | 7598     |
# |    total_timesteps | 533760   |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 3.06e+03 |
# |    ent_coef        | 0.341    |
# |    ent_coef_loss   | -0.0269  |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8900     |
# |    fps             | 70       |
# |    time_elapsed    | 7602     |
# |    total_timesteps | 534000   |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 2.44e+03 |
# |    ent_coef        | 0.333    |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 533899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.14e+03 |
# | time/              |          |
# |    episodes        | 8904     |
# |    fps             | 70       |
# |    time_elapsed    | 7605     |
# |    total_timesteps | 534240   |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 923      |
# |    ent_coef        | 0.342    |
# |    ent_coef_loss   | -0.0975  |
# |    learning_rate   | 0.00011  |
# |    n_updates       | 534139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8908     |
# |    fps             | 70       |
# |    time_elapsed    | 7609     |
# |    total_timesteps | 534480   |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 995      |
# |    ent_coef        | 0.342    |
# |    ent_coef_loss   | -0.547   |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8912     |
# |    fps             | 70       |
# |    time_elapsed    | 7612     |
# |    total_timesteps | 534720   |
# | train/             |          |
# |    actor_loss      | -531     |
# |    critic_loss     | 1.6e+03  |
# |    ent_coef        | 0.343    |
# |    ent_coef_loss   | 0.068    |
# |    learning_rate   | 0.000109 |
# |    n_updates       | 534619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 8916     |
# |    fps             | 70       |
# |    time_elapsed    | 7615     |
# |    total_timesteps | 534960   |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 1.47e+03 |
# |    ent_coef        | 0.346    |
# |    ent_coef_loss   | -0.0626  |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 534859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 8920     |
# |    fps             | 70       |
# |    time_elapsed    | 7619     |
# |    total_timesteps | 535200   |
# | train/             |          |
# |    actor_loss      | -547     |
# |    critic_loss     | 2.07e+03 |
# |    ent_coef        | 0.349    |
# |    ent_coef_loss   | 0.183    |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 8924     |
# |    fps             | 70       |
# |    time_elapsed    | 7622     |
# |    total_timesteps | 535440   |
# | train/             |          |
# |    actor_loss      | -518     |
# |    critic_loss     | 1.31e+03 |
# |    ent_coef        | 0.355    |
# |    ent_coef_loss   | 0.724    |
# |    learning_rate   | 0.000108 |
# |    n_updates       | 535339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.19e+03 |
# | time/              |          |
# |    episodes        | 8928     |
# |    fps             | 70       |
# |    time_elapsed    | 7626     |
# |    total_timesteps | 535680   |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 1.06e+03 |
# |    ent_coef        | 0.376    |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.19e+03 |
# | time/              |          |
# |    episodes        | 8932     |
# |    fps             | 70       |
# |    time_elapsed    | 7629     |
# |    total_timesteps | 535920   |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 2.31e+03 |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.000107 |
# |    n_updates       | 535819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 8936     |
# |    fps             | 70       |
# |    time_elapsed    | 7633     |
# |    total_timesteps | 536160   |
# | train/             |          |
# |    actor_loss      | -536     |
# |    critic_loss     | 3.03e+03 |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | 0.537    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 8940     |
# |    fps             | 70       |
# |    time_elapsed    | 7636     |
# |    total_timesteps | 536400   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 1.78e+03 |
# |    ent_coef        | 0.416    |
# |    ent_coef_loss   | 1.11     |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 8944     |
# |    fps             | 70       |
# |    time_elapsed    | 7639     |
# |    total_timesteps | 536640   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 2.77e+03 |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | 0.292    |
# |    learning_rate   | 0.000106 |
# |    n_updates       | 536539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8948     |
# |    fps             | 70       |
# |    time_elapsed    | 7643     |
# |    total_timesteps | 536880   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 2.48e+03 |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | 0.566    |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 536779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8952     |
# |    fps             | 70       |
# |    time_elapsed    | 7646     |
# |    total_timesteps | 537120   |
# | train/             |          |
# |    actor_loss      | -532     |
# |    critic_loss     | 3.72e+03 |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | 0.1      |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 537019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 8956     |
# |    fps             | 70       |
# |    time_elapsed    | 7650     |
# |    total_timesteps | 537360   |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 1.1e+03  |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | 0.299    |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 8960     |
# |    fps             | 70       |
# |    time_elapsed    | 7653     |
# |    total_timesteps | 537600   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 1.9e+03  |
# |    ent_coef        | 0.448    |
# |    ent_coef_loss   | -0.0378  |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8964     |
# |    fps             | 70       |
# |    time_elapsed    | 7656     |
# |    total_timesteps | 537840   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 1.46e+03 |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | -0.227   |
# |    learning_rate   | 0.000104 |
# |    n_updates       | 537739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8968     |
# |    fps             | 70       |
# |    time_elapsed    | 7660     |
# |    total_timesteps | 538080   |
# | train/             |          |
# |    actor_loss      | -563     |
# |    critic_loss     | 1.92e+03 |
# |    ent_coef        | 0.443    |
# |    ent_coef_loss   | -0.282   |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 537979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8972     |
# |    fps             | 70       |
# |    time_elapsed    | 7663     |
# |    total_timesteps | 538320   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 2.21e+03 |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | -0.0605  |
# |    learning_rate   | 0.000103 |
# |    n_updates       | 538219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 8976     |
# |    fps             | 70       |
# |    time_elapsed    | 7667     |
# |    total_timesteps | 538560   |
# | train/             |          |
# |    actor_loss      | -525     |
# |    critic_loss     | 1.76e+03 |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.0501  |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8980     |
# |    fps             | 70       |
# |    time_elapsed    | 7670     |
# |    total_timesteps | 538800   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 2.66e+03 |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | 0.0574   |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8984     |
# |    fps             | 70       |
# |    time_elapsed    | 7673     |
# |    total_timesteps | 539040   |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 2.25e+03 |
# |    ent_coef        | 0.443    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.000102 |
# |    n_updates       | 538939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8988     |
# |    fps             | 70       |
# |    time_elapsed    | 7677     |
# |    total_timesteps | 539280   |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 2.04e+03 |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.22e+03 |
# | time/              |          |
# |    episodes        | 8992     |
# |    fps             | 70       |
# |    time_elapsed    | 7680     |
# |    total_timesteps | 539520   |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 3.35e+03 |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | -0.37    |
# |    learning_rate   | 0.000101 |
# |    n_updates       | 539419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 8996     |
# |    fps             | 70       |
# |    time_elapsed    | 7684     |
# |    total_timesteps | 539760   |
# | train/             |          |
# |    actor_loss      | -517     |
# |    critic_loss     | 1.46e+03 |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | 0.61     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9000     |
# |    fps             | 70       |
# |    time_elapsed    | 7687     |
# |    total_timesteps | 540000   |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 3.62e+03 |
# |    ent_coef        | 0.454    |
# |    ent_coef_loss   | 0.261    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 539899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9004     |
# |    fps             | 70       |
# |    time_elapsed    | 7691     |
# |    total_timesteps | 540240   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 1.31e+03 |
# |    ent_coef        | 0.46     |
# |    ent_coef_loss   | 0.315    |
# |    learning_rate   | 9.96e-05 |
# |    n_updates       | 540139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9008     |
# |    fps             | 70       |
# |    time_elapsed    | 7694     |
# |    total_timesteps | 540480   |
# | train/             |          |
# |    actor_loss      | -530     |
# |    critic_loss     | 1.55e+03 |
# |    ent_coef        | 0.464    |
# |    ent_coef_loss   | -0.092   |
# |    learning_rate   | 9.92e-05 |
# |    n_updates       | 540379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9012     |
# |    fps             | 70       |
# |    time_elapsed    | 7697     |
# |    total_timesteps | 540720   |
# | train/             |          |
# |    actor_loss      | -544     |
# |    critic_loss     | 3.3e+03  |
# |    ent_coef        | 0.459    |
# |    ent_coef_loss   | -0.0169  |
# |    learning_rate   | 9.88e-05 |
# |    n_updates       | 540619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9016     |
# |    fps             | 70       |
# |    time_elapsed    | 7701     |
# |    total_timesteps | 540960   |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 3.01e+03 |
# |    ent_coef        | 0.454    |
# |    ent_coef_loss   | 0.281    |
# |    learning_rate   | 9.84e-05 |
# |    n_updates       | 540859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 70       |
# |    time_elapsed    | 7704     |
# |    total_timesteps | 541200   |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 1.59e+03 |
# |    ent_coef        | 0.457    |
# |    ent_coef_loss   | -0.379   |
# |    learning_rate   | 9.8e-05  |
# |    n_updates       | 541099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9024     |
# |    fps             | 70       |
# |    time_elapsed    | 7708     |
# |    total_timesteps | 541440   |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 892      |
# |    ent_coef        | 0.467    |
# |    ent_coef_loss   | 0.00673  |
# |    learning_rate   | 9.76e-05 |
# |    n_updates       | 541339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9028     |
# |    fps             | 70       |
# |    time_elapsed    | 7711     |
# |    total_timesteps | 541680   |
# | train/             |          |
# |    actor_loss      | -537     |
# |    critic_loss     | 4.65e+03 |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | 0.214    |
# |    learning_rate   | 9.72e-05 |
# |    n_updates       | 541579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9032     |
# |    fps             | 70       |
# |    time_elapsed    | 7714     |
# |    total_timesteps | 541920   |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 893      |
# |    ent_coef        | 0.479    |
# |    ent_coef_loss   | 0.0654   |
# |    learning_rate   | 9.68e-05 |
# |    n_updates       | 541819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9036     |
# |    fps             | 70       |
# |    time_elapsed    | 7718     |
# |    total_timesteps | 542160   |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 2.34e+03 |
# |    ent_coef        | 0.481    |
# |    ent_coef_loss   | 0.0285   |
# |    learning_rate   | 9.64e-05 |
# |    n_updates       | 542059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 70       |
# |    time_elapsed    | 7721     |
# |    total_timesteps | 542400   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 756      |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | -0.00852 |
# |    learning_rate   | 9.6e-05  |
# |    n_updates       | 542299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9044     |
# |    fps             | 70       |
# |    time_elapsed    | 7725     |
# |    total_timesteps | 542640   |
# | train/             |          |
# |    actor_loss      | -537     |
# |    critic_loss     | 2.54e+03 |
# |    ent_coef        | 0.481    |
# |    ent_coef_loss   | 0.448    |
# |    learning_rate   | 9.56e-05 |
# |    n_updates       | 542539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9048     |
# |    fps             | 70       |
# |    time_elapsed    | 7728     |
# |    total_timesteps | 542880   |
# | train/             |          |
# |    actor_loss      | -568     |
# |    critic_loss     | 1.39e+03 |
# |    ent_coef        | 0.487    |
# |    ent_coef_loss   | -0.0991  |
# |    learning_rate   | 9.52e-05 |
# |    n_updates       | 542779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9052     |
# |    fps             | 70       |
# |    time_elapsed    | 7732     |
# |    total_timesteps | 543120   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 2.08e+03 |
# |    ent_coef        | 0.488    |
# |    ent_coef_loss   | -0.288   |
# |    learning_rate   | 9.48e-05 |
# |    n_updates       | 543019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9056     |
# |    fps             | 70       |
# |    time_elapsed    | 7735     |
# |    total_timesteps | 543360   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 2.04e+03 |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 9.44e-05 |
# |    n_updates       | 543259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9060     |
# |    fps             | 70       |
# |    time_elapsed    | 7738     |
# |    total_timesteps | 543600   |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 1e+03    |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 9.4e-05  |
# |    n_updates       | 543499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9064     |
# |    fps             | 70       |
# |    time_elapsed    | 7742     |
# |    total_timesteps | 543840   |
# | train/             |          |
# |    actor_loss      | -543     |
# |    critic_loss     | 1.4e+03  |
# |    ent_coef        | 0.484    |
# |    ent_coef_loss   | -0.345   |
# |    learning_rate   | 9.36e-05 |
# |    n_updates       | 543739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9068     |
# |    fps             | 70       |
# |    time_elapsed    | 7745     |
# |    total_timesteps | 544080   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 2.39e+03 |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | 0.00978  |
# |    learning_rate   | 9.32e-05 |
# |    n_updates       | 543979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9072     |
# |    fps             | 70       |
# |    time_elapsed    | 7749     |
# |    total_timesteps | 544320   |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 2.22e+03 |
# |    ent_coef        | 0.479    |
# |    ent_coef_loss   | 0.147    |
# |    learning_rate   | 9.28e-05 |
# |    n_updates       | 544219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9076     |
# |    fps             | 70       |
# |    time_elapsed    | 7752     |
# |    total_timesteps | 544560   |
# | train/             |          |
# |    actor_loss      | -554     |
# |    critic_loss     | 1.32e+03 |
# |    ent_coef        | 0.475    |
# |    ent_coef_loss   | -0.0719  |
# |    learning_rate   | 9.24e-05 |
# |    n_updates       | 544459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9080     |
# |    fps             | 70       |
# |    time_elapsed    | 7755     |
# |    total_timesteps | 544800   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 2.37e+03 |
# |    ent_coef        | 0.476    |
# |    ent_coef_loss   | 0.264    |
# |    learning_rate   | 9.2e-05  |
# |    n_updates       | 544699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 9084     |
# |    fps             | 70       |
# |    time_elapsed    | 7759     |
# |    total_timesteps | 545040   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 1.59e+03 |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | 0.195    |
# |    learning_rate   | 9.16e-05 |
# |    n_updates       | 544939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 9088     |
# |    fps             | 70       |
# |    time_elapsed    | 7762     |
# |    total_timesteps | 545280   |
# | train/             |          |
# |    actor_loss      | -525     |
# |    critic_loss     | 1.67e+03 |
# |    ent_coef        | 0.466    |
# |    ent_coef_loss   | 0.0558   |
# |    learning_rate   | 9.12e-05 |
# |    n_updates       | 545179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 9092     |
# |    fps             | 70       |
# |    time_elapsed    | 7766     |
# |    total_timesteps | 545520   |
# | train/             |          |
# |    actor_loss      | -557     |
# |    critic_loss     | 1.81e+03 |
# |    ent_coef        | 0.463    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 9.08e-05 |
# |    n_updates       | 545419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 9096     |
# |    fps             | 70       |
# |    time_elapsed    | 7769     |
# |    total_timesteps | 545760   |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 969      |
# |    ent_coef        | 0.466    |
# |    ent_coef_loss   | 0.29     |
# |    learning_rate   | 9.04e-05 |
# |    n_updates       | 545659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 9100     |
# |    fps             | 70       |
# |    time_elapsed    | 7772     |
# |    total_timesteps | 546000   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 3.02e+03 |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 9e-05    |
# |    n_updates       | 545899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9104     |
# |    fps             | 70       |
# |    time_elapsed    | 7776     |
# |    total_timesteps | 546240   |
# | train/             |          |
# |    actor_loss      | -533     |
# |    critic_loss     | 2.07e+03 |
# |    ent_coef        | 0.475    |
# |    ent_coef_loss   | 0.394    |
# |    learning_rate   | 8.96e-05 |
# |    n_updates       | 546139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9108     |
# |    fps             | 70       |
# |    time_elapsed    | 7779     |
# |    total_timesteps | 546480   |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 2.93e+03 |
# |    ent_coef        | 0.477    |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 8.92e-05 |
# |    n_updates       | 546379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9112     |
# |    fps             | 70       |
# |    time_elapsed    | 7783     |
# |    total_timesteps | 546720   |
# | train/             |          |
# |    actor_loss      | -539     |
# |    critic_loss     | 1.52e+03 |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | 0.0867   |
# |    learning_rate   | 8.88e-05 |
# |    n_updates       | 546619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9116     |
# |    fps             | 70       |
# |    time_elapsed    | 7786     |
# |    total_timesteps | 546960   |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 2.08e+03 |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 8.84e-05 |
# |    n_updates       | 546859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9120     |
# |    fps             | 70       |
# |    time_elapsed    | 7789     |
# |    total_timesteps | 547200   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 1.33e+03 |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | 0.237    |
# |    learning_rate   | 8.8e-05  |
# |    n_updates       | 547099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9124     |
# |    fps             | 70       |
# |    time_elapsed    | 7793     |
# |    total_timesteps | 547440   |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 3.45e+03 |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | -0.272   |
# |    learning_rate   | 8.76e-05 |
# |    n_updates       | 547339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9128     |
# |    fps             | 70       |
# |    time_elapsed    | 7796     |
# |    total_timesteps | 547680   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 2.17e+03 |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.216   |
# |    learning_rate   | 8.72e-05 |
# |    n_updates       | 547579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9132     |
# |    fps             | 70       |
# |    time_elapsed    | 7800     |
# |    total_timesteps | 547920   |
# | train/             |          |
# |    actor_loss      | -544     |
# |    critic_loss     | 1.39e+03 |
# |    ent_coef        | 0.479    |
# |    ent_coef_loss   | -0.355   |
# |    learning_rate   | 8.68e-05 |
# |    n_updates       | 547819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9136     |
# |    fps             | 70       |
# |    time_elapsed    | 7803     |
# |    total_timesteps | 548160   |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 1.37e+03 |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 8.64e-05 |
# |    n_updates       | 548059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9140     |
# |    fps             | 70       |
# |    time_elapsed    | 7806     |
# |    total_timesteps | 548400   |
# | train/             |          |
# |    actor_loss      | -556     |
# |    critic_loss     | 1.2e+03  |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 8.6e-05  |
# |    n_updates       | 548299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9144     |
# |    fps             | 70       |
# |    time_elapsed    | 7810     |
# |    total_timesteps | 548640   |
# | train/             |          |
# |    actor_loss      | -531     |
# |    critic_loss     | 1.65e+03 |
# |    ent_coef        | 0.465    |
# |    ent_coef_loss   | 0.113    |
# |    learning_rate   | 8.56e-05 |
# |    n_updates       | 548539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9148     |
# |    fps             | 70       |
# |    time_elapsed    | 7813     |
# |    total_timesteps | 548880   |
# | train/             |          |
# |    actor_loss      | -551     |
# |    critic_loss     | 1.48e+03 |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -0.131   |
# |    learning_rate   | 8.52e-05 |
# |    n_updates       | 548779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9152     |
# |    fps             | 70       |
# |    time_elapsed    | 7817     |
# |    total_timesteps | 549120   |
# | train/             |          |
# |    actor_loss      | -535     |
# |    critic_loss     | 3.31e+03 |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | 0.243    |
# |    learning_rate   | 8.48e-05 |
# |    n_updates       | 549019   |
# ---------------------------------
# ---------------------------------
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9896     |
# |    fps             | 70       |
# |    time_elapsed    | 8453     |
# |    total_timesteps | 593760   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 1.2e+03  |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 1.04e-05 |
# |    n_updates       | 593659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9900     |
# |    fps             | 70       |
# |    time_elapsed    | 8457     |
# |    total_timesteps | 594000   |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0265  |
# |    learning_rate   | 1e-05    |
# |    n_updates       | 593899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9904     |
# |    fps             | 70       |
# |    time_elapsed    | 8460     |
# |    total_timesteps | 594240   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 2.53e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.0452   |
# |    learning_rate   | 9.6e-06  |
# |    n_updates       | 594139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9908     |
# |    fps             | 70       |
# |    time_elapsed    | 8464     |
# |    total_timesteps | 594480   |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 1.86e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0373  |
# |    learning_rate   | 9.2e-06  |
# |    n_updates       | 594379   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9912     |
# |    fps             | 70       |
# |    time_elapsed    | 8467     |
# |    total_timesteps | 594720   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 1.87e+03 |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 8.8e-06  |
# |    n_updates       | 594619   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9916     |
# |    fps             | 70       |
# |    time_elapsed    | 8470     |
# |    total_timesteps | 594960   |
# | train/             |          |
# |    actor_loss      | -557     |
# |    critic_loss     | 2.23e+03 |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | -0.031   |
# |    learning_rate   | 8.4e-06  |
# |    n_updates       | 594859   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 70       |
# |    time_elapsed    | 8474     |
# |    total_timesteps | 595200   |
# | train/             |          |
# |    actor_loss      | -540     |
# |    critic_loss     | 1.9e+03  |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 8e-06    |
# |    n_updates       | 595099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9924     |
# |    fps             | 70       |
# |    time_elapsed    | 8477     |
# |    total_timesteps | 595440   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 742      |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | 0.295    |
# |    learning_rate   | 7.6e-06  |
# |    n_updates       | 595339   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9928     |
# |    fps             | 70       |
# |    time_elapsed    | 8481     |
# |    total_timesteps | 595680   |
# | train/             |          |
# |    actor_loss      | -526     |
# |    critic_loss     | 2.49e+03 |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | -0.0781  |
# |    learning_rate   | 7.2e-06  |
# |    n_updates       | 595579   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9932     |
# |    fps             | 70       |
# |    time_elapsed    | 8484     |
# |    total_timesteps | 595920   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 1.56e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 6.8e-06  |
# |    n_updates       | 595819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9936     |
# |    fps             | 70       |
# |    time_elapsed    | 8488     |
# |    total_timesteps | 596160   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 1.74e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0935  |
# |    learning_rate   | 6.4e-06  |
# |    n_updates       | 596059   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 70       |
# |    time_elapsed    | 8491     |
# |    total_timesteps | 596400   |
# | train/             |          |
# |    actor_loss      | -527     |
# |    critic_loss     | 1.76e+03 |
# |    ent_coef        | 0.428    |
# |    ent_coef_loss   | 0.0933   |
# |    learning_rate   | 6e-06    |
# |    n_updates       | 596299   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9944     |
# |    fps             | 70       |
# |    time_elapsed    | 8494     |
# |    total_timesteps | 596640   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 787      |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0172  |
# |    learning_rate   | 5.6e-06  |
# |    n_updates       | 596539   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9948     |
# |    fps             | 70       |
# |    time_elapsed    | 8498     |
# |    total_timesteps | 596880   |
# | train/             |          |
# |    actor_loss      | -545     |
# |    critic_loss     | 3.12e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0939  |
# |    learning_rate   | 5.2e-06  |
# |    n_updates       | 596779   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9952     |
# |    fps             | 70       |
# |    time_elapsed    | 8501     |
# |    total_timesteps | 597120   |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 1.32e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.0353   |
# |    learning_rate   | 4.8e-06  |
# |    n_updates       | 597019   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9956     |
# |    fps             | 70       |
# |    time_elapsed    | 8505     |
# |    total_timesteps | 597360   |
# | train/             |          |
# |    actor_loss      | -555     |
# |    critic_loss     | 1.17e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.157    |
# |    learning_rate   | 4.4e-06  |
# |    n_updates       | 597259   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 70       |
# |    time_elapsed    | 8508     |
# |    total_timesteps | 597600   |
# | train/             |          |
# |    actor_loss      | -520     |
# |    critic_loss     | 3.11e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.213    |
# |    learning_rate   | 4e-06    |
# |    n_updates       | 597499   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9964     |
# |    fps             | 70       |
# |    time_elapsed    | 8512     |
# |    total_timesteps | 597840   |
# | train/             |          |
# |    actor_loss      | -561     |
# |    critic_loss     | 4.66e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.183    |
# |    learning_rate   | 3.6e-06  |
# |    n_updates       | 597739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9968     |
# |    fps             | 70       |
# |    time_elapsed    | 8515     |
# |    total_timesteps | 598080   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 2.39e+03 |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | 0.196    |
# |    learning_rate   | 3.2e-06  |
# |    n_updates       | 597979   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9972     |
# |    fps             | 70       |
# |    time_elapsed    | 8519     |
# |    total_timesteps | 598320   |
# | train/             |          |
# |    actor_loss      | -562     |
# |    critic_loss     | 665      |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.0355  |
# |    learning_rate   | 2.8e-06  |
# |    n_updates       | 598219   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9976     |
# |    fps             | 70       |
# |    time_elapsed    | 8522     |
# |    total_timesteps | 598560   |
# | train/             |          |
# |    actor_loss      | -529     |
# |    critic_loss     | 4.34e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.0581   |
# |    learning_rate   | 2.4e-06  |
# |    n_updates       | 598459   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 70       |
# |    time_elapsed    | 8525     |
# |    total_timesteps | 598800   |
# | train/             |          |
# |    actor_loss      | -550     |
# |    critic_loss     | 1.03e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.0102  |
# |    learning_rate   | 2e-06    |
# |    n_updates       | 598699   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 9984     |
# |    fps             | 70       |
# |    time_elapsed    | 8529     |
# |    total_timesteps | 599040   |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 4.3e+03  |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.0275   |
# |    learning_rate   | 1.6e-06  |
# |    n_updates       | 598939   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9988     |
# |    fps             | 70       |
# |    time_elapsed    | 8532     |
# |    total_timesteps | 599280   |
# | train/             |          |
# |    actor_loss      | -553     |
# |    critic_loss     | 2.32e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 1.2e-06  |
# |    n_updates       | 599179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9992     |
# |    fps             | 70       |
# |    time_elapsed    | 8536     |
# |    total_timesteps | 599520   |
# | train/             |          |
# |    actor_loss      | -534     |
# |    critic_loss     | 1.39e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.266    |
# |    learning_rate   | 8.02e-07 |
# |    n_updates       | 599419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 9996     |
# |    fps             | 70       |
# |    time_elapsed    | 8539     |
# |    total_timesteps | 599760   |
# | train/             |          |
# |    actor_loss      | -538     |
# |    critic_loss     | 1.64e+03 |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | 0.195    |
# |    learning_rate   | 4.02e-07 |
# |    n_updates       | 599659   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 70       |
# |    time_elapsed    | 8543     |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | -542     |
# |    critic_loss     | 965      |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.0239  |
# |    learning_rate   | 1.67e-09 |
# |    n_updates       | 599899   |
# ---------------------------------
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.episode_rewards to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.episode_rewards` for environment variables or `env.get_wrapper_attr('episode_rewards')` that will search the reminding wrappers.
#   logger.warn(

# %%
print(f"Model name: {model_name}, Steps: {steps}, Mean: {mean}, IQR: {episode_iqr}, CVaR: {episode_cvar}")
visualize.plot_rewards(episode_rewards, interpolate_line=False, rolling_line= True, ylim=(-2000,2000),color = "Green",
                       label = model_name, title = f"Rewards over {int(steps/60)} Episodes. ",
                       name = f"{model_name}_{steps}_rewards",
                       figurepath = FIGURES_PATH )
# Out:
# Model name: SAC_Gausian_s, Steps: 600000, Mean: 1008.5475, IQR: 268.0, CVaR: -6801.368421052632

# %% [markdown]
# Showing the results of the trained model

# %%
print(model.policy)
# Out:
# MultiInputPolicy(
#   (actor): Actor(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=52, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=4, bias=True)
#     (log_std): Linear(in_features=256, out_features=4, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): CombinedExtractor(
#       (extractors): ModuleDict(
#         (liquidity): Flatten(start_dim=1, end_dim=-1)
#         (cashflows): Flatten(start_dim=1, end_dim=-1)
#         (swap_rates): Flatten(start_dim=1, end_dim=-1)
#         (bank_rates): Flatten(start_dim=1, end_dim=-1)
#         (features): Flatten(start_dim=1, end_dim=-1)
#       )
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=56, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

def show_model(env, model) -> int:
    """Show the model in the environment"""
    # env.set_render_output(modelpath.stem)
    obs, info = env.reset()
    score = 0
    terminated = False
    truncated = False
    # env.set_render_output('A2C')

    while not terminated and not truncated:
        action, _state = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score = score + reward
        # env.render()
        df = env.list_model()
    env.plot()
    env.close()
    return score, df

score, df = show_model(env, model)

warnings.filterwarnings("default")

print ('final score: ', score)
df.head(60)
# Out:
# final score:  1293
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#     timestep  reward  risk_penalty  liquidity_penalty    liquidity  nii  \
# 0          1       1             0                  0   394.341759    1
# 1          2       0             0                  0  1733.082161    0
# 2          3       3             0                  0  1593.939469    3
# 3          4       4             0                  0  1546.388089    4
# 4          5       6             0                  0  1297.597824    6
# 5          6       6             0                  0  2107.837322    6
# 6          7       8             0                  0  1595.534692    8
# 7          8      11             0                  0  1298.720332   11
# 8          9      13             0                  0   790.614284   13
# 9         10      14             0                  0   239.530037   14
# 10        11      14             0                  0   575.061867   14
# 11        12      15             0                  0    20.876267   15
# 12        13      15             0                  0   337.777709   15
# 13        14      17             0                  0   243.140076   17
# 14        15      18             0                  0   361.864560   18
# 15        16      19             0                  0   210.694462   19
# 16        17      18             0                  0   689.278712   18
# 17        18      17             0                  0  1077.666125   17
# 18        19      17             0                  0   817.002578   17
# 19        20      17             0                  0   898.322551   17
# 20        21      16             0                  0  1259.641067   16
# 21        22      18             0                  0   668.844371   18
# 22        23      19             0                  0   278.239385   19
# 23        24      18             0                  0  1096.399856   18
# 24        25      20             0                  0   537.135814   20
# 25        26      22             0                  0   472.061987   22
# 26        27      21             0                  0   -53.792979   21
# 27        28      21             0                  0   629.548656   21
# 28        29      20             0                  0  1020.017266   20
# 29        30      19             0                  0   968.766263   19
# 30        31      20             0                  0   401.134477   20
# 31        32      22             0                  0   476.299457   22
# 32        33      21             0                  0   892.069781   21
# 33        34      21             0                  0  1073.553795   21
# 34        35      21             0                  0  1226.958070   21
# 35        36      23             0                  0   804.675280   23
# 36        37      24             0                  0   499.157184   24
# 37        38      24             0                  0   996.033265   24
# 38        39      27             0                  0  1049.673783   27
# 39        40      29             0                  0   406.758045   29
# 40        41      29             0                  0   336.568521   29
# 41        42      30             0                  0   389.943961   30
# 42        43      30             0                  0   890.303854   30
# 43        44      30             0                  0  1581.343358   30
# 44        45      31             0                  0   815.430918   31
# 45        46      30             0                  0  1263.637794   30
# 46        47      31             0                  0   518.994329   31
# 47        48      31             0                  0   736.568910   31
# 48        49      32             0                  0     0.010981   32
# 49        50      32             0                  0   839.614604   32
# 50        51      31             0                  0  1718.332668   31
# 51        52      32             0                  0  1327.642220   32
# 52        53      33             0                  0   693.724035   33
# 53        54      34             0                  0   362.728284   34
# 54        55      33             0                  0   362.429208   33
# 55        56      33             0                  0   522.310388   33
# 56        57      32             0                  0   924.712693   32
# 57        58      33             0                  0   222.918704   33
# 58        59      33             0                  0   713.971046   33
# 59        60      34             0                  0   481.372922   34
#
#        income  funding_cost  total_funding  total_mortgages
# 0    1.311522     -0.117646          -1393             1000
# 1    1.311522     -0.327813          -2730             1000
# 2    2.964055      0.056648          -3589             2000
# 3    4.457232      0.464585          -4540             3000
# 4    6.176168      0.518505          -5289             4000
# 5    6.176168      0.770943          -6097             4000
# 6    7.939636      0.874206          -6583             5000
# 7   10.025723      1.015976          -7284             6000
# 8   12.033947      0.990312          -7774             7000
# 9   13.772976      0.682669          -8221             8000
# 10  13.772976      0.445246          -8556             8000
# 11  15.570000      0.357895          -9000             9000
# 12  15.570000      0.110968          -9315             9000
# 13  17.154568      0.262642         -10218            10000
# 14  19.167149     -0.479139         -11334            11000
# 15  20.696566     -1.635061         -12181            12000
# 16  20.696566     -2.646395         -12657            12000
# 17  20.696566     -2.933255         -13043            12000
# 18  20.696566     -3.326758         -12780            12000
# 19  20.892645     -3.690161         -12860            12000
# 20  20.892645     -4.423634         -13220            12000
# 21  22.950129     -4.649737         -13626            13000
# 22  25.103414     -5.116385         -14233            14000
# 23  25.103414     -6.187550         -15049            14000
# 24  27.422964     -7.040884         -15487            15000
# 25  29.730223     -7.343207         -16421            16000
# 26  29.730223     -8.137280         -15894            16000
# 27  29.730223     -8.718186         -16575            16000
# 28  29.730223     -9.714042         -16963            16000
# 29  29.730223    -10.342525         -16910            16000
# 30  31.734602    -11.299628         -17339            17000
# 31  34.156236    -12.058629         -18413            18000
# 32  34.156236    -12.478297         -18827            18000
# 33  34.156236    -12.711580         -19007            18000
# 34  34.156236    -12.947687         -19159            18000
# 35  36.567313    -13.409724         -19735            19000
# 36  38.753307    -13.950041         -20428            20000
# 37  38.753307    -14.046432         -20923            20000
# 38  41.233108    -14.137402         -21974            21000
# 39  43.573950    -14.306843         -22329            22000
# 40  43.573950    -14.496978         -22256            22000
# 41  45.582016    -14.853889         -23307            23000
# 42  45.582016    -14.891918         -23804            23000
# 43  45.861301    -15.383726         -24493            23000
# 44  47.875441    -16.382311         -24725            24000
# 45  47.875441    -16.988716         -25172            24000
# 46  49.548791    -17.785857         -25424            25000
# 47  49.548791    -18.207909         -25639            25000
# 48  51.393953    -18.786228         -25901            26000
# 49  51.393953    -18.836632         -26739            26000
# 50  51.393953    -20.291085         -27615            26000
# 51  54.041289    -21.660409         -28222            27000
# 52  56.381570    -22.764150         -28586            28000
# 53  59.009707    -24.258885         -29254            29000
# 54  59.009707    -25.112296         -29251            29000
# 55  59.009707    -25.787091         -29408            29000
# 56  59.009707    -26.613054         -29808            29000
# 57  61.047014    -27.090093         -30104            30000
# 58  61.047014    -27.643458         -30593            30000
# 59  62.831788    -28.436639         -31359            31000

# %%
mean_reward, irq, es, rewards = evaluate_policy(model, env, n_eval_episodes=500)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(f"number of episodes = {len(rewards)}, mean_reward={mean_reward:.2f} Expected Shortfall={es:.2f} Interquartile Range={irq:.2f}")
# Out:
# number of episodes = 500, mean_reward=1215.74 Expected Shortfall=877.00 Interquartile Range=146.75

# %%
visualize.plot_rewards(rewards, interpolate_line=False, rolling_line=True, ylim=(-2000,2000), color = 'Green',
                       label = model_name,
                       title = f"Test {model_name} outroll over {int(steps/60)} Episodes. ")

# %% [markdown]
# It would be great if we can store a local copy of the notebook after execution so I can easily look back at the performed actions...

# %%
from google.colab import runtime
runtime.unassign()
